# %% [markdown]
# <a href="https://colab.research.google.com/github/restrepo/BSM-Submodules/blob/master/SARAH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
if os.getcwd()=='/content':
    # !wget -O SARAH.py https://raw.githubusercontent.com/restrepo/BSM-Submodules/master/SARAH.py 2>/dev/null
    # !wget -O cmdlike.py https://raw.githubusercontent.com/restrepo/BSM-Submodules/master/cmdlike.py 2>/dev/null
    # !git clone https://github.com/restrepo/SARAH.git 2>/dev/null
    # !mkdir -p JSON
    os.chdir('JSON')
    # !wget -O fullparticles.json https://raw.githubusercontent.com/restrepo/BSM-Submodules/master/JSON/fullparticles.json 2> /dev/null
    # !wget -O fullparticlesnames.json https://raw.githubusercontent.com/restrepo/BSM-Submodules/master/JSON/fullparticlesnames.json 2> /dev/null
    # !wget -O fullparametersnames.json https://raw.githubusercontent.com/restrepo/BSM-Submodules/master/JSON/fullparametersnames.json 2> /dev/null
    os.chdir('../')

# %%
import pandas as pd
import json
import re
import numpy as np
import sys
from SARAH import *
pd.set_option('display.max_colwidth',200)

# %% [markdown]
# ##  Load particles

# %% [markdown]
# Generated with [./particles.ipynb](./particles.ipynb)

# %%
SM=pd.read_json('JSON/particles.json')

# %%
SM
# Out:
#                                                           WeylFermionAndIndermediate  \
# Ah                                                                               NaN
# DL                                                                  {'LaTeX': 'D_L'}
# DR                                                                  {'LaTeX': 'D_R'}
# EL                                                                  {'LaTeX': 'E_L'}
# ER                                                                  {'LaTeX': 'E_R'}
# Fd                                                                               NaN
# Fe                                                                               NaN
# Fu                                                                               NaN
# Fv                                                                               NaN
# H     {'Width': 0, 'Mass': 'Automatic', 'OutputName': 'H', 'PDG': [0], 'LaTeX': 'H'}
# H0                                                                               NaN
# Hp                                                                               NaN
# UL                                                                  {'LaTeX': 'U_L'}
# UR                                                                  {'LaTeX': 'U_R'}
# VB                                                                               NaN
# VG                                                                               NaN
# VP                                                                               NaN
# VWB                                                                              NaN
# VWp                                                                              NaN
# VZ                                                                               NaN
# dL                                                                  {'LaTeX': 'd_L'}
# dR                                                                  {'LaTeX': 'd_R'}
# eL                                                                  {'LaTeX': 'e_L'}
# eR                                                                  {'LaTeX': 'e_R'}
# gB                                                                               NaN
# gG                                                                               NaN
# gP                                                                               NaN
# gWB                                                                              NaN
# gWp                                                                              NaN
# gWpC                                                                             NaN
# gZ                                                                               NaN
# hh                                                                               NaN
# l                                                                     {'LaTeX': 'l'}
# q                                                                     {'LaTeX': 'q'}
# uL                                                                  {'LaTeX': 'u_L'}
# uR                                                                  {'LaTeX': 'u_R'}
# vL                                                               {'LaTeX': '\\nu_L'}
#
#                                                                                                  GaugeES  \
# Ah                                                                                                   NaN
# DL                                                                                                   NaN
# DR                                                                                                   NaN
# EL                                                                                                   NaN
# ER                                                                                                   NaN
# Fd                                                                                                   NaN
# Fe                                                                                                   NaN
# Fu                                                                                                   NaN
# Fv                                                                                                   NaN
# H                                                                                                    NaN
# H0    {'LaTeX': 'H^0', 'OutputName': 'H0', 'FeynArtsNr': 1, 'PDG': [0], 'Width': 0, 'Mass': 'Automatic'}
# Hp    {'LaTeX': 'H^+', 'OutputName': 'Hp', 'FeynArtsNr': 2, 'PDG': [0], 'Width': 0, 'Mass': 'Automatic'}
# UL                                                                                                   NaN
# UR                                                                                                   NaN
# VB                                                                            {'Description': 'B-Boson'}
# VG                                                                              {'Description': 'Gluon'}
# VP                                                                                                   NaN
# VWB                                                                          {'Description': 'W-Bosons'}
# VWp                                                                                                  NaN
# VZ                                                                                                   NaN
# dL                                                                                                   NaN
# dR                                                                                                   NaN
# eL                                                                                                   NaN
# eR                                                                                                   NaN
# gB                                                                      {'Description': 'B-Boson Ghost'}
# gG                                                                        {'Description': 'Gluon Ghost'}
# gP                                                                                                   NaN
# gWB                                                                     {'Description': 'W-Boson Ghost'}
# gWp                                                                                                  NaN
# gWpC                                                                                                 NaN
# gZ                                                                                                   NaN
# hh                                                                                                   NaN
# l                                                                                                    NaN
# q                                                                                                    NaN
# uL                                                                                                   NaN
# uR                                                                                                   NaN
# vL                                                                                                   NaN
#
#                                                                                                                                                                   EWSB
# Ah                                                                        {'PDG.IX': [0], 'Width': [0], 'Description': 'Pseudo-Scalar Higgs', 'Mass': [0], 'PDG': [0]}
# DL                                                                                                                                                                 NaN
# DR                                                                                                                                                                 NaN
# EL                                                                                                                                                                 NaN
# ER                                                                                                                                                                 NaN
# Fd                                                                                                                                      {'Description': 'Down-Quarks'}
# Fe                                                                                                                                          {'Description': 'Leptons'}
# Fu                                                                                                                                        {'Description': 'Up-Quarks'}
# Fv                                                                                                                                        {'Description': 'Neutrinos'}
# H                                                                                                                                                                  NaN
# H0                                                                                                                                                                 NaN
# Hp    {'LaTeX': ['H^+', 'H^-'], 'OutputName': ['Hp', 'Hm'], 'PDG': [0], 'ElectricCharge': 1, 'PDG.IX': [0], 'Width': [0], 'Description': 'Charged Higgs', 'Mass': [0]}
# UL                                                                                                                                                                 NaN
# UR                                                                                                                                                                 NaN
# VB                                                                                                                                                                 NaN
# VG                                                                                                                                            {'Description': 'Gluon'}
# VP                                                                                                                                           {'Description': 'Photon'}
# VWB                                                                                                                                                                NaN
# VWp                                                                                                                   {'Goldstone': 'Hp', 'Description': 'W+ - Boson'}
# VZ                                                                                                                       {'Goldstone': 'Ah', 'Description': 'Z-Boson'}
# dL                                                                                                                                                                 NaN
# dR                                                                                                                                                                 NaN
# eL                                                                                                                                                                 NaN
# eR                                                                                                                                                                 NaN
# gB                                                                                                                                                                 NaN
# gG                                                                                                                                      {'Description': 'Gluon Ghost'}
# gP                                                                                                                                     {'Description': 'Photon Ghost'}
# gWB                                                                                                                                                                NaN
# gWp                                                                                                                       {'Description': 'Positive W+ - Boson Ghost'}
# gWpC                                                                                                                      {'Description': 'Negative W+ - Boson Ghost'}
# gZ                                                                                                                                    {'Description': 'Z-Boson Ghost'}
# hh                                                                                                        {'PDG.IX': [101000001], 'Description': 'Higgs', 'PDG': [25]}
# l                                                                                                                                                                  NaN
# q                                                                                                                                                                  NaN
# uL                                                                                                                                                                 NaN
# uR                                                                                                                                                                 NaN
# vL                                                                                                                                                                 NaN

# %%
kk=to_math(SM,'p.m')

# %% [markdown]
# ## Load parameters

# %% [markdown]
# Generated with [parameters.ipynb](./parameters.ipynb)

# %%
SMp=pd.read_json('JSON/parameters.json')

# %%
kk=to_math(SM,'para.m',definitions='ParameterDefinitions')

# %%
SMp
# Out:
#                                                                                                                                                                     Properties
# AlphaS                                                                                                                                         {'Description': 'Alpha Strong'}
# Gf                                                                                                                                         {'Description': 'Fermi's constant'}
# ThetaW                                                                          {'Description': 'Weinberg-Angle', 'DependenceNum': 'ArcSin[Sqrt[1 - Mass[VWp]^2/Mass[VZ]^2]]'}
# Ud                                                                                                                                 {'Description': 'Right-Down-Mixing-Matrix'}
# Ue                                                                                                                               {'Description': 'Right-Lepton-Mixing-Matrix'}
# Uu                                                                                                                                   {'Description': 'Right-Up-Mixing-Matrix'}
# Vd                                                                                                                                  {'Description': 'Left-Down-Mixing-Matrix'}
# Ve                                                                                                                                {'Description': 'Left-Lepton-Mixing-Matrix'}
# Vu                                                                                                                                    {'Description': 'Left-Up-Mixing-Matrix'}
# Yd           {'Description': 'Down-Yukawa-Coupling', 'DependenceNum': 'Sqrt[2]/v* {{Mass[Fd,1],0,0 },
#                 {0, Mass[Fd,2],0},
#                 {0, 0, Mass[Fd,3]}}'}
# Ye         {'Description': 'Lepton-Yukawa-Coupling', 'DependenceNum': 'Sqrt[2]/v* {{Mass[Fe,1],0,0 },
#                 {0, Mass[Fe,2],0},
#                 {0, 0, Mass[Fe,3]}}'}
# Yu             {'Description': 'Up-Yukawa-Coupling', 'DependenceNum': 'Sqrt[2]/v* {{Mass[Fu,1],0,0 },
#                 {0, Mass[Fu,2],0},
#                 {0, 0, Mass[Fu,3]}}'}
# ZW                                        {'Description': 'W Mixing Matrix', 'Dependence': '1/Sqrt[2] {{1, 1},
#                               {\[ImaginaryI],-\[ImaginaryI]}}'}
# ZZ                                                                                                                                   {'Description': 'Photon-Z Mixing Matrix'}
# \[Lambda]                                                                                       {'Description': 'SM Higgs Selfcouplings', 'DependenceNum': 'Mass[hh]^2/(v^2)'}
# aEWinv                                                                                                                 {'Description': 'inverse weak coupling constant at mZ'}
# e                                                                                                                                           {'Description': 'electric charge'}
# g1                                                                                                                                     {'Description': 'Hypercharge-Coupling'}
# g2                                                                                                                                            {'Description': 'Left-Coupling'}
# g3                                                                                                                                          {'Description': 'Strong-Coupling'}
# mH2                                                                                                                                 {'Description': 'SM Higgs Mass Parameter'}
# mu2                                                                                                                   {'OutputName': 'm2SM', 'Description': 'SM Mu Parameter'}
# v                                                     {'OutputName': 'vvSM', 'DependenceSPheno': None, 'Description': 'EW-VEV', 'DependenceNum': 'Sqrt[4*Mass[VWp]^2/(g2^2)]'}

# %% [markdown]
# ## Load SPheno

# %% [markdown]
# Generated with [SPheno.ipynb](./SPheno.ipynb)

# %%
SP=pd.read_json('JSON/SPheno.json')
SP=SP.sort_values('Index')

# %%
to_SPheno(SP,'sp.m',dictentries=['DefaultInputValues'])

# %% [markdown]
# ## Design
# USAGE:
# 1. Load a `SARAH` Model File
# 2. Warns if a `particle` or `parameter` is not yet defined
# 3. Build missing `particles` or `parameters` and update predefined particles loaded in `__init__`
# 4. Export `SARAH` auxiliarly files:
#    * `particles.m`
#    * `parameters.m`
#    * `SPheno.m`

# %%
import re
path="./SARAH/Models/"
re.search('\/$',path)
# Out:
# <_sre.SRE_Match object; span=(14, 15), match='/'>

# %%
import pandas as pd
import json
import re
import sys
from SARAH import *
#Move to SARAH
def get_EWSB(model,NAME='DEFINITION',KEY='EWSB'):
    dsbd=parse_mathematica_list_of_list(model,NAME='DEFINITION',KEY='EWSB')
    DEFINITION={}
    DEFINITION['EWSB']={}
    Bidiagonal=[]
    Diagonal=[]
    VEV=[]
    for k in dsbd.keys():

        for w in dsbd[k]:
            if k=='GaugeSector' or k=='MatterSector':
                if np.array(w).shape==(2,2):
                    weyl=bidiagonal(w,k)
                    Bidiagonal.append(weyl)
                elif np.array(w).shape==(3,):
                    symm=diagonal(w,k)
                    Diagonal.append(symm)
            elif k=='VEVs':
                VEV.append(get_vev(w,k))

    DEFINITION['EWSB']['Bidiagonal']=Bidiagonal
    DEFINITION['EWSB']['Diagonal']=Diagonal
    DEFINITION['EWSB']['VEVs']=VEV
    DEFINITION['EWSB']['DiracSpinors']=dsbd['DiracSpinors']
    return DEFINITION

def get_weylfermion_LaTeX(s):
    if len(s)==2 and re.search('[LR]$',s):
        sini=s[0]
        if sini=='v':
            sini=r'\nu'
        s=sini+'_'+s[1]
    return s

def get_abs_groups(grps=['1/2','2','1'],u1_abs='1/2',su2='2',su3_abs='1'):
    sgrps=str(grps).replace(' ','')
    return re.search(r"\['-*{}','{}','{}'".format(u1_abs,su2,su3_abs), sgrps )

def update_EWSB_Fermion_Description(p,prt):
    gprt=prt[prt.get('Field')==p.get('Parents')].reset_index(drop=True)
    if gprt.loc[0,'rotation']:
        gprt=prt[prt.get('Field')==gprt.loc[0,'Parents']].reset_index(drop=True)
    cmpt=gprt.loc[0,'Field']
    gprt=prt[prt.get('Field')==gprt.loc[0,'Parents']].reset_index(drop=True)
    if get_abs_groups( gprt.loc[0,'Properties'].get('Groups'), u1_abs='1/6',su2='2',su3_abs='3' ):
        if cmpt==gprt.loc[0,'Properties'].get('multiplet')[0]:
            p['Description']='Up-Quarks'
        else:
            p['Description']='Down-Quarks'
    if get_abs_groups( gprt.loc[0,'Properties'].get('Groups'), u1_abs='1/2',su2='2',su3_abs='1' ):
        if cmpt==gprt.loc[0,'Properties'].get('multiplet')[0]:
            p['Description']='Neutrinos'
        else:
            p['Description']='Leptons'
    return p

def get_EWSB_gauge_bosons(p,prt):
    mb=p.get('Properties').get('Mass_basis')
    #Get basis position
    pi=[i for i in range(len(mb)) if p.get('Field')==mb[i] ][-1]
    #Get parent particle
    ppij=p.get('Properties').get('Interaction_basis')[pi]
    #Simplify parent particle name
    ppi=re.sub('\[[0-9]+\]','',ppij)
    #Get Gauge Group from simplified parent particle name
    gppi=(prt[prt.get('Field')==ppi].reset_index(drop=True)).loc[0,'Properties'].get('Group').strip()
    if gppi=='U[1]':
        p['Description']='Photon'
    elif gppi=='SU[2]':
        #Get SU[2] multiplet position
        j=eval(re.search('\[([0-9]+)\]',ppij).groups()[0])
        if j==3:
            p['Description']='Z-Boson'
        elif j<3:
            p['Description']='W+ - Boson'
    return p

def update_EWSB_Fermion_Description(p,prt):
    gprt=prt.apply_filter( lambda d: d.get('Field')==p.get('Parents') )
    if gprt[0].get('rotation'):
        gprt=prt.apply_filter(lambda d: d.get('Field')==gprt[0].get('Parents'))
    cmpt=gprt[0].get('Field')
    gprt=prt.apply_filter(lambda d: d.get('Field')==gprt[0].get('Parents'))
    if get_abs_groups( gprt[0].get('Properties').get('Groups'), u1_abs='1/6',su2='2',su3_abs='3' ):
        if cmpt==gprt[0].get('Properties').get('multiplet')[0]:
            p['Description']='Up-Quarks'
        else:
            p['Description']='Down-Quarks'
    if get_abs_groups( gprt[0].get('Properties').get('Groups'), u1_abs='1/2',su2='2',su3_abs='1' ):
        if cmpt==gprt[0].get('Properties').get('multiplet')[0]:
            p['Description']='Neutrinos'
        else:
            p['Description']='Leptons'
    return p

def get_EWSB_gauge_bosons(p,prt):
    mb=p.get('Properties').get('Mass_basis')
    #Get basis position
    pi=[i for i in range(len(mb)) if p.get('Field')==mb[i] ][-1]
    #Get parent particle
    ppij=p.get('Properties').get('Interaction_basis')[pi]
    #Simplify parent particle name
    ppi=re.sub('\[[0-9]+\]','',ppij)
    #Get Gauge Group from simplified parent particle name
    gppi=prt.apply_filter(lambda d: d.get('Field')==ppi)[0].get('Properties').get('Group').strip()
    if gppi=='U[1]':
        p['Description']='Photon'
    elif gppi=='SU[2]':
        #Get SU[2] multiplet position
        j=eval(re.search('\[([0-9]+)\]',ppij).groups()[0])
        if j==3:
            p['Description']='Z-Boson'
        elif j<3:
            p['Description']='W+ - Boson'
    return p
#================
def _to_dict(df):
    return df.to_dict(orient='records')

#Classes
class list_of_dictionaries(list):
    '''
    Intialize a list of dictionaries
    If the object is returned, mv to the last
    class in the inheritance hierarchy
    '''
    #Optional: just if something need to be check the object itself
    def __init__(self,*args, **kwargs):
        dt=list( set ([ type(d) for d in args[0] ]) )
        if dt and not (len(dt)==1 and dict in dt):
                sys.exit('NOT A LIST OF DICTIONARIES')
        super(list_of_dictionaries, self).__init__(*args, **kwargs)

    def __add__(self,other):
        '''
        Keep the list __add__, but return the proper object:
        
        NOTE: super() -> same as super(__class__, <first argument>)
        '''
        return list_of_dictionaries( super().__add__(other) )
        #return list_of_dictionaries(super(list_of_dictionaries, self).__add__(other))
        
    def size(self):
        return len(self)
    
    def unique(self):
        y=list( set( [str(d) for d in self] ) )
        return list_of_dictionaries( [eval(d) for d in y] )
    
    def Filter(self,k,v,first=False):
        x=list(filter(lambda d: d.get(k)==v,self))
        #x=[d for d in self if d.get(k)==v]
        if not x:
            x=[{}]
        if first:
            return x[0]
        else:
            return list_of_dictionaries(x)

    def apply_filter(self,f):
        x=list(filter(f,self))
        return list_of_dictionaries(x)

    def apply(self,f,args=()):
        if not isinstance(args, tuple):
            args = (args,)
        if args:
            g=lambda x:f(x,*args)
        else:
            g=f
        
        x=list(map(g,self))
        return x

    def Index(self):
        return range(len(self))
    
class Particles(list_of_dictionaries):
    '''
    Object containing a list of particles
    '''
    def __init__(self,*args, **kwargs):
        super(Particles, self).__init__(*args, **kwargs)
        
    #Be sure that Particles is returned:
    def __add__(self,*args, **kwargs):
        return Particles(super().__add__(*args, **kwargs))
    
    def apply(self,*args, **kwargs):
        return super().apply(*args, **kwargs)
    
    def update(self,d):
        '''
        Updated internally with:
        d: dictionary
        for each one of the particles (dictionaries) in the
        Particles object
        '''
        for k in d.keys():
            kk=self.apply(lambda p: p.update({k:d[k]}) )  
    
    def unique(self):
        return Particles( super().unique() )
    

    def apply_filter(self,*args, **kwargs):
        return Particles(super().apply_filter(*args, **kwargs))


    #New methods:
    def mask(self,msk):
        return Particles( np.array(self)[msk] )

    def get_fields(self,field='Field'):
        return [d.get(field) for d in self]

class Parameters(Particles):
    '''
    Object containing a list of parameters
    '''
    def get_symbols(self,field='Symbol'):
        '''
        returns a list
        '''
        return super(Parameters,self).get_fields(field=field)
    
class SARAH:
    def __init__(self,model='SM',
                      path="./SARAH/Models/",
                      particles ='JSON/fullparticlesnames.json',
                      parameters='JSON/fullparametersnames.json',
                      SPheno='JSON/fullSPhenonames.json'):
        '''
        LOAD predefined particles
        TODO: Include singlet scalar and other multiplets
        TODO: modify to_dict to default orient="records"
        '''
        f=open('JSON/fullparticlesnames.json','r')
        self.particles=Particles(json.load(f))
        f.close()        
        dfpt=pd.DataFrame(self.particles)
        dfpt.index=dfpt['Name'].str.replace('-','_').str.replace('\s','_')
        self.particle = pd.Series()
        for n in dfpt.index:
            self.particle[n]=dfpt.loc[n]
        f=open('JSON/fullparametersnames.json','r')
        self.parameters=Parameters(json.load(f))
        f.close()        
        dfpm = pd.DataFrame(self.parameters)
        dfpm.index=dfpm['Name'].str.replace('-','_').str.replace('\s','_')
        self.parameter = pd.Series()
        for n in dfpm.index:
            self.parameter[n]=dfpm.loc[n]
        self.SPheno={}
        self.Fields=['Gauge','FermionFields','ScalarFields']
        self.NAME='DEFINITION'
        self.KEY='EWSB'
        self.modelparticles=Particles([])
        self.modelparameters=Parameters([])
        self.modelSPheno=[]
        #READ Model File
        if not re.search('\/$',path):
            path=path+'/'
        mfile='{}.m'.format(model.split('/')[-1])
        MODEL_PATH='{}{}/{}'.format(path,model,mfile)
        f=open(MODEL_PATH,'r')
        self.model_file=f.read()
        f.close()
        self.DEFINITION=get_EWSB(self.model_file,self.NAME,self.KEY)

        
    def parse_particle_content(self):
        '''1)
        Parse Particle Content section of SARAH Model File
        with the intial particles in the GaugeES basis
        '''
        newparticles=get_particles(self.model_file,self.Fields,self.NAME,self.KEY,[],[])
        self.modelparticles=Particles( self.modelparticles+newparticles )
        return Particles(newparticles)
    
    
    def parse_vevs_particles(self):
        '''3.a)
        '''
        newparticles=[]
        for d in self.DEFINITION[self.KEY]['VEVs']:
            particle=vev_to_particles(d,cp='Real')
            newparticles.append(particle)
            particle=vev_to_particles(d,cp='Imaginary')
            newparticles.append(particle)
            
        self.modelparticles=Particles( self.modelparticles+newparticles )
        return Particles(newparticles)
    def parse_diagonal_rotated_particles(self):
        '''3.b.I)
        '''
        newp=rotations_to_particles(self.DEFINITION,
                                     self.KEY,
                                     lr='',
                                     sep='')
        self.modelparticles=Particles( self.modelparticles+newp )
        return Particles( newp )

    def parse_bidiagonal_rotated_particles(self):
        '''3.b.II) - 3.b.III)
        '''
        newp=rotations_to_particles(self.DEFINITION,
                                        self.KEY,
                                        lr='left',
                                        sep='_')
        newp=newp+rotations_to_particles(self.DEFINITION,
                                        self.KEY,
                                        lr='right',
                                        sep='_')
        self.modelparticles=Particles(self.modelparticles+newp)
        return Particles(newp)

    def parse_DiracSpinors(self):
        '''3.c)
        '''
        newparticles=[]
        dict_of_spinors=self.DEFINITION['EWSB']['DiracSpinors']
        for f in dict_of_spinors.keys():
            particle=spinor_to_particles(dict_of_spinors,self.DEFINITION,f)
            newparticles.append(particle)
            
        self.modelparticles=Particles( self.modelparticles+newparticles )
        return Particles( newparticles )
    
    def parse_DEFINITION(self):
        '''3a..e)
        '''
        newp=self.parse_vevs_particles()
        newp=newp+self.parse_diagonal_rotated_particles()
        newp=newp+self.parse_bidiagonal_rotated_particles()
        newp=newp+self.parse_DiracSpinors()        
        return newp
    
    def parse_model_particles(self):
        '''
        Generate particles, parameters and SPheno dictionary.
        A) There will be a basic class of particles which can be readed directly
        B) Later one inhereted class with SM particles
        C) May be one final class with BSM particles not automatically identified
        The SARAH file is organized in sections:
        1) First the Gauge, FermionFields and ScalarFields in the Gauge basis
        2) Next the Lagrangian (more relevant to extract parameters)
        3) Next load the dictionary DEFINITION
        3.a) VEVS definitions 
        3.b) Rotations 
        3.b.I)   Diagonal -> GaugeSector, MatterField
        3.b.II)  Bidiagonal left  -> MatterField
        3.b.III) Bidiagonal right -> MatterField
        3.c) Dirac Fermions
        '''
        #2)
        newp=self.parse_particle_content()
        #3) a...c
        newp=newp+self.parse_DEFINITION()
        return newp
        #Check missing particles
        
    def update_particles(self,f,Definition='EWSB',Lorentz='DiracSpinor',args=()):
        DS=self.modelparticles.apply_filter(
                   lambda p: p.get('Definition')==Definition
                ).apply_filter(
                   lambda p: p.get('Properties').get('Lorentz').strip()==Lorentz)
        return DS.apply(f,args=args )
    
    def add_parameter(self,Name):
        # update predefined dataframes for particles, parameters and SPheno
        #reuturn series
        pass
    def to_particles(self,file='particles.m'):
        '''
        Generate particles.m
        '''
        pass
    def to_parameters(self,file='parameters.m'):
        '''
        Generate parameters.m
        '''
        pass
    def to_SPheno(self,file='SPheno.m'):
        '''
        Generate SPheno.m
        '''
        pass
    def to_all(self):
        self.to_particles()
        self.to_parameters()
        self.to_SPheno()
    def to_json(self):
        '''
        UPDATE JSON predefined dictionaries
        '''
        pass
#class

# %%
def test_Particles_and_Parameters():
    w=Parameters( [{'Symbol':'g','B':6}]  )
    x=Particles( [{'Field':'Z','A':1,'B':2},{'A':2},{'A':3,'B':2}] )
    y=Particles( [{'B':4},{'B':4}]   )
    z=x+y
    yy=y.unique()
    xx=x.apply_filter( lambda d: d.get('Field')=='Z')
    xxx=x.apply( lambda d: d.get('Field')=='Z')

    assert z.size()==5
    assert yy==[{'B': 4}]
    assert x.get_fields()==['Z', None, None]
    assert w.get_symbols()==['g']
    assert xx==[{'A': 1, 'B': 2, 'Field': 'Z'}]
    assert xxx==[True, False, False]
    assert x.mask(x.apply(lambda p: p.get('A')>2))==[{'A': 3, 'B': 2}]

    assert str(type(x) ).find('Particles')>-1
    assert str(type(z) ).find('Particles')>-1
    assert str(type(yy)).find('Particles')>-1
    assert str(type(w)).find('Parameters')>-1
    assert str(type(xx)).find('Particles')>-1
    return z
z=test_Particles_and_Parameters()
z.unique()
# Out:
# [{'B': 4}, {'A': 1, 'B': 2, 'Field': 'Z'}, {'A': 2}, {'A': 3, 'B': 2}]

# %%
#s=SARAH(model='SM')
#s.model_file

#1)
#newparticles=s.parse_particle_content()
#pd.DataFrame(newparticles)

#pd.DataFrame(s.parse_vevs_particles())

#pd.DataFrame(s.parse_diagonal_rotated_particles())

#pd.DataFrame(s.parse_bidiagonal_rotated_particles())

#pd.DataFrame(s.parse_DiracSpinors())

# %%
s=SARAH(model='SM')
newp=s.parse_model_particles()
# Out:
# ('B,   U[1], hypercharge, g1,False',) Gauge 5
# {'Field': 'VB', 'Parents': None, 'Properties': {'Group': '   U[1]', 'Index': ' hypercharge', 'Coupling': ' g1', 'SSB': ' g1', 'Lorentz': 'Vector'}, 'Definition': 'GaugeES'}
# ('WB, SU[2], left,        g2,True',) Gauge 5
# {'Field': 'VWB', 'Parents': None, 'Properties': {'Group': ' SU[2]', 'Index': ' left', 'Coupling': '        g2', 'SSB': '        g2', 'Lorentz': 'Vector'}, 'Definition': 'GaugeES'}
# ('G,  SU[3], color,       g3,False',) Gauge 5
# {'Field': 'VG', 'Parents': None, 'Properties': {'Group': '  SU[3]', 'Index': ' color', 'Coupling': '       g3', 'SSB': '       g3', 'Lorentz': 'Vector'}, 'Definition': 'GaugeES'}
# ('q, 3, uL:: dL,     1/6, 2,  3;  ',) FermionFields 6
# **********
#  uL:: dL [' uL', ' dL']
#  uL
#  dL
# **********
# ('l, 3, vL:: eL,    -1/2, 2,  1;',) FermionFields 6
# **********
#  vL:: eL [' vL', ' eL']
#  vL
#  eL
# **********
# ('d, 3, conj[dR],     1/3, 1, -3',) FermionFields 6
# **********
#  conj[dR] [' dR']
#  dR
# **********
# ('u, 3, conj[uR],    -2/3, 1, -3',) FermionFields 6
# **********
#  conj[uR] [' uR']
#  uR
# **********
# ('e, 3, conj[eR],       1, 1,  1',) FermionFields 6
# **********
#  conj[eR] [' eR']
#  eR
# **********
# ('H, 1, Hp:: H0,     1/2, 2,  1;',) ScalarFields 6
# **********
#  Hp:: H0 [' Hp', ' H0']
#  Hp
#  H0
# **********

# %%
pd.DataFrame(s.modelparticles)
# Out:
#    Field   Parents  ...         Block rotation
# 0     VB      None  ...           NaN      NaN
# 1    VWB      None  ...           NaN      NaN
# 2     VG      None  ...           NaN      NaN
# 3      q      None  ...           NaN      NaN
# 4      l      None  ...           NaN      NaN
# 5      d      None  ...           NaN      NaN
# 6      u      None  ...           NaN      NaN
# 7      e      None  ...           NaN      NaN
# 8      H      None  ...           NaN      NaN
# 9     uL         q  ...           NaN      NaN
# 10    dL         q  ...           NaN      NaN
# 11    vL         l  ...           NaN      NaN
# 12    eL         l  ...           NaN      NaN
# 13    dR         d  ...           NaN      NaN
# 14    uR         u  ...           NaN      NaN
# 15    eR         e  ...           NaN      NaN
# 16    Hp         H  ...           NaN      NaN
# 17    H0         H  ...           NaN      NaN
# 18    hh        H0  ...          VEVs      NaN
# 19    Ah        H0  ...          VEVs      NaN
# 20    VP        VB  ...   GaugeSector       ZZ
# 21    VZ    VWB[3]  ...   GaugeSector       ZZ
# 22   VWp    VWB[1]  ...   GaugeSector       ZW
# 23    DL        dL  ...   MatterField       Vd
# 24    UL        uL  ...   MatterField       Vu
# 25    EL        eL  ...   MatterField       Ve
# 26    DR  conj[dR]  ...   MatterField       Ud
# 27    UR  conj[uR]  ...   MatterField       Uu
# 28    ER  conj[eR]  ...   MatterField       Ue
# 29    Fd        DL  ...  DiracSpinors      NaN
# 30    Fe        EL  ...  DiracSpinors      NaN
# 31    Fu        UL  ...  DiracSpinors      NaN
# 32    Fv        vL  ...  DiracSpinors      NaN
#
# [33 rows x 6 columns]

# %%
def test_SARAH(mprt):
    assert mprt.apply_filter(lambda d: 
                    d.get('Field')=='Fd')[0].get('Block')=='DiracSpinors'
    
    assert s.modelparticles.apply_filter(lambda d: 
                              d.get('Properties').get('Lorentz')=='DiracSpinor'
                ).apply_filter(lambda d: d.get('Field')=='Fu'
                )[0].get('Block')=='DiracSpinors'
    mprt.apply_filter(lambda d: 
                    d.get('Block')=='DiracSpinors'
                    ).update({'Description':'NewParticles'}
       )
    assert mprt.apply_filter(lambda d: 
                    d.get('Description')=='NewParticles'
                 )[-1]['Description']=='NewParticles'    
test_SARAH(copy.deepcopy(s.modelparticles))

# %% [markdown]
# ## Update particles

# %% [markdown]
# ### How to build a function for the `self.update_particles` method
# For one Specific Type of Particles: `self.update_particles(f,Definition,Lorentz,args)` is expected to filter the set of particles
# by using the  `Definition`  and `Lorentz` arguments, and pass the resulting list of particles (as an object `Particles`) to function `f(particle,*args)`, where `particle` is each one of the elements of the filtered list of particles.  The function must return another `Particles` object with the help of the extra arguments passed through the optional tuple: `args=(...)`
#
# The main purpose of the generic function `f` is either to
# 1. add additional info to an existing particle: Define a function with a mandatory `particle` argument which returns the  same particle with additional info like `p['Description]`. The recommended name for the function in such a case is `get_Specific_Type_of_Particles_Descriptions(particle,...)`
# 1. generate a new non-existing particle. In such a case the recommended name for the function is `get_Specific_Type_of_Particles(particle,...)`
#
# __Example__:
#
# Define
# ```python
# def get_WeylFermion_Description(p,particles):
#     p.get('Properties')['update_Description']={'LaTeX' : get_weylfermion_LaTeX( p.get('Field') )}
#     return p
# ```
# and use
# ```python
# self.update_particles( get_WeylFermion_Descriptions,
#                       Definition='WeylFermionAndIndermediate',
#                       Lorentz='WeylFermion')
# ```

# %%
def get_WeylFermion_Descriptions(p):
    p.get('Properties')['update_Description']={'LaTeX' : get_weylfermion_LaTeX( p.get('Field') )}
    return p

def get_4Spinor_Descriptions(particle,particles):
    """
    Function which that take the dictionary particle and adds: 
    'Description' or 'Properties' -> 'updata_Description'
    To the particle with 'Field' some 4Spinor
    """
    p=particle
    gprt=particles.apply_filter( lambda d: d.get('Field')==p.get('Parents') )
    if gprt[0].get('rotation'):
        gprt=particles.apply_filter(lambda d: d.get('Field')==gprt[0].get('Parents'))
    cmpt=gprt[0].get('Field')
    gprt=particles.apply_filter(lambda d: d.get('Field')==gprt[0].get('Parents'))
    if get_abs_groups( gprt[0].get('Properties').get('Groups'), u1_abs='1/6',su2='2',su3_abs='3' ):
        if cmpt==gprt[0].get('Properties').get('multiplet')[0]:
            p['Description']='Up-Quarks'
        else:
            p['Description']='Down-Quarks'
    if get_abs_groups( gprt[0].get('Properties').get('Groups'), u1_abs='1/2',su2='2',su3_abs='1' ):
        if cmpt==gprt[0].get('Properties').get('multiplet')[0]:
            p['Description']='Neutrinos'
        else:
            p['Description']='Leptons'
    return p

def get_gauge_vectors_Descriptions(p,particles,di={'U[1]' :{'Description':'B-Boson' ,'Ghost':'B-Boson Ghost' },
                    'SU[2]':{'Description':'W-Bosons','Ghost':'W-Boson Ghost'},
                    'SU[3]':{'Description':'Gluon'   ,'Ghost':'Gluon Ghost'}}):
    gr=p.get('Properties').get('Group').strip()
    if di.get( gr  ):
        p['Description']=di.get(gr).get('Description')
    return p

def get_ghosts(p,particles,di={'U[1]' :{'Description':'B-Boson' ,'Ghost':'B-Boson Ghost' },
                    'SU[2]':{'Description':'W-Bosons','Ghost':'W-Boson Ghost'},
                    'SU[3]':{'Description':'Gluon'   ,'Ghost':'Gluon Ghost'}}):
    gr=p.get('Properties').get('Group').strip()
    if di.get( gr  ):
        p=particles.apply_filter(lambda d: d.get('Description')==di.get(gr).get('Ghost'))[0]
        return p
    else:
        return {}

# %% [markdown]
# TODO:
# Make an inherited class from `SARAH` with the previous definitions and the following method:

# %%
us=s
self=us
NP=us.update_particles(get_4Spinor_Descriptions,
                           Definition='EWSB',
                           Lorentz='DiracSpinor',
                           args=(self.modelparticles))
NP=NP+us.update_particles(get_4Spinor_Descriptions,
                           Definition='EWSB',Lorentz='MajoranaSpinor',args=(self.modelparticles))
NP=NP+us.update_particles( get_WeylFermion_Descriptions, 
                           Definition='WeylFermionAndIndermediate',
                           Lorentz='WeylFermion')
NP=NP+us.update_particles(get_gauge_vectors_Descriptions,
                           Definition='GaugeES',
                           Lorentz='Vector',
                           args=(self.modelparticles,
                     {'U[1]' :{'Description':'B-Boson' ,'Ghost':'B-Boson Ghost' },
                      'SU[2]':{'Description':'W-Bosons','Ghost':'W-Boson Ghost'},
                      'SU[3]':{'Description':'Gluon'   ,'Ghost':'Gluon Ghost'}}))
NP=NP+us.update_particles(get_ghosts,
                           Definition='GaugeES',
                           Lorentz='Vector',
                           args=(self.particles,
                     {'U[1]' :{'Description':'B-Boson' ,'Ghost':'B-Boson Ghost' },
                      'SU[2]':{'Description':'W-Bosons','Ghost':'W-Boson Ghost'},
                      'SU[3]':{'Description':'Gluon'   ,'Ghost':'Gluon Ghost'}}))

# %%
pd.DataFrame(NP)
# Out:
#                                                                                                                                          Properties  ...           Name
# 0                                                                                     {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['DL', 'conj[DR]']}  ...            NaN
# 1                                                                                     {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['EL', 'conj[ER]']}  ...            NaN
# 2                                                                                     {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['UL', 'conj[UR]']}  ...            NaN
# 3                                                                                        {'Lorentz': 'MajoranaSpinor', 'MajoranaSpinor': ['vL', 0]}  ...            NaN
# 4               {'NF': '3', 'Groups': ['1/6', '2', '3'], 'Lorentz': 'WeylFermion', 'multiplet': ['uL', 'dL'], 'update_Description': {'LaTeX': 'q'}}  ...            NaN
# 5              {'NF': '3', 'Groups': ['-1/2', '2', '1'], 'Lorentz': 'WeylFermion', 'multiplet': ['vL', 'eL'], 'update_Description': {'LaTeX': 'l'}}  ...            NaN
# 6                                         {'NF': '3', 'Groups': ['1/3', '1', '-3'], 'Lorentz': 'WeylFermion', 'update_Description': {'LaTeX': 'd'}}  ...            NaN
# 7                                        {'NF': '3', 'Groups': ['-2/3', '1', '-3'], 'Lorentz': 'WeylFermion', 'update_Description': {'LaTeX': 'u'}}  ...            NaN
# 8                                            {'NF': '3', 'Groups': ['1', '1', '1'], 'Lorentz': 'WeylFermion', 'update_Description': {'LaTeX': 'e'}}  ...            NaN
# 9                                                                     {'Lorentz': 'WeylFermion', 'NF': '3', 'update_Description': {'LaTeX': 'u_L'}}  ...            NaN
# 10                                                                    {'Lorentz': 'WeylFermion', 'NF': '3', 'update_Description': {'LaTeX': 'd_L'}}  ...            NaN
# 11                                                                  {'Lorentz': 'WeylFermion', 'NF': '3', 'update_Description': {'LaTeX': '\nu_L'}}  ...            NaN
# 12                                                                    {'Lorentz': 'WeylFermion', 'NF': '3', 'update_Description': {'LaTeX': 'e_L'}}  ...            NaN
# 13                                                                    {'Lorentz': 'WeylFermion', 'NF': '3', 'update_Description': {'LaTeX': 'd_R'}}  ...            NaN
# 14                                                                    {'Lorentz': 'WeylFermion', 'NF': '3', 'update_Description': {'LaTeX': 'u_R'}}  ...            NaN
# 15                                                                    {'Lorentz': 'WeylFermion', 'NF': '3', 'update_Description': {'LaTeX': 'e_R'}}  ...            NaN
# 16         {'Mass_basis': 'DL', 'Interaction_basis': ['dL'], 'Chirality': 'left', 'Lorentz': 'WeylFermion', 'update_Description': {'LaTeX': 'D_L'}}  ...            NaN
# 17         {'Mass_basis': 'UL', 'Interaction_basis': ['uL'], 'Chirality': 'left', 'Lorentz': 'WeylFermion', 'update_Description': {'LaTeX': 'U_L'}}  ...            NaN
# 18         {'Mass_basis': 'EL', 'Interaction_basis': ['eL'], 'Chirality': 'left', 'Lorentz': 'WeylFermion', 'update_Description': {'LaTeX': 'E_L'}}  ...            NaN
# 19  {'Mass_basis': 'DR', 'Interaction_basis': ['conj[dR]'], 'Chirality': 'right', 'Lorentz': 'WeylFermion', 'update_Description': {'LaTeX': 'D_R'}}  ...            NaN
# 20  {'Mass_basis': 'UR', 'Interaction_basis': ['conj[uR]'], 'Chirality': 'right', 'Lorentz': 'WeylFermion', 'update_Description': {'LaTeX': 'U_R'}}  ...            NaN
# 21  {'Mass_basis': 'ER', 'Interaction_basis': ['conj[eR]'], 'Chirality': 'right', 'Lorentz': 'WeylFermion', 'update_Description': {'LaTeX': 'E_R'}}  ...            NaN
# 22                                              {'Group': '   U[1]', 'Index': ' hypercharge', 'Coupling': ' g1', 'SSB': ' g1', 'Lorentz': 'Vector'}  ...            NaN
# 23                                        {'Group': ' SU[2]', 'Index': ' left', 'Coupling': '        g2', 'SSB': '        g2', 'Lorentz': 'Vector'}  ...            NaN
# 24                                        {'Group': '  SU[3]', 'Index': ' color', 'Coupling': '       g3', 'SSB': '       g3', 'Lorentz': 'Vector'}  ...            NaN
# 25                                                                                                        {'Group': '   U[1]', 'Lorentz': 'Scalar'}  ...  B-Boson Ghost
# 26                                                                                                         {'Group': ' SU[2]', 'Lorentz': 'Scalar'}  ...  W-Boson Ghost
# 27                                                                                                        {'Group': '  SU[3]', 'Lorentz': 'Scalar'}  ...    Gluon Ghost
#
# [28 rows x 8 columns]

# %% [markdown]
# ## TMP

# %%
class update_SARAH(SARAH):
    def update_particles(self,f,Definition='EWSB',Lorentz='DiracSpinor',args=()):
        DS=self.modelparticles.apply_filter(
                   lambda p: p.get('Definition')==Definition
                ).apply_filter(
                   lambda p: p.get('Properties').get('Lorentz').strip()==Lorentz)
        return DS.apply(f,args=args )    def update_particles(self,f,Definition='EWSB',Lorentz='DiracSpinor',args=()):
        DS=self.modelparticles.apply_filter(
                   lambda p: p.get('Definition')==Definition
                ).apply_filter(
                   lambda p: p.get('Properties').get('Lorentz').strip()==Lorentz)
        return DS.apply(f,args=args )

    def update_GaugeES_Vectors(self,
                di={'U[1]' :{'Description':'B-Boson' ,'Ghost':'B-Boson Ghost' },
                    'SU[2]':{'Description':'W-Bosons','Ghost':'W-Boson Ghost'},
                    'SU[3]':{'Description':'Gluon'   ,'Ghost':'Gluon Ghost'}}):
        prtn=self.modelparticles
        fprt=self.particles
        VB=Particles([])
        G=prtn.apply_filter(lambda p: p.get('Definition')=='GaugeES'
             ).apply_filter(lambda p: p.get('Properties').get('Lorentz').strip()=='Vector')

        for k in di.keys():
            kk1=G.apply_filter(lambda p: p.get('Properties').get('Group').strip()==k )
            if kk1.size()==1:
                kk1.update({'Description':di.get(k).get('Description')} )
                VB=VB+kk1
            kk2=fprt.apply_filter(lambda d: d.get('Description')==di.get(k).get('Ghost'))    
            if kk2.size()==1:
                VB=VB+kk2
        return VB
    def update_WeylFermionAndIndermediate_WeylFermions(self):
        WF=self.modelparticles.apply_filter(
            lambda d: d.get('Definition')=='WeylFermionAndIndermediate'
            ).apply_filter(
            lambda d: d.get('Properties').get('Lorentz').strip()=='WeylFermion'
            )
        kk=WF.apply(lambda p: p.get('Properties').update(
                {'update_Description': 
                    { 'LaTeX' : get_weylfermion_LaTeX( p.get('Field') )} } )
                  )
        return WF    

    def update_Scalar_Particles(self):
        prtn=self.modelparticles
        fprt=self.particles
        S=Particles([])
        H=prtn.apply_filter(lambda p: p.get('Definition')=='WeylFermionAndIndermediate'
             ).apply_filter(lambda p: p.get('Properties').get('Lorentz').strip()=='Scalar')
        
        if self.Add_Charged_SM_Higgs_to_EWSB: #SM-like single VEV, scalar potential
            if get_abs_groups( H[0].get('Properties').get('Groups') ):
                H[0].get('Properties')['update_Description']={
                                               'PDG'       : [0],
                                               'Width'     : 0,
                                               'Mass'      : 'Automatic',
                                               'LaTeX'     : H[0].get('Field'),
                                               'OutputName': H[0].get('Field') }
                S=S+H

        newparticles=S
        dprt=self.modelparticles.apply_filter(lambda d: d.get('Parents')==H[0].get('Field'))
        if len(dprt)==2:
            for j in dprt.Index():
                dp=dprt[j]
                #Higss components
                charge=[]
                #WRONG: Cannot use 'H'
                if True:#dp.get('Parents')==H[0].get('Field'):
                    if H[0].get('Properties').get('Groups')[0].find('-')==-1:
                        charge=['Charged','Neutral']
                    else:
                        charge=['Neutral','Charged']
                    #print('va j',j,charge)
                        
                    if charge[j]=='Charged':
                        #Obtain from general dictionary: Charged Higgs NOT Physical
                        dp.get('Properties')['update_Description']={'PDG'  :[0],
                                'Width':0,
                                'Mass' : 'Automatic',
                                'FeynArtsNr' : 2,
                                'LaTeX' : 'H^+',
                                'OutputName' : dp.get('Field')                            
                               }
                        dp.get('Properties')['ElectricCharge']=1
                        newparticles.append(dp)
                        #TODO: Add EWSB charged scalar only if no more scalars
                        # with parent Hp
                        if self.Add_Charged_SM_Higgs_to_EWSB:
                            gdp={'Definition': 'EWSB',
                                 'Field': 'Hp',
                                 'Parents': 'Hp',
                                 'Description': 'Charged Higgs',
                                 'Properties': {'Lorentz': 'Scalar',
                                 'NF': '1',
                                 'ElectricCharge' : 1,
                                 'update_Description': fprt.apply_filter(
                                       lambda d: d.get('Description')=='Charged Higgs'
                                              )[0].get('Properties'
                                                 ).get('update_Description')}}
                            
                            newparticles.append(gdp)                                
                    else: #Neutral
                        #Obtain from general dictionary: Complex Neutral Higgs
                        dp.get('Properties')['update_Description']={'PDG'  :[0], 
                                'Width':0,
                                'Mass' : 'Automatic',
                                'FeynArtsNr' : 1,
                                'LaTeX' : 'H^0',
                                'OutputName' : dp.get('Field')                        
                               }
                        dp.get('Properties')['ElectricCharge']=0                            
                        newparticles.append(dp)
                        #print('va H0',j)
                        
                        #TODO: Define object to capture two daugthers
                        gdprt=prtn.apply_filter(lambda d: d.get('Parents')==dp.get('Field'))
                        if len(gdprt)==2:
                            for k in gdprt.Index():
                                gdp=gdprt[k]
                                if gdp.get('Properties').get('CP')=='Real':
                                    gdp['Description']='Higgs'
                                    #Obtain from general dictionary: Higgs
                                    gdp.get('Properties')['update_Description']={
                                        'PDG'         : [25],
                                        'PDG.IX'      : [101000001]
                                    }
                                    newparticles.append(gdp)
                                else: #'CP' → Imaginary 
                                    gdp['Description']='Pseudo-Scalar Higgs'
                                    #Obtain from general dictionary: Pseudo-Scalar Higgs
                                    gdp.get('Properties')['update_Description']={
                                        'PDG'         : [0],
                                        'PDG.IX'      : [0],
                                        'Mass'        : [0],
                                        'Width'       : [0]
                                    }
                                    newparticles.append(gdp)                                        
                                #break
                    #break
        #break
        return newparticles


    def update_modelparticles(self):
        chkvevs=self.modelparticles.mask(self.modelparticles.apply(
                   lambda p: True if p.get('Properties').get('vev') else False
                   )    ).size()
        if chkvevs==2:
            self.Add_Charged_SM_Higgs_to_EWSB=True
            
        self.updated_modelparticles=Particles([])
        self.updated_modelparticles=self.updated_modelparticles+self.update_GaugeES_Vectors()
        self.updated_modelparticles=self.updated_modelparticles+self.update_Scalar_Particles()
        self.updated_modelparticles=self.updated_modelparticles+self.update_WeylFermionAndIndermediate_WeylFermions()
        return self.updated_modelparticles

# %%
us=update_SARAH(model='SM')
newp=us.parse_model_particles()
# Out:
# ('B,   U[1], hypercharge, g1,False',) Gauge 5
# {'Field': 'VB', 'Definition': 'GaugeES', 'Parents': None, 'Properties': {'Coupling': ' g1', 'Group': '   U[1]', 'SSB': ' g1', 'Index': ' hypercharge', 'Lorentz': 'Vector'}}
# ('WB, SU[2], left,        g2,True',) Gauge 5
# {'Field': 'VWB', 'Definition': 'GaugeES', 'Parents': None, 'Properties': {'Coupling': '        g2', 'Group': ' SU[2]', 'SSB': '        g2', 'Index': ' left', 'Lorentz': 'Vector'}}
# ('G,  SU[3], color,       g3,False',) Gauge 5
# {'Field': 'VG', 'Definition': 'GaugeES', 'Parents': None, 'Properties': {'Coupling': '       g3', 'Group': '  SU[3]', 'SSB': '       g3', 'Index': ' color', 'Lorentz': 'Vector'}}
# ('q, 3, uL:: dL,     1/6, 2,  3;  ',) FermionFields 6
# **********
#  uL:: dL [' uL', ' dL']
#  uL
#  dL
# **********
# ('l, 3, vL:: eL,    -1/2, 2,  1;',) FermionFields 6
# **********
#  vL:: eL [' vL', ' eL']
#  vL
#  eL
# **********
# ('d, 3, conj[dR],     1/3, 1, -3',) FermionFields 6
# **********
#  conj[dR] [' dR']
#  dR
# **********
# ('u, 3, conj[uR],    -2/3, 1, -3',) FermionFields 6
# **********
#  conj[uR] [' uR']
#  uR
# **********
# ('e, 3, conj[eR],       1, 1,  1',) FermionFields 6
# **********
#  conj[eR] [' eR']
#  eR
# **********
# ('H, 1, Hp:: H0,     1/2, 2,  1;',) ScalarFields 6
# **********
#  Hp:: H0 [' Hp', ' H0']
#  Hp
#  H0
# **********

# %%
pd.DataFrame( us.update_GaugeES_Vectors() )
# Out:
#    Block Definition    Description Field           Name Parents  \
# 0    NaN    GaugeES       W-Bosons   VWB            NaN    None
# 1    NaN    GaugeES  W-Boson Ghost   gWB  W-Boson Ghost     VWB
# 2    NaN    GaugeES          Gluon    VG            NaN    None
# 3    NaN    GaugeES    Gluon Ghost    gG    Gluon Ghost      VG
# 4    NaN    GaugeES        B-Boson    VB            NaN    None
# 5    NaN    GaugeES  B-Boson Ghost    gB  B-Boson Ghost      VB
#
#                                                                                                   Properties  \
# 0  {'Coupling': '        g2', 'Group': ' SU[2]', 'SSB': '        g2', 'Index': ' left', 'Lorentz': 'Vector'}
# 1                                                                   {'Group': ' SU[2]', 'Lorentz': 'Scalar'}
# 2  {'Coupling': '       g3', 'Group': '  SU[3]', 'SSB': '       g3', 'Index': ' color', 'Lorentz': 'Vector'}
# 3                                                                  {'Group': '  SU[3]', 'Lorentz': 'Scalar'}
# 4        {'Coupling': ' g1', 'Group': '   U[1]', 'SSB': ' g1', 'Index': ' hypercharge', 'Lorentz': 'Vector'}
# 5                                                                  {'Group': '   U[1]', 'Lorentz': 'Scalar'}
#
#    rotation
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN

# %%
kk=us.update_modelparticles()
pd.DataFrame( us.updated_modelparticles )
# Out:
#           Block                  Definition          Description Field  \
# 0           NaN                     GaugeES             W-Bosons   VWB
# 1          None                     GaugeES        W-Boson Ghost   gWB
# 2           NaN                     GaugeES                Gluon    VG
# 3          None                     GaugeES          Gluon Ghost    gG
# 4           NaN                     GaugeES              B-Boson    VB
# 5          None                     GaugeES        B-Boson Ghost    gB
# 6           NaN  WeylFermionAndIndermediate                  NaN     H
# 7           NaN                     GaugeES                  NaN    Hp
# 8           NaN                        EWSB        Charged Higgs    Hp
# 9           NaN                     GaugeES                  NaN    H0
# 10         VEVs                        EWSB                Higgs    hh
# 11         VEVs                        EWSB  Pseudo-Scalar Higgs    Ah
# 12          NaN  WeylFermionAndIndermediate                  NaN     q
# 13          NaN  WeylFermionAndIndermediate                  NaN     l
# 14          NaN  WeylFermionAndIndermediate                  NaN     d
# 15          NaN  WeylFermionAndIndermediate                  NaN     u
# 16          NaN  WeylFermionAndIndermediate                  NaN     e
# 17          NaN  WeylFermionAndIndermediate                  NaN    uL
# 18          NaN  WeylFermionAndIndermediate                  NaN    dL
# 19          NaN  WeylFermionAndIndermediate                  NaN    vL
# 20          NaN  WeylFermionAndIndermediate                  NaN    eL
# 21          NaN  WeylFermionAndIndermediate                  NaN    dR
# 22          NaN  WeylFermionAndIndermediate                  NaN    uR
# 23          NaN  WeylFermionAndIndermediate                  NaN    eR
# 24  MatterField  WeylFermionAndIndermediate                  NaN    DL
# 25  MatterField  WeylFermionAndIndermediate                  NaN    UL
# 26  MatterField  WeylFermionAndIndermediate                  NaN    EL
# 27  MatterField  WeylFermionAndIndermediate                  NaN    DR
# 28  MatterField  WeylFermionAndIndermediate                  NaN    UR
# 29  MatterField  WeylFermionAndIndermediate                  NaN    ER
#
#              Name   Parents  \
# 0             NaN      None
# 1   W-Boson Ghost       VWB
# 2             NaN      None
# 3     Gluon Ghost        VG
# 4             NaN      None
# 5   B-Boson Ghost        VB
# 6             NaN      None
# 7             NaN         H
# 8             NaN        Hp
# 9             NaN         H
# 10            NaN        H0
# 11            NaN        H0
# 12            NaN      None
# 13            NaN      None
# 14            NaN      None
# 15            NaN      None
# 16            NaN      None
# 17            NaN         q
# 18            NaN         q
# 19            NaN         l
# 20            NaN         l
# 21            NaN         d
# 22            NaN         u
# 23            NaN         e
# 24            NaN        dL
# 25            NaN        uL
# 26            NaN        eL
# 27            NaN  conj[dR]
# 28            NaN  conj[uR]
# 29            NaN  conj[eR]
#
#                                                                                                                                                                                                  Properties  \
# 0                                                                                                 {'Coupling': '        g2', 'Group': ' SU[2]', 'SSB': '        g2', 'Index': ' left', 'Lorentz': 'Vector'}
# 1                                                                                                                                                                  {'Group': ' SU[2]', 'Lorentz': 'Scalar'}
# 2                                                                                                 {'Coupling': '       g3', 'Group': '  SU[3]', 'SSB': '       g3', 'Index': ' color', 'Lorentz': 'Vector'}
# 3                                                                                                                                                                 {'Group': '  SU[3]', 'Lorentz': 'Scalar'}
# 4                                                                                                       {'Coupling': ' g1', 'Group': '   U[1]', 'SSB': ' g1', 'Index': ' hypercharge', 'Lorentz': 'Vector'}
# 5                                                                                                                                                                 {'Group': '   U[1]', 'Lorentz': 'Scalar'}
# 6            {'multiplet': ['Hp', 'H0'], 'update_Description': {'Width': 0, 'OutputName': 'H', 'LaTeX': 'H', 'PDG': [0], 'Mass': 'Automatic'}, 'Groups': ['1/2', '2', '1'], 'NF': '1', 'Lorentz': 'Scalar'}
# 7                           {'ElectricCharge': 1, 'update_Description': {'Width': 0, 'LaTeX': 'H^+', 'PDG': [0], 'FeynArtsNr': 2, 'Mass': 'Automatic', 'OutputName': 'Hp'}, 'NF': '1', 'Lorentz': 'Scalar'}
# 8   {'ElectricCharge': 1, 'update_Description': {'Width': [0], 'LaTeX': ['H^+', 'H^-'], 'PDG': [0], 'Mass': [0], 'ElectricCharge': 1, 'OutputName': ['Hp', 'Hm'], 'PDG.IX': [0]}, 'NF': '1', 'Lorentz': ...
# 9                           {'ElectricCharge': 0, 'update_Description': {'Width': 0, 'LaTeX': 'H^0', 'PDG': [0], 'FeynArtsNr': 1, 'Mass': 'Automatic', 'OutputName': 'H0'}, 'NF': '1', 'Lorentz': 'Scalar'}
# 10                                                                  {'update_Description': {'PDG': [25], 'PDG.IX': [101000001]}, 'CP': 'Real', 'Coefficient': '1/Sqrt[2]', 'vev': 'v', 'Lorentz': 'Scalar'}
# 11                               {'update_Description': {'Width': [0], 'Mass': [0], 'PDG': [0], 'PDG.IX': [0]}, 'CP': 'Imaginary', 'Coefficient': '\[ImaginaryI]/Sqrt[2]', 'vev': 'v', 'Lorentz': 'Scalar'}
# 12                                                                      {'multiplet': ['uL', 'dL'], 'update_Description': {'LaTeX': 'q'}, 'Groups': ['1/6', '2', '3'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 13                                                                     {'multiplet': ['vL', 'eL'], 'update_Description': {'LaTeX': 'l'}, 'Groups': ['-1/2', '2', '1'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 14                                                                                                {'update_Description': {'LaTeX': 'd'}, 'Groups': ['1/3', '1', '-3'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 15                                                                                               {'update_Description': {'LaTeX': 'u'}, 'Groups': ['-2/3', '1', '-3'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 16                                                                                                   {'update_Description': {'LaTeX': 'e'}, 'Groups': ['1', '1', '1'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 17                                                                                                                            {'update_Description': {'LaTeX': 'u_L'}, 'NF': '3', 'Lorentz': 'WeylFermion'}
# 18                                                                                                                            {'update_Description': {'LaTeX': 'd_L'}, 'NF': '3', 'Lorentz': 'WeylFermion'}
# 19                                                                                                                          {'update_Description': {'LaTeX': '\nu_L'}, 'NF': '3', 'Lorentz': 'WeylFermion'}
# 20                                                                                                                            {'update_Description': {'LaTeX': 'e_L'}, 'NF': '3', 'Lorentz': 'WeylFermion'}
# 21                                                                                                                            {'update_Description': {'LaTeX': 'd_R'}, 'NF': '3', 'Lorentz': 'WeylFermion'}
# 22                                                                                                                            {'update_Description': {'LaTeX': 'u_R'}, 'NF': '3', 'Lorentz': 'WeylFermion'}
# 23                                                                                                                            {'update_Description': {'LaTeX': 'e_R'}, 'NF': '3', 'Lorentz': 'WeylFermion'}
# 24                                                                 {'update_Description': {'LaTeX': 'D_L'}, 'Chirality': 'left', 'Mass_basis': 'DL', 'Interaction_basis': ['dL'], 'Lorentz': 'WeylFermion'}
# 25                                                                 {'update_Description': {'LaTeX': 'U_L'}, 'Chirality': 'left', 'Mass_basis': 'UL', 'Interaction_basis': ['uL'], 'Lorentz': 'WeylFermion'}
# 26                                                                 {'update_Description': {'LaTeX': 'E_L'}, 'Chirality': 'left', 'Mass_basis': 'EL', 'Interaction_basis': ['eL'], 'Lorentz': 'WeylFermion'}
# 27                                                          {'update_Description': {'LaTeX': 'D_R'}, 'Chirality': 'right', 'Mass_basis': 'DR', 'Interaction_basis': ['conj[dR]'], 'Lorentz': 'WeylFermion'}
# 28                                                          {'update_Description': {'LaTeX': 'U_R'}, 'Chirality': 'right', 'Mass_basis': 'UR', 'Interaction_basis': ['conj[uR]'], 'Lorentz': 'WeylFermion'}
# 29                                                          {'update_Description': {'LaTeX': 'E_R'}, 'Chirality': 'right', 'Mass_basis': 'ER', 'Interaction_basis': ['conj[eR]'], 'Lorentz': 'WeylFermion'}
#
#    rotation
# 0       NaN
# 1      None
# 2       NaN
# 3      None
# 4       NaN
# 5      None
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24       Vd
# 25       Vu
# 26       Ve
# 27       Ud
# 28       Uu
# 29       Ue

# %%
pd.DataFrame( us.update_Scalar_Particles() )
# Out:
#   Block                  Definition          Description Field Parents  \
# 0   NaN  WeylFermionAndIndermediate                  NaN     H    None
# 1   NaN                     GaugeES                  NaN    Hp       H
# 2   NaN                        EWSB        Charged Higgs    Hp      Hp
# 3   NaN                     GaugeES                  NaN    H0       H
# 4  VEVs                        EWSB                Higgs    hh      H0
# 5  VEVs                        EWSB  Pseudo-Scalar Higgs    Ah      H0
#
#                                                                                                                                                                                                 Properties
# 0           {'multiplet': ['Hp', 'H0'], 'update_Description': {'Width': 0, 'OutputName': 'H', 'LaTeX': 'H', 'PDG': [0], 'Mass': 'Automatic'}, 'Groups': ['1/2', '2', '1'], 'NF': '1', 'Lorentz': 'Scalar'}
# 1                          {'ElectricCharge': 1, 'update_Description': {'Width': 0, 'LaTeX': 'H^+', 'PDG': [0], 'FeynArtsNr': 2, 'Mass': 'Automatic', 'OutputName': 'Hp'}, 'NF': '1', 'Lorentz': 'Scalar'}
# 2  {'ElectricCharge': 1, 'update_Description': {'Width': [0], 'LaTeX': ['H^+', 'H^-'], 'PDG': [0], 'Mass': [0], 'ElectricCharge': 1, 'OutputName': ['Hp', 'Hm'], 'PDG.IX': [0]}, 'NF': '1', 'Lorentz': ...
# 3                          {'ElectricCharge': 0, 'update_Description': {'Width': 0, 'LaTeX': 'H^0', 'PDG': [0], 'FeynArtsNr': 1, 'Mass': 'Automatic', 'OutputName': 'H0'}, 'NF': '1', 'Lorentz': 'Scalar'}
# 4                                                                  {'update_Description': {'PDG': [25], 'PDG.IX': [101000001]}, 'CP': 'Real', 'Coefficient': '1/Sqrt[2]', 'vev': 'v', 'Lorentz': 'Scalar'}
# 5                               {'update_Description': {'Width': [0], 'Mass': [0], 'PDG': [0], 'PDG.IX': [0]}, 'CP': 'Imaginary', 'Coefficient': '\[ImaginaryI]/Sqrt[2]', 'vev': 'v', 'Lorentz': 'Scalar'}

# %%
pd.DataFrame(us.update_WeylFermionAndIndermediate_WeylFermions())
# Out:
#           Block                  Definition Field   Parents  \
# 0           NaN  WeylFermionAndIndermediate     q      None
# 1           NaN  WeylFermionAndIndermediate     l      None
# 2           NaN  WeylFermionAndIndermediate     d      None
# 3           NaN  WeylFermionAndIndermediate     u      None
# 4           NaN  WeylFermionAndIndermediate     e      None
# 5           NaN  WeylFermionAndIndermediate    uL         q
# 6           NaN  WeylFermionAndIndermediate    dL         q
# 7           NaN  WeylFermionAndIndermediate    vL         l
# 8           NaN  WeylFermionAndIndermediate    eL         l
# 9           NaN  WeylFermionAndIndermediate    dR         d
# 10          NaN  WeylFermionAndIndermediate    uR         u
# 11          NaN  WeylFermionAndIndermediate    eR         e
# 12  MatterField  WeylFermionAndIndermediate    DL        dL
# 13  MatterField  WeylFermionAndIndermediate    UL        uL
# 14  MatterField  WeylFermionAndIndermediate    EL        eL
# 15  MatterField  WeylFermionAndIndermediate    DR  conj[dR]
# 16  MatterField  WeylFermionAndIndermediate    UR  conj[uR]
# 17  MatterField  WeylFermionAndIndermediate    ER  conj[eR]
#
#                                                                                                                                          Properties  \
# 0               {'NF': '3', 'multiplet': ['uL', 'dL'], 'update_Description': {'LaTeX': 'q'}, 'Groups': ['1/6', '2', '3'], 'Lorentz': 'WeylFermion'}
# 1              {'NF': '3', 'multiplet': ['vL', 'eL'], 'update_Description': {'LaTeX': 'l'}, 'Groups': ['-1/2', '2', '1'], 'Lorentz': 'WeylFermion'}
# 2                                         {'update_Description': {'LaTeX': 'd'}, 'Groups': ['1/3', '1', '-3'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 3                                        {'update_Description': {'LaTeX': 'u'}, 'Groups': ['-2/3', '1', '-3'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 4                                            {'update_Description': {'LaTeX': 'e'}, 'Groups': ['1', '1', '1'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 5                                                                     {'update_Description': {'LaTeX': 'u_L'}, 'NF': '3', 'Lorentz': 'WeylFermion'}
# 6                                                                     {'update_Description': {'LaTeX': 'd_L'}, 'NF': '3', 'Lorentz': 'WeylFermion'}
# 7                                                                   {'update_Description': {'LaTeX': '\nu_L'}, 'NF': '3', 'Lorentz': 'WeylFermion'}
# 8                                                                     {'update_Description': {'LaTeX': 'e_L'}, 'NF': '3', 'Lorentz': 'WeylFermion'}
# 9                                                                     {'update_Description': {'LaTeX': 'd_R'}, 'NF': '3', 'Lorentz': 'WeylFermion'}
# 10                                                                    {'update_Description': {'LaTeX': 'u_R'}, 'NF': '3', 'Lorentz': 'WeylFermion'}
# 11                                                                    {'update_Description': {'LaTeX': 'e_R'}, 'NF': '3', 'Lorentz': 'WeylFermion'}
# 12         {'Interaction_basis': ['dL'], 'Mass_basis': 'DL', 'Chirality': 'left', 'update_Description': {'LaTeX': 'D_L'}, 'Lorentz': 'WeylFermion'}
# 13         {'Interaction_basis': ['uL'], 'Mass_basis': 'UL', 'Chirality': 'left', 'update_Description': {'LaTeX': 'U_L'}, 'Lorentz': 'WeylFermion'}
# 14         {'Interaction_basis': ['eL'], 'Mass_basis': 'EL', 'Chirality': 'left', 'update_Description': {'LaTeX': 'E_L'}, 'Lorentz': 'WeylFermion'}
# 15  {'Interaction_basis': ['conj[dR]'], 'Mass_basis': 'DR', 'Chirality': 'right', 'update_Description': {'LaTeX': 'D_R'}, 'Lorentz': 'WeylFermion'}
# 16  {'Interaction_basis': ['conj[uR]'], 'Mass_basis': 'UR', 'Chirality': 'right', 'update_Description': {'LaTeX': 'U_R'}, 'Lorentz': 'WeylFermion'}
# 17  {'Interaction_basis': ['conj[eR]'], 'Mass_basis': 'ER', 'Chirality': 'right', 'update_Description': {'LaTeX': 'E_R'}, 'Lorentz': 'WeylFermion'}
#
#    rotation
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12       Vd
# 13       Vu
# 14       Ve
# 15       Ud
# 16       Uu
# 17       Ue

# %%
self=us

# %%
us.update_particles(get_4Spinor_Descriptions,Definition='EWSB',Lorentz='DiracSpinor',args=(self.modelparticles))
# Out:
# [{'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Description': 'Up-Quarks',
#   'Field': 'Fu',
#   'Parents': 'UL',
#   'Properties': {'DiracSpinor': ['UL', 'conj[UR]'], 'Lorentz': 'DiracSpinor'}},
#  {'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Description': 'Leptons',
#   'Field': 'Fe',
#   'Parents': 'EL',
#   'Properties': {'DiracSpinor': ['EL', 'conj[ER]'], 'Lorentz': 'DiracSpinor'}},
#  {'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Description': 'Down-Quarks',
#   'Field': 'Fd',
#   'Parents': 'DL',
#   'Properties': {'DiracSpinor': ['DL', 'conj[DR]'], 'Lorentz': 'DiracSpinor'}}]

# %%
us.update_particles(get_4Spinor_Descriptions,Definition='EWSB',Lorentz='MajoranaSpinor',args=(self.modelparticles))
# Out:
# [{'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Description': 'Neutrinos',
#   'Field': 'Fv',
#   'Parents': 'vL',
#   'Properties': {'Lorentz': 'MajoranaSpinor', 'MajoranaSpinor': ['vL', 0]}}]

# %%
if True:
    def update_particles(self,f,Definition='EWSB',Lorentz='DiracSpinor',args=()):
        DS=self.modelparticles.apply_filter(
                   lambda p: p.get('Definition')==Definition
                ).apply_filter(
                   lambda p: p.get('Properties').get('Lorentz').strip()==Lorentz)
        return DS.apply(f,args=args )

    def update_GaugeES_Vectors(self,
                di={'U[1]' :{'Description':'B-Boson' ,'Ghost':'B-Boson Ghost' },
                    'SU[2]':{'Description':'W-Bosons','Ghost':'W-Boson Ghost'},
                    'SU[3]':{'Description':'Gluon'   ,'Ghost':'Gluon Ghost'}}):
        prtn=self.modelparticles
        fprt=self.particles
        VB=Particles([])
        G=prtn.apply_filter(lambda p: p.get('Definition')=='GaugeES'
             ).apply_filter(lambda p: p.get('Properties').get('Lorentz').strip()=='Vector')

        for k in di.keys():
            kk1=G.apply_filter(lambda p: p.get('Properties').get('Group').strip()==k )
            if kk1.size()==1:
                kk1.update({'Description':di.get(k).get('Description')} )
                VB=VB+kk1
            kk2=fprt.apply_filter(lambda d: d.get('Description')==di.get(k).get('Ghost'))    
            if kk2.size()==1:
                VB=VB+kk2
        return VB

# %%
def get_gauge_vectors_descriptions(p,particles,di={'U[1]' :{'Description':'B-Boson' ,'Ghost':'B-Boson Ghost' },
                    'SU[2]':{'Description':'W-Bosons','Ghost':'W-Boson Ghost'},
                    'SU[3]':{'Description':'Gluon'   ,'Ghost':'Gluon Ghost'}}):
    gr=p.get('Properties').get('Group').strip()
    if di.get( gr  ):
        p['Description']=di.get(gr).get('Description')
    return p

def get_ghosts(p,particles,di={'U[1]' :{'Description':'B-Boson' ,'Ghost':'B-Boson Ghost' },
                    'SU[2]':{'Description':'W-Bosons','Ghost':'W-Boson Ghost'},
                    'SU[3]':{'Description':'Gluon'   ,'Ghost':'Gluon Ghost'}}):
    gr=p.get('Properties').get('Group').strip()
    if di.get( gr  ):
        p=particles.apply_filter(lambda d: d.get('Description')==di.get(gr).get('Ghost'))[0]
        return p
    else:
        return {}

# %%
us.update_particles(get_gauge_vectors_descriptions,
                    Definition='GaugeES',
                    Lorentz='Vector',
                    args=(self.modelparticles,
                     {'U[1]' :{'Description':'B-Boson' ,'Ghost':'B-Boson Ghost' },
                      'SU[2]':{'Description':'W-Bosons','Ghost':'W-Boson Ghost'},
                      'SU[3]':{'Description':'Gluon'   ,'Ghost':'Gluon Ghost'}}))
# Out:
# [{'Definition': 'GaugeES',
#   'Description': 'B-Boson',
#   'Field': 'VB',
#   'Parents': None,
#   'Properties': {'Coupling': ' g1',
#    'Group': '   U[1]',
#    'Index': ' hypercharge',
#    'Lorentz': 'Vector',
#    'SSB': ' g1'}},
#  {'Definition': 'GaugeES',
#   'Description': 'W-Bosons',
#   'Field': 'VWB',
#   'Parents': None,
#   'Properties': {'Coupling': '        g2',
#    'Group': ' SU[2]',
#    'Index': ' left',
#    'Lorentz': 'Vector',
#    'SSB': '        g2'}},
#  {'Definition': 'GaugeES',
#   'Description': 'Gluon',
#   'Field': 'VG',
#   'Parents': None,
#   'Properties': {'Coupling': '       g3',
#    'Group': '  SU[3]',
#    'Index': ' color',
#    'Lorentz': 'Vector',
#    'SSB': '       g3'}}]

# %%
us.update_particles(get_ghosts,
                    Definition='GaugeES',
                    Lorentz='Vector',
                    args=(self.particles,
                     {'U[1]' :{'Description':'B-Boson' ,'Ghost':'B-Boson Ghost' },
                      'SU[2]':{'Description':'W-Bosons','Ghost':'W-Boson Ghost'},
                      'SU[3]':{'Description':'Gluon'   ,'Ghost':'Gluon Ghost'}}))
# Out:
# [{'Block': None,
#   'Definition': 'GaugeES',
#   'Description': 'B-Boson Ghost',
#   'Field': 'gB',
#   'Name': 'B-Boson Ghost',
#   'Parents': 'VB',
#   'Properties': {'Group': '   U[1]', 'Lorentz': 'Scalar'},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'GaugeES',
#   'Description': 'W-Boson Ghost',
#   'Field': 'gWB',
#   'Name': 'W-Boson Ghost',
#   'Parents': 'VWB',
#   'Properties': {'Group': ' SU[2]', 'Lorentz': 'Scalar'},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'GaugeES',
#   'Description': 'Gluon Ghost',
#   'Field': 'gG',
#   'Name': 'Gluon Ghost',
#   'Parents': 'VG',
#   'Properties': {'Group': '  SU[3]', 'Lorentz': 'Scalar'},
#   'rotation': None}]

# %%
VB=self.update_particles??#(self,lambda p:p,Definition='GaugeES',Lorentz='Vector')
#VB.apply(get_gauge_vectors_descriptions,args=(self.modelparticles))
#type(VB)
# Out:
#   File "<ipython-input-445-29bf20c007c2>", line 1
#     VB=self.update_particles??#(self,lambda p:p,Definition='GaugeES',Lorentz='Vector')
#                             ^
# SyntaxError: invalid syntax

# %%
for p in DS:
    gprt=self.modelparticles.apply_filter( lambda d: d.get('Field')==p.get('Parents') )
    if gprt[0].get('rotation'):
        gprt=prt.apply_filter(lambda d: d.get('Field')==gprt[0].get('Parents'))
    cmpt=gprt[0].get('Field')
    gprt=prt.apply_filter(lambda d: d.get('Field')==gprt[0].get('Parents'))
    if get_abs_groups( gprt[0].get('Properties').get('Groups'), u1_abs='1/6',su2='2',su3_abs='3' ):
        if cmpt==gprt[0].get('Properties').get('multiplet')[0]:
            p['Description']='Up-Quarks'
        else:
            p['Description']='Down-Quarks'
    if get_abs_groups( gprt[0].get('Properties').get('Groups'), u1_abs='1/2',su2='2',su3_abs='1' ):
        if cmpt==gprt[0].get('Properties').get('multiplet')[0]:
            p['Description']='Neutrinos'
        else:
            p['Description']='Leptons'    
    break

# %%
g(1)
# Out:
# 2

# %%
args=(2,3)
def f(x,y,z):
    print(y)
g=lambda p: f(p,*args)
g(2)
# Out:
# 2

# %%
# Out:
# [{'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Description': 'Up-Quarks',
#   'Field': 'Fu',
#   'Parents': 'UL',
#   'Properties': {'DiracSpinor': ['UL', 'conj[UR]'], 'Lorentz': 'DiracSpinor'}},
#  {'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Description': 'Leptons',
#   'Field': 'Fe',
#   'Parents': 'EL',
#   'Properties': {'DiracSpinor': ['EL', 'conj[ER]'], 'Lorentz': 'DiracSpinor'}},
#  {'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Description': 'Down-Quarks',
#   'Field': 'Fd',
#   'Parents': 'DL',
#   'Properties': {'DiracSpinor': ['DL', 'conj[DR]'], 'Lorentz': 'DiracSpinor'}}]

# %%
update_particles?

# %%
Get_DiracSpinor_Description(p)#,self.modelparticles)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-378-9ae8bf70cda9> in <module>()
# ----> 1 Get_DiracSpinor_Description(p)#,self.modelparticles)
#
# TypeError: Get_DiracSpinor_Description() missing 1 required positional argument: 'particles'

# %%
update_EWSB_Fermion_Description??

# %%
    if p.get('Definition')=='EWSB' and p.get('Properties').get('Lorentz')=='DiracSpinor':
        p=update_EWSB_Fermion_Description(p,prtn)
        newparticles.append(p)
    if p.get('Definition')=='EWSB' and p.get('Properties').get('Lorentz')=='MajoranaSpinor':
        p=update_EWSB_Fermion_Description(p,prtn)
        newparticles.append(p)
        #break        
        #break
    if p.get('Definition')=='EWSB' and p.get('Properties').get('Lorentz')=='Vector':
        #if p.get('Field')=='VP':#'VP':#'VWp':#'VZ':
        #    break
        p=get_EWSB_gauge_bosons(p,prtn)
        newparticles.append(p)

# %%
#TODO: Make false when there are more scalar doublets
fprt=s.particles
Add_Charged_SM_Higgs_to_EWSB=True
newparticles=Particles([])
for i in prtn.Index():
    p=prtn[i]
    if p.get('Definition')=='GaugeES' and p.get('Properties').get('Lorentz').strip()=='Vector':
        if  p.get('Properties').get('Group').strip()=='U[1]':
            p['Description']='B-Boson'
            newparticles.append(p)
            #Obtain from fullparticlesnames
            newparticles.append({'Definition':'GaugeES','Field':'gB',
                               'Description':'B-Boson Ghost',
                               'Parents':p.get('Field'),'Properties':{
                               'Group':p.get('Properties').get('Group'),'Lorentz':'Scalar'}})
            #break
        elif p.get('Properties').get('Group').strip()=='SU[2]':
            p['Description']='W-Bosons'
            newparticles.append(p)
            newparticles.append({'Definition':'GaugeES','Field':'gWB',
                               'Description':'W-Boson Ghost',
                               'Parents':p.get('Field'),'Properties':{
                                'Group':p.get('Properties').get('Group'), 'Lorentz':'Scalar'}})        
            
        elif p.get('Properties').get('Group').strip()=='SU[3]':
            p['Description']='Gluon'
            newparticles.append(p)
            newparticles.append({'Definition':'GaugeES','Field':'gG',
                               'Description':'Gluon Ghost',
                               'Parents':p.get('Field'),'Properties':{
                               'Group':p.get('Properties').get('Group'),'Lorentz':'Scalar'}})
        #Search for daugthers
    if p.get('Definition')=='WeylFermionAndIndermediate' and p.get('Properties').get('Lorentz')=='Scalar':
        #Generic Doublet scalar: Include SM Higgs
        #re.search(r"\['-*1/2','2','1'",str(p.get('Properties').get('Groups')).replace(' ',''))
        if get_abs_groups(p.get('Properties').get('Groups'),u1_abs='1/2',su2='2',su3_abs='1'):
            p.get('Properties')['update_Description']={'PDG'       : [0],
                                                           'Width'     : 0,
                                                           'Mass'      : 'Automatic',
                                                           'LaTeX'     : p.get('Field'),
                                                           'OutputName': p.get('Field') }
            newparticles.append(p)
            #print(p)
            dprt=prtn.apply_filter(lambda d: d.get('Parents')==p.get('Field'))
            if len(dprt)==2:
                print('va',0)
                for j in dprt.Index():
                    dp=dprt[j]
                    #Higss components
                    charge=[]
                    if dp.get('Parents')=='H':
                        if p.get('Properties').get('Groups')[0].find('-')==-1:
                            charge=['Charged','Neutral']
                        else:
                            charge=['Neutral','Charged']
                        #print('va j',j,charge)
                            
                        if charge[j]=='Charged':
                            #Obtain from general dictionary: Charged Higgs NOT Physical
                            dp.get('Properties')['update_Description']={'PDG'  :[0],
                                    'Width':0,
                                    'Mass' : 'Automatic',
                                    'FeynArtsNr' : 2,
                                    'LaTeX' : 'H^+',
                                    'OutputName' : dp.get('Field')                            
                                   }
                            dp.get('Properties')['ElectricCharge']=1
                            newparticles.append(dp)
                            #TODO: Add EWSB charged scalar only if no more scalars
                            # with parent Hp
                            if Add_Charged_SM_Higgs_to_EWSB:
                                gdp={'Definition': 'EWSB',
                                     'Field': 'Hp',
                                     'Parents': 'Hp',
                                     'Description': 'Charged Higgs',
                                     'Properties': {'Lorentz': 'Scalar',
                                     'NF': '1',
                                     'ElectricCharge' : 1,
                                     'update_Description': fprt.apply_filter(
                                           lambda d: d.get('Description')=='Charged Higgs'
                                                  )[0].get('Properties'
                                                     ).get('update_Description')}}
                                
                                newparticles.append(gdp)                                
                        else: #Neutral
                            #Obtain from general dictionary: Complex Neutral Higgs
                            dp.get('Properties')['update_Description']={'PDG'  :[0], 
                                    'Width':0,
                                    'Mass' : 'Automatic',
                                    'FeynArtsNr' : 1,
                                    'LaTeX' : 'H^0',
                                    'OutputName' : dp.get('Field')                        
                                   }
                            dp.get('Properties')['ElectricCharge']=0                            
                            newparticles.append(dp)
                            #print('va H0',j)
                            
                            #TODO: Define object to capture two daugthers
                            gdprt=prtn.apply_filter(lambda d: d.get('Parents')==dp.get('Field'))
                            if len(gdprt)==2:
                                for k in gdprt.Index():
                                    gdp=gdprt[k]
                                    if gdp.get('Properties').get('CP')=='Real':
                                        gdp['Description']='Higgs'
                                        #Obtain from general dictionary: Higgs
                                        gdp.get('Properties')['update_Description']={
                                            'PDG'         : [25],
                                            'PDG.IX'      : [101000001]
                                        }
                                        newparticles.append(gdp)
                                    else: #'CP' → Imaginary 
                                        gdp['Description']='Pseudo-Scalar Higgs'
                                        #Obtain from general dictionary: Pseudo-Scalar Higgs
                                        gdp.get('Properties')['update_Description']={
                                            'PDG'         : [0],
                                            'PDG.IX'      : [0],
                                            'Mass'        : [0],
                                            'Width'       : [0]
                                        }
                                        newparticles.append(gdp)                                        
                                    #break
                        #break
            #break
            #Search for daughters: two complex fields
    if p.get('Definition')=='WeylFermionAndIndermediate' and p.get('Properties').get('Lorentz')=='WeylFermion':
        p.get('Properties')['update_Description']={'LaTeX' : get_weylfermion_LaTeX( p.get('Field') )}            
        newparticles.append(p)
    #For the following two an or could be used
    if p.get('Definition')=='EWSB' and p.get('Properties').get('Lorentz')=='DiracSpinor':
        p=update_EWSB_Fermion_Description(p,prtn)
        newparticles.append(p)
    if p.get('Definition')=='EWSB' and p.get('Properties').get('Lorentz')=='MajoranaSpinor':
        p=update_EWSB_Fermion_Description(p,prtn)
        newparticles.append(p)
        #break        
        #break
    if p.get('Definition')=='EWSB' and p.get('Properties').get('Lorentz')=='Vector':
        #if p.get('Field')=='VP':#'VP':#'VWp':#'VZ':
        #    break
        p=get_EWSB_gauge_bosons(p,prtn)
        newparticles.append(p)
        
    newparticles=Particles(newparticles)
# Out:
# va 0

# %%
pd.DataFrame(newparticles)
# Out:
#    Field   Parents  ...         Block rotation
# 0     VB      None  ...           NaN      NaN
# 1     gB        VB  ...           NaN      NaN
# 2    VWB      None  ...           NaN      NaN
# 3    gWB       VWB  ...           NaN      NaN
# 4     VG      None  ...           NaN      NaN
# 5     gG        VG  ...           NaN      NaN
# 6      q      None  ...           NaN      NaN
# 7      l      None  ...           NaN      NaN
# 8      d      None  ...           NaN      NaN
# 9      u      None  ...           NaN      NaN
# 10     e      None  ...           NaN      NaN
# 11     H      None  ...           NaN      NaN
# 12    Hp         H  ...           NaN      NaN
# 13    Hp        Hp  ...           NaN      NaN
# 14    H0         H  ...           NaN      NaN
# 15    hh        H0  ...          VEVs      NaN
# 16    Ah        H0  ...          VEVs      NaN
# 17    uL         q  ...           NaN      NaN
# 18    dL         q  ...           NaN      NaN
# 19    vL         l  ...           NaN      NaN
# 20    eL         l  ...           NaN      NaN
# 21    dR         d  ...           NaN      NaN
# 22    uR         u  ...           NaN      NaN
# 23    eR         e  ...           NaN      NaN
# 24    VP        VB  ...   GaugeSector       ZZ
# 25    VZ    VWB[3]  ...   GaugeSector       ZZ
# 26   VWp    VWB[1]  ...   GaugeSector       ZW
# 27    DL        dL  ...   MatterField       Vd
# 28    UL        uL  ...   MatterField       Vu
# 29    EL        eL  ...   MatterField       Ve
# 30    DR  conj[dR]  ...   MatterField       Ud
# 31    UR  conj[uR]  ...   MatterField       Uu
# 32    ER  conj[eR]  ...   MatterField       Ue
# 33    Fd        DL  ...  DiracSpinors      NaN
# 34    Fe        EL  ...  DiracSpinors      NaN
# 35    Fu        UL  ...  DiracSpinors      NaN
# 36    Fv        vL  ...  DiracSpinors      NaN
#
# [37 rows x 7 columns]
