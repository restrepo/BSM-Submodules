# %%
import pandas as pd
import json
import re
import numpy as np
import sys
from SARAH import *
pd.set_option('display.max_colwidth',200)

# %% [markdown]
# ##  Load particles

# %% [markdown]
# Generated with [./particles.ipynb](./particles.ipynb)

# %%
SM=pd.read_json('JSON/particles.json')

# %%
SM
# Out:
#                                                           WeylFermionAndIndermediate  \
# Ah                                                                               NaN
# DL                                                                  {'LaTeX': 'D_L'}
# DR                                                                  {'LaTeX': 'D_R'}
# EL                                                                  {'LaTeX': 'E_L'}
# ER                                                                  {'LaTeX': 'E_R'}
# Fd                                                                               NaN
# Fe                                                                               NaN
# Fu                                                                               NaN
# Fv                                                                               NaN
# H     {'Width': 0, 'Mass': 'Automatic', 'OutputName': 'H', 'PDG': [0], 'LaTeX': 'H'}
# H0                                                                               NaN
# Hp                                                                               NaN
# UL                                                                  {'LaTeX': 'U_L'}
# UR                                                                  {'LaTeX': 'U_R'}
# VB                                                                               NaN
# VG                                                                               NaN
# VP                                                                               NaN
# VWB                                                                              NaN
# VWp                                                                              NaN
# VZ                                                                               NaN
# dL                                                                  {'LaTeX': 'd_L'}
# dR                                                                  {'LaTeX': 'd_R'}
# eL                                                                  {'LaTeX': 'e_L'}
# eR                                                                  {'LaTeX': 'e_R'}
# gB                                                                               NaN
# gG                                                                               NaN
# gP                                                                               NaN
# gWB                                                                              NaN
# gWp                                                                              NaN
# gWpC                                                                             NaN
# gZ                                                                               NaN
# hh                                                                               NaN
# l                                                                     {'LaTeX': 'l'}
# q                                                                     {'LaTeX': 'q'}
# uL                                                                  {'LaTeX': 'u_L'}
# uR                                                                  {'LaTeX': 'u_R'}
# vL                                                               {'LaTeX': '\\nu_L'}
#
#                                                                                                  GaugeES  \
# Ah                                                                                                   NaN
# DL                                                                                                   NaN
# DR                                                                                                   NaN
# EL                                                                                                   NaN
# ER                                                                                                   NaN
# Fd                                                                                                   NaN
# Fe                                                                                                   NaN
# Fu                                                                                                   NaN
# Fv                                                                                                   NaN
# H                                                                                                    NaN
# H0    {'LaTeX': 'H^0', 'OutputName': 'H0', 'FeynArtsNr': 1, 'PDG': [0], 'Width': 0, 'Mass': 'Automatic'}
# Hp    {'LaTeX': 'H^+', 'OutputName': 'Hp', 'FeynArtsNr': 2, 'PDG': [0], 'Width': 0, 'Mass': 'Automatic'}
# UL                                                                                                   NaN
# UR                                                                                                   NaN
# VB                                                                            {'Description': 'B-Boson'}
# VG                                                                              {'Description': 'Gluon'}
# VP                                                                                                   NaN
# VWB                                                                          {'Description': 'W-Bosons'}
# VWp                                                                                                  NaN
# VZ                                                                                                   NaN
# dL                                                                                                   NaN
# dR                                                                                                   NaN
# eL                                                                                                   NaN
# eR                                                                                                   NaN
# gB                                                                      {'Description': 'B-Boson Ghost'}
# gG                                                                        {'Description': 'Gluon Ghost'}
# gP                                                                                                   NaN
# gWB                                                                     {'Description': 'W-Boson Ghost'}
# gWp                                                                                                  NaN
# gWpC                                                                                                 NaN
# gZ                                                                                                   NaN
# hh                                                                                                   NaN
# l                                                                                                    NaN
# q                                                                                                    NaN
# uL                                                                                                   NaN
# uR                                                                                                   NaN
# vL                                                                                                   NaN
#
#                                                                                                                                                                   EWSB
# Ah                                                                        {'PDG.IX': [0], 'Width': [0], 'Description': 'Pseudo-Scalar Higgs', 'Mass': [0], 'PDG': [0]}
# DL                                                                                                                                                                 NaN
# DR                                                                                                                                                                 NaN
# EL                                                                                                                                                                 NaN
# ER                                                                                                                                                                 NaN
# Fd                                                                                                                                      {'Description': 'Down-Quarks'}
# Fe                                                                                                                                          {'Description': 'Leptons'}
# Fu                                                                                                                                        {'Description': 'Up-Quarks'}
# Fv                                                                                                                                        {'Description': 'Neutrinos'}
# H                                                                                                                                                                  NaN
# H0                                                                                                                                                                 NaN
# Hp    {'LaTeX': ['H^+', 'H^-'], 'OutputName': ['Hp', 'Hm'], 'PDG': [0], 'ElectricCharge': 1, 'PDG.IX': [0], 'Width': [0], 'Description': 'Charged Higgs', 'Mass': [0]}
# UL                                                                                                                                                                 NaN
# UR                                                                                                                                                                 NaN
# VB                                                                                                                                                                 NaN
# VG                                                                                                                                            {'Description': 'Gluon'}
# VP                                                                                                                                           {'Description': 'Photon'}
# VWB                                                                                                                                                                NaN
# VWp                                                                                                                   {'Goldstone': 'Hp', 'Description': 'W+ - Boson'}
# VZ                                                                                                                       {'Goldstone': 'Ah', 'Description': 'Z-Boson'}
# dL                                                                                                                                                                 NaN
# dR                                                                                                                                                                 NaN
# eL                                                                                                                                                                 NaN
# eR                                                                                                                                                                 NaN
# gB                                                                                                                                                                 NaN
# gG                                                                                                                                      {'Description': 'Gluon Ghost'}
# gP                                                                                                                                     {'Description': 'Photon Ghost'}
# gWB                                                                                                                                                                NaN
# gWp                                                                                                                       {'Description': 'Positive W+ - Boson Ghost'}
# gWpC                                                                                                                      {'Description': 'Negative W+ - Boson Ghost'}
# gZ                                                                                                                                    {'Description': 'Z-Boson Ghost'}
# hh                                                                                                        {'PDG.IX': [101000001], 'Description': 'Higgs', 'PDG': [25]}
# l                                                                                                                                                                  NaN
# q                                                                                                                                                                  NaN
# uL                                                                                                                                                                 NaN
# uR                                                                                                                                                                 NaN
# vL                                                                                                                                                                 NaN

# %%
kk=to_math(SM,'p.m')

# %% [markdown]
# ## Load parameters

# %% [markdown]
# Generated with [parameters.ipynb](./parameters.ipynb)

# %%
SMp=pd.read_json('JSON/parameters.json')

# %%
kk=to_math(SM,'para.m',definitions='ParameterDefinitions')

# %%
SMp
# Out:
#                                                                                                                                                                     Properties
# AlphaS                                                                                                                                         {'Description': 'Alpha Strong'}
# Gf                                                                                                                                         {'Description': 'Fermi's constant'}
# ThetaW                                                                          {'Description': 'Weinberg-Angle', 'DependenceNum': 'ArcSin[Sqrt[1 - Mass[VWp]^2/Mass[VZ]^2]]'}
# Ud                                                                                                                                 {'Description': 'Right-Down-Mixing-Matrix'}
# Ue                                                                                                                               {'Description': 'Right-Lepton-Mixing-Matrix'}
# Uu                                                                                                                                   {'Description': 'Right-Up-Mixing-Matrix'}
# Vd                                                                                                                                  {'Description': 'Left-Down-Mixing-Matrix'}
# Ve                                                                                                                                {'Description': 'Left-Lepton-Mixing-Matrix'}
# Vu                                                                                                                                    {'Description': 'Left-Up-Mixing-Matrix'}
# Yd           {'Description': 'Down-Yukawa-Coupling', 'DependenceNum': 'Sqrt[2]/v* {{Mass[Fd,1],0,0 },
#                 {0, Mass[Fd,2],0},
#                 {0, 0, Mass[Fd,3]}}'}
# Ye         {'Description': 'Lepton-Yukawa-Coupling', 'DependenceNum': 'Sqrt[2]/v* {{Mass[Fe,1],0,0 },
#                 {0, Mass[Fe,2],0},
#                 {0, 0, Mass[Fe,3]}}'}
# Yu             {'Description': 'Up-Yukawa-Coupling', 'DependenceNum': 'Sqrt[2]/v* {{Mass[Fu,1],0,0 },
#                 {0, Mass[Fu,2],0},
#                 {0, 0, Mass[Fu,3]}}'}
# ZW                                        {'Description': 'W Mixing Matrix', 'Dependence': '1/Sqrt[2] {{1, 1},
#                               {\[ImaginaryI],-\[ImaginaryI]}}'}
# ZZ                                                                                                                                   {'Description': 'Photon-Z Mixing Matrix'}
# \[Lambda]                                                                                       {'Description': 'SM Higgs Selfcouplings', 'DependenceNum': 'Mass[hh]^2/(v^2)'}
# aEWinv                                                                                                                 {'Description': 'inverse weak coupling constant at mZ'}
# e                                                                                                                                           {'Description': 'electric charge'}
# g1                                                                                                                                     {'Description': 'Hypercharge-Coupling'}
# g2                                                                                                                                            {'Description': 'Left-Coupling'}
# g3                                                                                                                                          {'Description': 'Strong-Coupling'}
# mH2                                                                                                                                 {'Description': 'SM Higgs Mass Parameter'}
# mu2                                                                                                                   {'OutputName': 'm2SM', 'Description': 'SM Mu Parameter'}
# v                                                     {'OutputName': 'vvSM', 'DependenceSPheno': None, 'Description': 'EW-VEV', 'DependenceNum': 'Sqrt[4*Mass[VWp]^2/(g2^2)]'}

# %% [markdown]
# ## Load SPheno

# %% [markdown]
# Generated with [SPheno.ipynb](./SPheno.ipynb)

# %%
SP=pd.read_json('JSON/SPheno.json')
SP=SP.sort_values('Index')

# %%
to_SPheno(SP,'sp.m',dictentries=['DefaultInputValues'])

# %% [markdown]
# ## Design
# USAGE:
# 1. Load a `SARAH` Model File
# 2. Warns if a `particle` or `parameter` is not yet defined
# 3. Build missing `particles` or `parameters` and update predefined particles loaded in `__init__`
# 4. Export `SARAH` auxiliarly files:
#    * `particles.m`
#    * `parameters.m`
#    * `SPheno.m`

# %%
path="./SARAH/Models/"
re.search('\/$',path)
# Out:
# <_sre.SRE_Match object; span=(14, 15), match='/'>

# %%
import pandas as pd
import json
import re
from SARAH import *
#Move to SARAH
def get_EWSB(model,NAME='DEFINITION',KEY='EWSB'):
    dsbd=parse_mathematica_list_of_list(model,NAME='DEFINITION',KEY='EWSB')
    DEFINITION={}
    DEFINITION['EWSB']={}
    Bidiagonal=[]
    Diagonal=[]
    VEV=[]
    for k in dsbd.keys():

        for w in dsbd[k]:
            if k=='GaugeSector' or k=='MatterSector':
                if np.array(w).shape==(2,2):
                    weyl=bidiagonal(w,k)
                    Bidiagonal.append(weyl)
                elif np.array(w).shape==(3,):
                    symm=diagonal(w,k)
                    Diagonal.append(symm)
            elif k=='VEVs':
                VEV.append(get_vev(w,k))

    DEFINITION['EWSB']['Bidiagonal']=Bidiagonal
    DEFINITION['EWSB']['Diagonal']=Diagonal
    DEFINITION['EWSB']['VEVs']=VEV
    DEFINITION['EWSB']['DiracSpinors']=dsbd['DiracSpinors']
    return DEFINITION
#================
def _to_dict(df):
    return df.to_dict(orient='records')
class SARAH:
    def __init__(self,model='SM',
                      path="./SARAH/Models/",
                      particles ='JSON/fullparticlesnames.json',
                      parameters='JSON/fullparametersnames.json',
                      SPheno='JSON/fullSPhenonames.json'):
        '''
        LOAD predefined particles
        TODO: Include singlet scalar and other multiplets
        TODO: modify to_dict to default orient="records"
        '''
        self.particles=pd.read_json('JSON/fullparticlesnames.json')
        self.particles.index=self.particles['Name'].str.replace('-','_').str.replace('\s','_')
        self.particle = pd.Series()
        for n in self.particles.index:
            self.particle[n]=self.particles.loc[n]
        self.parameters = pd.read_json('JSON/fullparametersnames.json')
        self.parameters.index=self.parameters['Name'].str.replace('-','_').str.replace('\s','_')
        self.parameter = pd.Series()
        for n in self.parameters.index:
            self.parameter[n]=self.parameters.loc[n]
        self.SPheno={}
        self.Fields=['Gauge','FermionFields','ScalarFields']
        self.NAME='DEFINITION'
        self.KEY='EWSB'
        self.modelparticles=[]
        self.modelparameters=[]
        self.modelSPheno=[]
        #READ Model File
        if not re.search('\/$',path):
            path=path+'/'
        mfile='{}.m'.format(model.split('/')[-1])
        MODEL_PATH='{}{}/{}'.format(path,model,mfile)
        f=open(MODEL_PATH,'r')
        self.model_file=f.read()
        f.close()
        self.DEFINITION=get_EWSB(self.model_file,self.NAME,self.KEY)

        
    def parse_particle_content(self):
        '''1)
        Parse Particle Content section of SARAH Model File
        with the intial particles in the GaugeES basis
        '''
        newparticles=get_particles(self.model_file,Fields,self.NAME,self.KEY,[],[])
        self.modelparticles=self.modelparticles+newparticles
        return newparticles
    
    
    def parse_vevs_particles(self):
        '''3.a)
        '''
        newparticles=[]
        for d in self.DEFINITION[self.KEY]['VEVs']:
            particle=vev_to_particles(d,cp='Real')
            newparticles.append(particle)
            particle=vev_to_particles(d,cp='Imaginary')
            newparticles.append(particle)
            
        self.modelparticles=self.modelparticles+newparticles
        return newparticles
    def parse_diagonal_rotated_particles(self):
        '''3.b.I)
        '''
        np=rotations_to_particles(self.DEFINITION,
                                     self.KEY,
                                     lr='',
                                     sep='')
        self.modelparticles=self.modelparticles+np
        return np

    def parse_bidiagonal_rotated_particles(self):
        '''3.b.II) - 3.b.III)
        '''
        np=rotations_to_particles(self.DEFINITION,
                                        self.KEY,
                                        lr='left',
                                        sep='_')
        np=np+rotations_to_particles(self.DEFINITION,
                                        self.KEY,
                                        lr='right',
                                        sep='_')
        self.modelparticles=self.modelparticles+np
        return np

    def parse_DiracSpinors(self):
        '''3.c)
        '''
        newparticles=[]
        dict_of_spinors=self.DEFINITION['EWSB']['DiracSpinors']
        for f in dict_of_spinors.keys():
            particle=spinor_to_particles(dict_of_spinors,self.DEFINITION,f)
            newparticles.append(particle)
            
        self.modelparticles=self.modelparticles+newparticles
        return newparticles
    
    def parse_DEFINITION(self):
        '''3a..e)
        '''
        np=self.parse_vevs_particles()
        np=np+self.parse_diagonal_rotated_particles()
        np=np+self.parse_bidiagonal_rotated_particles()
        np=np+self.parse_DiracSpinors()        
        return np
    
    def parse_model(self):
        '''
        Generate particles, parameters and SPheno dictionary.
        A) There will be a basic class of particles which can be readed directly
        B) Later one inhereted class with SM particles
        C) May be one final class with BSM particles not automatically identified
        The SARAH file is organized in sections:
        1) First the Gauge, FermionFields and ScalarFields in the Gauge basis
        2) Next the Lagrangian (more relevant to extract parameters)
        3) Next load the dictionary DEFINITION
        3.a) VEVS definitions 
        3.b) Rotations 
        3.b.I)   Diagonal -> GaugeSector, MatterField
        3.b.II)  Bidiagonal left  -> MatterField
        3.b.III) Bidiagonal right -> MatterField
        3.c) Dirac Fermions
        '''
        #2)
        np=self.parse_particle_content()
        #3) a...c
        np=np+self.parse_DEFINITION()
        return np
        #Check missing particles
    def add_parameter(self,Name):
        # update predefined dataframes for particles, parameters and SPheno
        #reuturn series
        pass
    def to_particles(self,file='particles.m'):
        '''
        Generate particles.m
        '''
        pass
    def to_parameters(self,file='parameters.m'):
        '''
        Generate parameters.m
        '''
        pass
    def to_SPheno(self,file='SPheno.m'):
        '''
        Generate SPheno.m
        '''
        pass
    def to_all(self):
        self.to_particles()
        self.to_parameters()
        self.to_SPheno()
    def to_json(self):
        '''
        UPDATE JSON predefined dictionaries
        '''
        pass
#class

# %%
s=SARAH(model='SM')

# %%
s.model_file
# Out:
# 'Off[General::spell]\n\nModel`Name = "SM";\nModel`NameLaTeX ="Standard Model";\nModel`Authors = "F.Staub";\nModel`Date = "2014-11-06";\n\n(* 2013-01-24: changed normalization of lambda term to convention of hep-ph/0207271 *)\n(* 2013-06-24: using new name conventions (without inital "S" and "F" for scalar and matter fields) *)\n(* 2013-09-01: changing to new conventions for FermionFields/MatterFields *)\n(* 2014-11-06: Changed sign in Lagrangian to fit standard conventions *)\n(* 2016-05-03: Changed sign of Yu *)\n\n\n\n(*-------------------------------------------*)\n(*   Particle Content*)\n(*-------------------------------------------*)\n\n(* Gauge Groups *)\n\nGauge[[1]]={B,   U[1], hypercharge, g1,False};\nGauge[[2]]={WB, SU[2], left,        g2,True};\nGauge[[3]]={G,  SU[3], color,       g3,False};\n\n\n(* Matter Fields *)\n\nFermionFields[[1]] = {q, 3, {uL, dL},     1/6, 2,  3};  \nFermionFields[[2]] = {l, 3, {vL, eL},    -1/2, 2,  1};\nFermionFields[[3]] = {d, 3, conj[dR],     1/3, 1, -3};\nFermionFields[[4]] = {u, 3, conj[uR],    -2/3, 1, -3};\nFermionFields[[5]] = {e, 3, conj[eR],       1, 1,  1};\n\nScalarFields[[1]] =  {H, 1, {Hp, H0},     1/2, 2,  1};\n\n\n        \n(*----------------------------------------------*)\n(*   DEFINITION                                 *)\n(*----------------------------------------------*)\n\nNameOfStates={GaugeES, EWSB};\n\n(* ----- Before EWSB ----- *)\n\nDEFINITION[GaugeES][LagrangianInput]= {\n\t{LagHC, {AddHC->True}},\n\t{LagNoHC,{AddHC->False}}\n};\n\n\nLagNoHC = -mu2 conj[H].H - 1/2 \\[Lambda] conj[H].H.conj[H].H;\nLagHC =  -(Yd conj[H].d.q + Ye conj[H].e.l + Yu u.q.H);\n\n\n\t\t\t  \t\t  \n\n(* Gauge Sector *)\n\nDEFINITION[EWSB][GaugeSector] =\n{ \n  {{VB,VWB[3]},{VP,VZ},ZZ},\n  {{VWB[1],VWB[2]},{VWp,conj[VWp]},ZW}\n};     \n        \n        \n          \t\n\n(* ----- VEVs ---- *)\n\nDEFINITION[EWSB][VEVs]= \n{    {H0, {v, 1/Sqrt[2]}, {Ah, \\[ImaginaryI]/Sqrt[2]},{hh, 1/Sqrt[2]}}     };\n \n\nDEFINITION[EWSB][MatterSector]=   \n    {{{{dL}, {conj[dR]}}, {{DL,Vd}, {DR,Ud}}},\n     {{{uL}, {conj[uR]}}, {{UL,Vu}, {UR,Uu}}},\n     {{{eL}, {conj[eR]}}, {{EL,Ve}, {ER,Ue}}}};  \n\n\n(*------------------------------------------------------*)\n(* Dirac-Spinors *)\n(*------------------------------------------------------*)\n\nDEFINITION[EWSB][DiracSpinors]={\n Fd ->{  DL, conj[DR]},\n Fe ->{  EL, conj[ER]},\n Fu ->{  UL, conj[UR]},\n Fv ->{  vL, 0}};\n\nDEFINITION[EWSB][GaugeES]={\n Fd1 ->{  FdL, 0},\n Fd2 ->{  0, FdR},\n Fu1 ->{  Fu1, 0},\n Fu2 ->{  0, Fu2},\n Fe1 ->{  Fe1, 0},\n Fe2 ->{  0, Fe2}};\n\n\n\n'

# %% [markdown]
# 1.a

# %% [markdown]
# Read raw particles in fully symmetric phase and interaction basis

# %%
newparticles=s.parse_particle_content()
pd.DataFrame(newparticles)
# Out:
# ('B,   U[1], hypercharge, g1,False',) Gauge 5
# {'Definition': 'GaugeES', 'Properties': {'Coupling': ' g1', 'Index': ' hypercharge', 'SSB': ' g1', 'Group': '   U[1]', 'Lorentz': 'Vector'}, 'Field': 'VB', 'Parents': None}
# ('WB, SU[2], left,        g2,True',) Gauge 5
# {'Definition': 'GaugeES', 'Properties': {'Coupling': '        g2', 'Index': ' left', 'SSB': '        g2', 'Group': ' SU[2]', 'Lorentz': 'Vector'}, 'Field': 'VWB', 'Parents': None}
# ('G,  SU[3], color,       g3,False',) Gauge 5
# {'Definition': 'GaugeES', 'Properties': {'Coupling': '       g3', 'Index': ' color', 'SSB': '       g3', 'Group': '  SU[3]', 'Lorentz': 'Vector'}, 'Field': 'VG', 'Parents': None}
# ('q, 3, uL:: dL,     1/6, 2,  3;  ',) FermionFields 6
# **********
#  uL:: dL [' uL', ' dL']
#  uL
#  dL
# **********
# ('l, 3, vL:: eL,    -1/2, 2,  1;',) FermionFields 6
# **********
#  vL:: eL [' vL', ' eL']
#  vL
#  eL
# **********
# ('d, 3, conj[dR],     1/3, 1, -3',) FermionFields 6
# **********
#  conj[dR] [' dR']
#  dR
# **********
# ('u, 3, conj[uR],    -2/3, 1, -3',) FermionFields 6
# **********
#  conj[uR] [' uR']
#  uR
# **********
# ('e, 3, conj[eR],       1, 1,  1',) FermionFields 6
# **********
#  conj[eR] [' eR']
#  eR
# **********
# ('H, 1, Hp:: H0,     1/2, 2,  1;',) ScalarFields 6
# **********
#  Hp:: H0 [' Hp', ' H0']
#  Hp
#  H0
# **********
#                     Definition Field Parents  \
# 0                      GaugeES    VB    None
# 1                      GaugeES   VWB    None
# 2                      GaugeES    VG    None
# 3   WeylFermionAndIndermediate     q    None
# 4   WeylFermionAndIndermediate     l    None
# 5   WeylFermionAndIndermediate     d    None
# 6   WeylFermionAndIndermediate     u    None
# 7   WeylFermionAndIndermediate     e    None
# 8   WeylFermionAndIndermediate     H    None
# 9   WeylFermionAndIndermediate    uL       q
# 10  WeylFermionAndIndermediate    dL       q
# 11  WeylFermionAndIndermediate    vL       l
# 12  WeylFermionAndIndermediate    eL       l
# 13  WeylFermionAndIndermediate    dR       d
# 14  WeylFermionAndIndermediate    uR       u
# 15  WeylFermionAndIndermediate    eR       e
# 16                     GaugeES    Hp       H
# 17                     GaugeES    H0       H
#
#                                                                                                    Properties
# 0         {'Coupling': ' g1', 'Index': ' hypercharge', 'SSB': ' g1', 'Group': '   U[1]', 'Lorentz': 'Vector'}
# 1   {'Coupling': '        g2', 'Index': ' left', 'SSB': '        g2', 'Group': ' SU[2]', 'Lorentz': 'Vector'}
# 2   {'Coupling': '       g3', 'Index': ' color', 'SSB': '       g3', 'Group': '  SU[3]', 'Lorentz': 'Vector'}
# 3               {'multiplet': ['uL', 'dL'], 'Groups': ['1/6', '2', '3'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 4              {'multiplet': ['vL', 'eL'], 'Groups': ['-1/2', '2', '1'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 5                                         {'Groups': ['1/3', '1', '-3'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 6                                        {'Groups': ['-2/3', '1', '-3'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 7                                            {'Groups': ['1', '1', '1'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 8                    {'multiplet': ['Hp', 'H0'], 'Groups': ['1/2', '2', '1'], 'NF': '1', 'Lorentz': 'Scalar'}
# 9                                                                       {'Lorentz': 'WeylFermion', 'NF': '3'}
# 10                                                                      {'Lorentz': 'WeylFermion', 'NF': '3'}
# 11                                                                      {'Lorentz': 'WeylFermion', 'NF': '3'}
# 12                                                                      {'Lorentz': 'WeylFermion', 'NF': '3'}
# 13                                                                      {'Lorentz': 'WeylFermion', 'NF': '3'}
# 14                                                                      {'Lorentz': 'WeylFermion', 'NF': '3'}
# 15                                                                      {'Lorentz': 'WeylFermion', 'NF': '3'}
# 16                                                                           {'Lorentz': 'Scalar', 'NF': '1'}
# 17                                                                           {'Lorentz': 'Scalar', 'NF': '1'}

# %%
pd.DataFrame(s.parse_vevs_particles())
# Out:
#   Block Definition Field Parents  \
# 0  VEVs       EWSB    hh      H0
# 1  VEVs       EWSB    Ah      H0
#
#                                                                                      Properties
# 0                   {'vev': 'v', 'Lorentz': 'Scalar', 'CP': 'Real', 'Coefficient': '1/Sqrt[2]'}
# 1  {'vev': 'v', 'Lorentz': 'Scalar', 'CP': 'Imaginary', 'Coefficient': '\[ImaginaryI]/Sqrt[2]'}

# %%
pd.DataFrame(s.parse_diagonal_rotated_particles())
# Out:
#          Block Definition Field Parents  \
# 0  GaugeSector       EWSB    VP      VB
# 1  GaugeSector       EWSB    VZ  VWB[3]
# 2  GaugeSector       EWSB   VWp  VWB[1]
#
#                                                                                              Properties  \
# 0              {'Lorentz': 'Vector', 'Interaction_basis': ['VB', 'VWB[3]'], 'Mass_basis': ['VP', 'VZ']}
# 1              {'Lorentz': 'Vector', 'Interaction_basis': ['VB', 'VWB[3]'], 'Mass_basis': ['VP', 'VZ']}
# 2  {'Lorentz': 'Vector', 'Interaction_basis': ['VWB[1]', 'VWB[2]'], 'Mass_basis': ['VWp', 'conj[VWp]']}
#
#   rotation
# 0       ZZ
# 1       ZZ
# 2       ZW

# %%
pd.DataFrame(s.parse_bidiagonal_rotated_particles())
# Out:
#          Block                  Definition Field   Parents  \
# 0  MatterField  WeylFermionAndIndermediate    DL        dL
# 1  MatterField  WeylFermionAndIndermediate    UL        uL
# 2  MatterField  WeylFermionAndIndermediate    EL        eL
# 3  MatterField  WeylFermionAndIndermediate    DR  conj[dR]
# 4  MatterField  WeylFermionAndIndermediate    UR  conj[uR]
# 5  MatterField  WeylFermionAndIndermediate    ER  conj[eR]
#
#                                                                                                 Properties  \
# 0         {'Lorentz': 'WeylFermion', 'Interaction_basis': ['dL'], 'Mass_basis': 'DL', 'Chirality': 'left'}
# 1         {'Lorentz': 'WeylFermion', 'Interaction_basis': ['uL'], 'Mass_basis': 'UL', 'Chirality': 'left'}
# 2         {'Lorentz': 'WeylFermion', 'Interaction_basis': ['eL'], 'Mass_basis': 'EL', 'Chirality': 'left'}
# 3  {'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[dR]'], 'Mass_basis': 'DR', 'Chirality': 'right'}
# 4  {'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[uR]'], 'Mass_basis': 'UR', 'Chirality': 'right'}
# 5  {'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[eR]'], 'Mass_basis': 'ER', 'Chirality': 'right'}
#
#   rotation
# 0       Vd
# 1       Vu
# 2       Ve
# 3       Ud
# 4       Uu
# 5       Ue

# %%
pd.DataFrame(s.parse_DiracSpinors())
# Out:
#           Block Definition Field Parents  \
# 0  DiracSpinors       EWSB    Fd      DL
# 1  DiracSpinors       EWSB    Fu      UL
# 2  DiracSpinors       EWSB    Fv      vL
# 3  DiracSpinors       EWSB    Fe      EL
#
#                                                       Properties
# 0  {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['DL', 'conj[DR]']}
# 1  {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['UL', 'conj[UR]']}
# 2     {'Lorentz': 'MajoranaSpinor', 'MajoranaSpinor': ['vL', 0]}
# 3  {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['EL', 'conj[ER]']}

# %%
s=SARAH(model='SM')
np=s.parse_model()
# Out:
# ('B,   U[1], hypercharge, g1,False',) Gauge 5
# {'Definition': 'GaugeES', 'Properties': {'Coupling': ' g1', 'Index': ' hypercharge', 'SSB': ' g1', 'Group': '   U[1]', 'Lorentz': 'Vector'}, 'Field': 'VB', 'Parents': None}
# ('WB, SU[2], left,        g2,True',) Gauge 5
# {'Definition': 'GaugeES', 'Properties': {'Coupling': '        g2', 'Index': ' left', 'SSB': '        g2', 'Group': ' SU[2]', 'Lorentz': 'Vector'}, 'Field': 'VWB', 'Parents': None}
# ('G,  SU[3], color,       g3,False',) Gauge 5
# {'Definition': 'GaugeES', 'Properties': {'Coupling': '       g3', 'Index': ' color', 'SSB': '       g3', 'Group': '  SU[3]', 'Lorentz': 'Vector'}, 'Field': 'VG', 'Parents': None}
# ('q, 3, uL:: dL,     1/6, 2,  3;  ',) FermionFields 6
# **********
#  uL:: dL [' uL', ' dL']
#  uL
#  dL
# **********
# ('l, 3, vL:: eL,    -1/2, 2,  1;',) FermionFields 6
# **********
#  vL:: eL [' vL', ' eL']
#  vL
#  eL
# **********
# ('d, 3, conj[dR],     1/3, 1, -3',) FermionFields 6
# **********
#  conj[dR] [' dR']
#  dR
# **********
# ('u, 3, conj[uR],    -2/3, 1, -3',) FermionFields 6
# **********
#  conj[uR] [' uR']
#  uR
# **********
# ('e, 3, conj[eR],       1, 1,  1',) FermionFields 6
# **********
#  conj[eR] [' eR']
#  eR
# **********
# ('H, 1, Hp:: H0,     1/2, 2,  1;',) ScalarFields 6
# **********
#  Hp:: H0 [' Hp', ' H0']
#  Hp
#  H0
# **********

# %%
pd.DataFrame(s.modelparticles)
# Out:
#            Block                  Definition Field   Parents  \
# 0            NaN                     GaugeES    VB      None
# 1            NaN                     GaugeES   VWB      None
# 2            NaN                     GaugeES    VG      None
# 3            NaN  WeylFermionAndIndermediate     q      None
# 4            NaN  WeylFermionAndIndermediate     l      None
# 5            NaN  WeylFermionAndIndermediate     d      None
# 6            NaN  WeylFermionAndIndermediate     u      None
# 7            NaN  WeylFermionAndIndermediate     e      None
# 8            NaN  WeylFermionAndIndermediate     H      None
# 9            NaN  WeylFermionAndIndermediate    uL         q
# 10           NaN  WeylFermionAndIndermediate    dL         q
# 11           NaN  WeylFermionAndIndermediate    vL         l
# 12           NaN  WeylFermionAndIndermediate    eL         l
# 13           NaN  WeylFermionAndIndermediate    dR         d
# 14           NaN  WeylFermionAndIndermediate    uR         u
# 15           NaN  WeylFermionAndIndermediate    eR         e
# 16           NaN                     GaugeES    Hp         H
# 17           NaN                     GaugeES    H0         H
# 18          VEVs                        EWSB    hh        H0
# 19          VEVs                        EWSB    Ah        H0
# 20   GaugeSector                        EWSB    VP        VB
# 21   GaugeSector                        EWSB    VZ    VWB[3]
# 22   GaugeSector                        EWSB   VWp    VWB[1]
# 23   MatterField  WeylFermionAndIndermediate    DL        dL
# 24   MatterField  WeylFermionAndIndermediate    UL        uL
# 25   MatterField  WeylFermionAndIndermediate    EL        eL
# 26   MatterField  WeylFermionAndIndermediate    DR  conj[dR]
# 27   MatterField  WeylFermionAndIndermediate    UR  conj[uR]
# 28   MatterField  WeylFermionAndIndermediate    ER  conj[eR]
# 29  DiracSpinors                        EWSB    Fd        DL
# 30  DiracSpinors                        EWSB    Fu        UL
# 31  DiracSpinors                        EWSB    Fv        vL
# 32  DiracSpinors                        EWSB    Fe        EL
#
#                                                                                                    Properties  \
# 0         {'Coupling': ' g1', 'Index': ' hypercharge', 'SSB': ' g1', 'Group': '   U[1]', 'Lorentz': 'Vector'}
# 1   {'Coupling': '        g2', 'Index': ' left', 'SSB': '        g2', 'Group': ' SU[2]', 'Lorentz': 'Vector'}
# 2   {'Coupling': '       g3', 'Index': ' color', 'SSB': '       g3', 'Group': '  SU[3]', 'Lorentz': 'Vector'}
# 3               {'multiplet': ['uL', 'dL'], 'Groups': ['1/6', '2', '3'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 4              {'multiplet': ['vL', 'eL'], 'Groups': ['-1/2', '2', '1'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 5                                         {'Groups': ['1/3', '1', '-3'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 6                                        {'Groups': ['-2/3', '1', '-3'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 7                                            {'Groups': ['1', '1', '1'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 8                    {'multiplet': ['Hp', 'H0'], 'Groups': ['1/2', '2', '1'], 'NF': '1', 'Lorentz': 'Scalar'}
# 9                                                                       {'Lorentz': 'WeylFermion', 'NF': '3'}
# 10                                                                      {'Lorentz': 'WeylFermion', 'NF': '3'}
# 11                                                                      {'Lorentz': 'WeylFermion', 'NF': '3'}
# 12                                                                      {'Lorentz': 'WeylFermion', 'NF': '3'}
# 13                                                                      {'Lorentz': 'WeylFermion', 'NF': '3'}
# 14                                                                      {'Lorentz': 'WeylFermion', 'NF': '3'}
# 15                                                                      {'Lorentz': 'WeylFermion', 'NF': '3'}
# 16                                                                           {'Lorentz': 'Scalar', 'NF': '1'}
# 17                                                                           {'Lorentz': 'Scalar', 'NF': '1'}
# 18                                {'vev': 'v', 'Lorentz': 'Scalar', 'CP': 'Real', 'Coefficient': '1/Sqrt[2]'}
# 19               {'vev': 'v', 'Lorentz': 'Scalar', 'CP': 'Imaginary', 'Coefficient': '\[ImaginaryI]/Sqrt[2]'}
# 20                   {'Lorentz': 'Vector', 'Interaction_basis': ['VB', 'VWB[3]'], 'Mass_basis': ['VP', 'VZ']}
# 21                   {'Lorentz': 'Vector', 'Interaction_basis': ['VB', 'VWB[3]'], 'Mass_basis': ['VP', 'VZ']}
# 22       {'Lorentz': 'Vector', 'Interaction_basis': ['VWB[1]', 'VWB[2]'], 'Mass_basis': ['VWp', 'conj[VWp]']}
# 23           {'Lorentz': 'WeylFermion', 'Interaction_basis': ['dL'], 'Mass_basis': 'DL', 'Chirality': 'left'}
# 24           {'Lorentz': 'WeylFermion', 'Interaction_basis': ['uL'], 'Mass_basis': 'UL', 'Chirality': 'left'}
# 25           {'Lorentz': 'WeylFermion', 'Interaction_basis': ['eL'], 'Mass_basis': 'EL', 'Chirality': 'left'}
# 26    {'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[dR]'], 'Mass_basis': 'DR', 'Chirality': 'right'}
# 27    {'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[uR]'], 'Mass_basis': 'UR', 'Chirality': 'right'}
# 28    {'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[eR]'], 'Mass_basis': 'ER', 'Chirality': 'right'}
# 29                                              {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['DL', 'conj[DR]']}
# 30                                              {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['UL', 'conj[UR]']}
# 31                                                 {'Lorentz': 'MajoranaSpinor', 'MajoranaSpinor': ['vL', 0]}
# 32                                              {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['EL', 'conj[ER]']}
#
#    rotation
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20       ZZ
# 21       ZZ
# 22       ZW
# 23       Vd
# 24       Vu
# 25       Ve
# 26       Ud
# 27       Uu
# 28       Ue
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN

# %%
s.particles
# Out:
#                                           Block                  Definition  \
# Name
# B_Boson                                    None                     GaugeES
# B_Boson_Ghost                              None                     GaugeES
# W_Bosons                                   None                     GaugeES
# W_Boson_Ghost                              None                     GaugeES
# Gluon                                      None                     GaugeES
# Gluon_Ghost                                None                     GaugeES
# Quark_Doublets                             None  WeylFermionAndIndermediate
# Quark_Leptons                              None  WeylFermionAndIndermediate
# Anti_Quarks_Down_Right_Simplified          None  WeylFermionAndIndermediate
# Anti_Quarks_Up_Right_Simplified            None  WeylFermionAndIndermediate
# Anti_Leptons_Right_Simplified              None  WeylFermionAndIndermediate
# Higgs_Doublet                              None  WeylFermionAndIndermediate
# Charged_Higgs_Not_Physical                 None                     GaugeES
# Charged_Higgs                              None                        EWSB
# Complex_Neutral_Higgs                      None                     GaugeES
# Higgs                                      VEVs                        EWSB
# Pseudo_Scalar_Higgs                        VEVs                        EWSB
# Quarks_Up_Left                             None  WeylFermionAndIndermediate
# Quarks_Down_Left                           None  WeylFermionAndIndermediate
# Neutrinos_Left                             None  WeylFermionAndIndermediate
# Leptons_Left                               None  WeylFermionAndIndermediate
# Anti_Quarks_Down_Right                     None  WeylFermionAndIndermediate
# Anti_Quarks_Up_Right                       None  WeylFermionAndIndermediate
# Anti_Leptons_Right                         None  WeylFermionAndIndermediate
# Quarks_Down_Left_Physical           MatterField  WeylFermionAndIndermediate
# Quarks_Up_Left_Physical             MatterField  WeylFermionAndIndermediate
# Leptons_Left_Physical               MatterField  WeylFermionAndIndermediate
# Anti_Quarks_Down_Right_Physical     MatterField  WeylFermionAndIndermediate
# Anti_Quarks_Up_Right_Physical       MatterField  WeylFermionAndIndermediate
# Anti_Leptons_Right_Physical         MatterField  WeylFermionAndIndermediate
# Up_Quarks                          DiracSpinors                        EWSB
# Down_Quarks                        DiracSpinors                        EWSB
# Leptons                            DiracSpinors                        EWSB
# Neutrinos                          DiracSpinors                        EWSB
#
#                                            Description Field  \
# Name
# B_Boson                                        B-Boson    VB
# B_Boson_Ghost                            B-Boson Ghost    gB
# W_Bosons                                      W-Bosons   VWB
# W_Boson_Ghost                            W-Boson Ghost   gWB
# Gluon                                            Gluon    VG
# Gluon_Ghost                                Gluon Ghost    gG
# Quark_Doublets                                    None     q
# Quark_Leptons                                     None     l
# Anti_Quarks_Down_Right_Simplified                 None     d
# Anti_Quarks_Up_Right_Simplified                   None     u
# Anti_Leptons_Right_Simplified                     None     e
# Higgs_Doublet                                     None     H
# Charged_Higgs_Not_Physical                        None    Hp
# Charged_Higgs                            Charged Higgs    Hp
# Complex_Neutral_Higgs                             None    H0
# Higgs                                            Higgs    hh
# Pseudo_Scalar_Higgs                Pseudo-Scalar Higgs    Ah
# Quarks_Up_Left                                    None    uL
# Quarks_Down_Left                                  None    dL
# Neutrinos_Left                                    None    vL
# Leptons_Left                                      None    eL
# Anti_Quarks_Down_Right                            None    dR
# Anti_Quarks_Up_Right                              None    uR
# Anti_Leptons_Right                                None    eR
# Quarks_Down_Left_Physical                         None    DL
# Quarks_Up_Left_Physical                           None    UL
# Leptons_Left_Physical                             None    EL
# Anti_Quarks_Down_Right_Physical                   None    DR
# Anti_Quarks_Up_Right_Physical                     None    UR
# Anti_Leptons_Right_Physical                       None    ER
# Up_Quarks                                    Up-Quarks    Fu
# Down_Quarks                                Down-Quarks    Fd
# Leptons                                        Leptons    Fe
# Neutrinos                                    Neutrinos    Fv
#
#                                                                 Name  \
# Name
# B_Boson                                                      B-Boson
# B_Boson_Ghost                                          B-Boson Ghost
# W_Bosons                                                    W-Bosons
# W_Boson_Ghost                                          W-Boson Ghost
# Gluon                                                          Gluon
# Gluon_Ghost                                              Gluon Ghost
# Quark_Doublets                                        Quark Doublets
# Quark_Leptons                                          Quark Leptons
# Anti_Quarks_Down_Right_Simplified  Anti-Quarks-Down Right Simplified
# Anti_Quarks_Up_Right_Simplified      Anti-Quarks-Up Right Simplified
# Anti_Leptons_Right_Simplified          Anti-Leptons Right Simplified
# Higgs_Doublet                                          Higgs Doublet
# Charged_Higgs_Not_Physical                Charged Higgs Not Physical
# Charged_Higgs                                          Charged Higgs
# Complex_Neutral_Higgs                          Complex Neutral Higgs
# Higgs                                                          Higgs
# Pseudo_Scalar_Higgs                              Pseudo-Scalar Higgs
# Quarks_Up_Left                                        Quarks-Up Left
# Quarks_Down_Left                                    Quarks-Down Left
# Neutrinos_Left                                        Neutrinos Left
# Leptons_Left                                            Leptons Left
# Anti_Quarks_Down_Right                        Anti-Quarks-Down Right
# Anti_Quarks_Up_Right                            Anti-Quarks-Up Right
# Anti_Leptons_Right                                Anti-Leptons Right
# Quarks_Down_Left_Physical                  Quarks-Down Left Physical
# Quarks_Up_Left_Physical                      Quarks-Up Left Physical
# Leptons_Left_Physical                          Leptons Left Physical
# Anti_Quarks_Down_Right_Physical      Anti-Quarks-Down Right Physical
# Anti_Quarks_Up_Right_Physical          Anti-Quarks-Up Right Physical
# Anti_Leptons_Right_Physical              Anti-Leptons Right Physical
# Up_Quarks                                                  Up-Quarks
# Down_Quarks                                              Down-Quarks
# Leptons                                                      Leptons
# Neutrinos                                                  Neutrinos
#
#                                     Parents  \
# Name
# B_Boson                                None
# B_Boson_Ghost                            VB
# W_Bosons                               None
# W_Boson_Ghost                           VWB
# Gluon                                  None
# Gluon_Ghost                              VG
# Quark_Doublets                         None
# Quark_Leptons                          None
# Anti_Quarks_Down_Right_Simplified      None
# Anti_Quarks_Up_Right_Simplified        None
# Anti_Leptons_Right_Simplified          None
# Higgs_Doublet                          None
# Charged_Higgs_Not_Physical                H
# Charged_Higgs                            Hp
# Complex_Neutral_Higgs                     H
# Higgs                                    H0
# Pseudo_Scalar_Higgs                      H0
# Quarks_Up_Left                            q
# Quarks_Down_Left                          q
# Neutrinos_Left                            l
# Leptons_Left                              l
# Anti_Quarks_Down_Right                    d
# Anti_Quarks_Up_Right                      u
# Anti_Leptons_Right                        e
# Quarks_Down_Left_Physical                dL
# Quarks_Up_Left_Physical                  uL
# Leptons_Left_Physical                    eL
# Anti_Quarks_Down_Right_Physical    conj[dR]
# Anti_Quarks_Up_Right_Physical      conj[uR]
# Anti_Leptons_Right_Physical        conj[eR]
# Up_Quarks                                UL
# Down_Quarks                              DL
# Leptons                                  EL
# Neutrinos                                vL
#
#                                                                                                                                                                                                                        Properties  \
# Name
# B_Boson                                                                                                                       {'Coupling': ' g1', 'Index': ' hypercharge', 'SSB': ' g1', 'Group': '   U[1]', 'Lorentz': 'Vector'}
# B_Boson_Ghost                                                                                                                                                                           {'Lorentz': 'Scalar', 'Group': '   U[1]'}
# W_Bosons                                                                                                                {'Coupling': '        g2', 'Index': ' left', 'SSB': '        g2', 'Group': ' SU[2]', 'Lorentz': 'Vector'}
# W_Boson_Ghost                                                                                                                                                                            {'Lorentz': 'Scalar', 'Group': ' SU[2]'}
# Gluon                                                                                                                   {'Coupling': '       g3', 'Index': ' color', 'SSB': '       g3', 'Group': '  SU[3]', 'Lorentz': 'Vector'}
# Gluon_Ghost                                                                                                                                                                             {'Lorentz': 'Scalar', 'Group': '  SU[3]'}
# Quark_Doublets                                                                                {'multiplet': ['uL', 'dL'], 'Groups': ['1/6', '2', '3'], 'NF': '3', 'update_Description': {'LaTeX': 'q'}, 'Lorentz': 'WeylFermion'}
# Quark_Leptons                                                                                {'multiplet': ['vL', 'eL'], 'Groups': ['-1/2', '2', '1'], 'NF': '3', 'update_Description': {'LaTeX': 'l'}, 'Lorentz': 'WeylFermion'}
# Anti_Quarks_Down_Right_Simplified                                                                                       {'Groups': ['1/3', '1', '-3'], 'NF': '3', 'update_Description': {'LaTeX': 'd'}, 'Lorentz': 'WeylFermion'}
# Anti_Quarks_Up_Right_Simplified                                                                                        {'Groups': ['-2/3', '1', '-3'], 'NF': '3', 'update_Description': {'LaTeX': 'u'}, 'Lorentz': 'WeylFermion'}
# Anti_Leptons_Right_Simplified                                                                                              {'Groups': ['1', '1', '1'], 'NF': '3', 'update_Description': {'LaTeX': 'e'}, 'Lorentz': 'WeylFermion'}
# Higgs_Doublet                      {'multiplet': ['Hp', 'H0'], 'Groups': ['1/2', '2', '1'], 'NF': '1', 'update_Description': {'OutputName': 'H', 'PDG': [0], 'LaTeX': 'H', 'Width': 0, 'Mass': 'Automatic'}, 'Lorentz': 'Scalar'}
# Charged_Higgs_Not_Physical                                             {'Lorentz': 'Scalar', 'NF': '1', 'update_Description': {'PDG': [0], 'OutputName': 'Hp', 'FeynArtsNr': 2, 'LaTeX': 'H^+', 'Width': 0, 'Mass': 'Automatic'}}
# Charged_Higgs                            {'Lorentz': 'Scalar', 'NF': '1', 'update_Description': {'PDG': [0], 'OutputName': ['Hp', 'Hm'], 'ElectricCharge': 1, 'LaTeX': ['H^+', 'H^-'], 'Width': [0], 'Mass': [0], 'PDG.IX': [0]}}
# Complex_Neutral_Higgs                                                  {'Lorentz': 'Scalar', 'NF': '1', 'update_Description': {'PDG': [0], 'OutputName': 'H0', 'FeynArtsNr': 1, 'LaTeX': 'H^0', 'Width': 0, 'Mass': 'Automatic'}}
# Higgs                                                                                     {'Coefficient': '1/Sqrt[2]', 'Lorentz': 'Scalar', 'CP': 'Real', 'update_Description': {'PDG': [25], 'PDG.IX': [101000001]}, 'vev': 'v'}
# Pseudo_Scalar_Higgs                                    {'Coefficient': '\[ImaginaryI]/Sqrt[2]', 'Lorentz': 'Scalar', 'CP': 'Imaginary', 'update_Description': {'PDG': [0], 'Width': [0], 'Mass': [0], 'PDG.IX': [0]}, 'vev': 'v'}
# Quarks_Up_Left                                                                                                                                      {'Lorentz': 'WeylFermion', 'NF': '3', 'update_Description': {'LaTeX': 'u_L'}}
# Quarks_Down_Left                                                                                                                                    {'Lorentz': 'WeylFermion', 'NF': '3', 'update_Description': {'LaTeX': 'd_L'}}
# Neutrinos_Left                                                                                                                                    {'Lorentz': 'WeylFermion', 'NF': '3', 'update_Description': {'LaTeX': '\nu_L'}}
# Leptons_Left                                                                                                                                        {'Lorentz': 'WeylFermion', 'NF': '3', 'update_Description': {'LaTeX': 'e_L'}}
# Anti_Quarks_Down_Right                                                                                                                              {'Lorentz': 'WeylFermion', 'NF': '3', 'update_Description': {'LaTeX': 'd_R'}}
# Anti_Quarks_Up_Right                                                                                                                                {'Lorentz': 'WeylFermion', 'NF': '3', 'update_Description': {'LaTeX': 'u_R'}}
# Anti_Leptons_Right                                                                                                                                  {'Lorentz': 'WeylFermion', 'NF': '3', 'update_Description': {'LaTeX': 'e_R'}}
# Quarks_Down_Left_Physical                                                                {'update_Description': {'LaTeX': 'D_L'}, 'Lorentz': 'WeylFermion', 'Interaction_basis': ['dL'], 'Mass_basis': 'DL', 'Chirality': 'left'}
# Quarks_Up_Left_Physical                                                                  {'update_Description': {'LaTeX': 'U_L'}, 'Lorentz': 'WeylFermion', 'Interaction_basis': ['uL'], 'Mass_basis': 'UL', 'Chirality': 'left'}
# Leptons_Left_Physical                                                                    {'update_Description': {'LaTeX': 'E_L'}, 'Lorentz': 'WeylFermion', 'Interaction_basis': ['eL'], 'Mass_basis': 'EL', 'Chirality': 'left'}
# Anti_Quarks_Down_Right_Physical                                                   {'update_Description': {'LaTeX': 'D_R'}, 'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[dR]'], 'Mass_basis': 'DR', 'Chirality': 'right'}
# Anti_Quarks_Up_Right_Physical                                                     {'update_Description': {'LaTeX': 'U_R'}, 'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[uR]'], 'Mass_basis': 'UR', 'Chirality': 'right'}
# Anti_Leptons_Right_Physical                                                       {'update_Description': {'LaTeX': 'E_R'}, 'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[eR]'], 'Mass_basis': 'ER', 'Chirality': 'right'}
# Up_Quarks                                                                                                                                                           {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['UL', 'conj[UR]']}
# Down_Quarks                                                                                                                                                         {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['DL', 'conj[DR]']}
# Leptons                                                                                                                                                             {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['EL', 'conj[ER]']}
# Neutrinos                                                                                                                                                              {'Lorentz': 'MajoranaSpinor', 'MajoranaSpinor': ['vL', 0]}
#
#                                   rotation
# Name
# B_Boson                               None
# B_Boson_Ghost                         None
# W_Bosons                              None
# W_Boson_Ghost                         None
# Gluon                                 None
# Gluon_Ghost                           None
# Quark_Doublets                        None
# Quark_Leptons                         None
# Anti_Quarks_Down_Right_Simplified     None
# Anti_Quarks_Up_Right_Simplified       None
# Anti_Leptons_Right_Simplified         None
# Higgs_Doublet                         None
# Charged_Higgs_Not_Physical            None
# Charged_Higgs                         None
# Complex_Neutral_Higgs                 None
# Higgs                                 None
# Pseudo_Scalar_Higgs                   None
# Quarks_Up_Left                        None
# Quarks_Down_Left                      None
# Neutrinos_Left                        None
# Leptons_Left                          None
# Anti_Quarks_Down_Right                None
# Anti_Quarks_Up_Right                  None
# Anti_Leptons_Right                    None
# Quarks_Down_Left_Physical               Vd
# Quarks_Up_Left_Physical                 Vu
# Leptons_Left_Physical                   Ve
# Anti_Quarks_Down_Right_Physical         Ud
# Anti_Quarks_Up_Right_Physical           Uu
# Anti_Leptons_Right_Physical             Ue
# Up_Quarks                             None
# Down_Quarks                           None
# Leptons                               None
# Neutrinos                             None

# %%
s.parameters
# Out:
#                                            Class  \
# Name
# Down_Yukawa_Coupling                  Lagrangian
# Lepton_Yukawa_Coupling                Lagrangian
# SM_Mu_Parameter                       Lagrangian
# EW_VEV                                Lagrangian
# SM_Higgs_Selfcouplings                Lagrangian
# Weinberg_Angle                        Lagrangian
# Up_Yukawa_Coupling                    Lagrangian
# Right_Up_Mixing_Matrix                  Rotation
# Left_Lepton_Mixing_Matrix               Rotation
# Right_Lepton_Mixing_Matrix              Rotation
# W_Mixing_Matrix                         Rotation
# Photon_Z_Mixing_Matrix                  Rotation
# Left_Down_Mixing_Matrix                 Rotation
# Left_Up_Mixing_Matrix                   Rotation
# Right_Down_Mixing_Matrix                Rotation
# Strong_Coupling                         Coupling
# Left_Coupling                           Coupling
# Hypercharge_Coupling                    Coupling
# Fermi's_constant                        Constant
# Alpha_Strong                            Constant
# inverse_weak_coupling_constant_at_mZ    Constant
# SM_Higgs_Mass_Parameter                 Constant
# electric_charge                         Constant
#
#                                                                Description  \
# Name
# Down_Yukawa_Coupling                                  Down-Yukawa-Coupling
# Lepton_Yukawa_Coupling                              Lepton-Yukawa-Coupling
# SM_Mu_Parameter                                            SM Mu Parameter
# EW_VEV                                                              EW-VEV
# SM_Higgs_Selfcouplings                              SM Higgs Selfcouplings
# Weinberg_Angle                                              Weinberg-Angle
# Up_Yukawa_Coupling                                      Up-Yukawa-Coupling
# Right_Up_Mixing_Matrix                              Right-Up-Mixing-Matrix
# Left_Lepton_Mixing_Matrix                        Left-Lepton-Mixing-Matrix
# Right_Lepton_Mixing_Matrix                      Right-Lepton-Mixing-Matrix
# W_Mixing_Matrix                                            W Mixing Matrix
# Photon_Z_Mixing_Matrix                              Photon-Z Mixing Matrix
# Left_Down_Mixing_Matrix                            Left-Down-Mixing-Matrix
# Left_Up_Mixing_Matrix                                Left-Up-Mixing-Matrix
# Right_Down_Mixing_Matrix                          Right-Down-Mixing-Matrix
# Strong_Coupling                                            Strong-Coupling
# Left_Coupling                                                Left-Coupling
# Hypercharge_Coupling                                  Hypercharge-Coupling
# Fermi's_constant                                          Fermi's constant
# Alpha_Strong                                                  Alpha Strong
# inverse_weak_coupling_constant_at_mZ  inverse weak coupling constant at mZ
# SM_Higgs_Mass_Parameter                            SM Higgs Mass Parameter
# electric_charge                                            electric charge
#
#                                                                       Name  \
# Name
# Down_Yukawa_Coupling                                  Down-Yukawa-Coupling
# Lepton_Yukawa_Coupling                              Lepton-Yukawa-Coupling
# SM_Mu_Parameter                                            SM Mu Parameter
# EW_VEV                                                              EW-VEV
# SM_Higgs_Selfcouplings                              SM Higgs Selfcouplings
# Weinberg_Angle                                              Weinberg-Angle
# Up_Yukawa_Coupling                                      Up-Yukawa-Coupling
# Right_Up_Mixing_Matrix                              Right-Up-Mixing-Matrix
# Left_Lepton_Mixing_Matrix                        Left-Lepton-Mixing-Matrix
# Right_Lepton_Mixing_Matrix                      Right-Lepton-Mixing-Matrix
# W_Mixing_Matrix                                            W Mixing Matrix
# Photon_Z_Mixing_Matrix                              Photon-Z Mixing Matrix
# Left_Down_Mixing_Matrix                            Left-Down-Mixing-Matrix
# Left_Up_Mixing_Matrix                                Left-Up-Mixing-Matrix
# Right_Down_Mixing_Matrix                          Right-Down-Mixing-Matrix
# Strong_Coupling                                            Strong-Coupling
# Left_Coupling                                                Left-Coupling
# Hypercharge_Coupling                                  Hypercharge-Coupling
# Fermi's_constant                                          Fermi's constant
# Alpha_Strong                                                  Alpha Strong
# inverse_weak_coupling_constant_at_mZ  inverse weak coupling constant at mZ
# SM_Higgs_Mass_Parameter                            SM Higgs Mass Parameter
# electric_charge                                            electric charge
#
#                                                                              Properties  \
# Name
# Down_Yukawa_Coupling                  {'Coupling': 'Yd', 'fields': ['H', 'd', 'q'], ...
# Lepton_Yukawa_Coupling                {'Coupling': 'Ye', 'fields': ['H', 'e', 'l'], ...
# SM_Mu_Parameter                       {'Coupling': 'mu2', 'fields': ['H', 'H'], 'Hig...
# EW_VEV                                {'Coupling': 'v', 'update_Description': {'Outp...
# SM_Higgs_Selfcouplings                {'Coupling': '\[Lambda]', 'fields': ['H', 'H',...
# Weinberg_Angle                        {'Coupling': 'ThetaW', 'update_Description': {...
# Up_Yukawa_Coupling                    {'Coupling': 'Yu', 'fields': ['u', 'q', 'H'], ...
# Right_Up_Mixing_Matrix                                                               {}
# Left_Lepton_Mixing_Matrix                                                            {}
# Right_Lepton_Mixing_Matrix                                                           {}
# W_Mixing_Matrix                       {'update_Description': {'Dependence': '1/Sqrt[...
# Photon_Z_Mixing_Matrix                                                               {}
# Left_Down_Mixing_Matrix                                                              {}
# Left_Up_Mixing_Matrix                                                                {}
# Right_Down_Mixing_Matrix                                                             {}
# Strong_Coupling                                                                      {}
# Left_Coupling                                                                        {}
# Hypercharge_Coupling                                                                 {}
# Fermi's_constant                                                                     {}
# Alpha_Strong                                                                         {}
# inverse_weak_coupling_constant_at_mZ                                                 {}
# SM_Higgs_Mass_Parameter                                                              {}
# electric_charge                                                                      {}
#
#                                          Symbol
# Name
# Down_Yukawa_Coupling                         Yd
# Lepton_Yukawa_Coupling                       Ye
# SM_Mu_Parameter                             mu2
# EW_VEV                                        v
# SM_Higgs_Selfcouplings                \[Lambda]
# Weinberg_Angle                           ThetaW
# Up_Yukawa_Coupling                           Yu
# Right_Up_Mixing_Matrix                       Uu
# Left_Lepton_Mixing_Matrix                    Ve
# Right_Lepton_Mixing_Matrix                   Ue
# W_Mixing_Matrix                              ZW
# Photon_Z_Mixing_Matrix                       ZZ
# Left_Down_Mixing_Matrix                      Vd
# Left_Up_Mixing_Matrix                        Vu
# Right_Down_Mixing_Matrix                     Ud
# Strong_Coupling                              g3
# Left_Coupling                                g2
# Hypercharge_Coupling                         g1
# Fermi's_constant                             Gf
# Alpha_Strong                             AlphaS
# inverse_weak_coupling_constant_at_mZ     aEWinv
# SM_Higgs_Mass_Parameter                     mH2
# electric_charge                               e

# %%
s.particle.Anti_Leptons_Right
# Out:
# Block                                                       None
# Definition                            WeylFermionAndIndermediate
# Description                                                 None
# Field                                                         eR
# Name                                          Anti-Leptons Right
# Parents                                                        e
# Properties     {'Lorentz': 'WeylFermion', 'NF': '3', 'update_...
# rotation                                                    None
# Name: Anti_Leptons_Right, dtype: object

# %%
s.parameter.Alpha_Strong
# Out:
# Class              Constant
# Description    Alpha Strong
# Name           Alpha Strong
# Properties               {}
# Symbol               AlphaS
# Name: Alpha_Strong, dtype: object

# %%
s.to_all()

# %%
print(s.model_file)
# Out:
# Off[General::spell]
#
# Model`Name = "SM";
# Model`NameLaTeX ="Standard Model";
# Model`Authors = "F.Staub";
# Model`Date = "2014-11-06";
#
# (* 2013-01-24: changed normalization of lambda term to convention of hep-ph/0207271 *)
# (* 2013-06-24: using new name conventions (without inital "S" and "F" for scalar and matter fields) *)
# (* 2013-09-01: changing to new conventions for FermionFields/MatterFields *)
# (* 2014-11-06: Changed sign in Lagrangian to fit standard conventions *)
# (* 2016-05-03: Changed sign of Yu *)
#
#
#
# (*-------------------------------------------*)
# (*   Particle Content*)
# (*-------------------------------------------*)
#
# (* Gauge Groups *)
#
# Gauge[[1]]={B,   U[1], hypercharge, g1,False};
# Gauge[[2]]={WB, SU[2], left,        g2,True};
# Gauge[[3]]={G,  SU[3], color,       g3,False};
#
#
# (* Matter Fields *)
#
# FermionFields[[1]] = {q, 3, {uL, dL},     1/6, 2,  3};
# FermionFields[[2]] = {l, 3, {vL, eL},    -1/2, 2,  1};
# FermionFields[[3]] = {d, 3, conj[dR],     1/3, 1, -3};
# FermionFields[[4]] = {u, 3, conj[uR],    -2/3, 1, -3};
# FermionFields[[5]] = {e, 3, conj[eR],       1, 1,  1};
#
# ScalarFields[[1]] =  {H, 1, {Hp, H0},     1/2, 2,  1};
#
#
#
# (*----------------------------------------------*)
# (*   DEFINITION                                 *)
# (*----------------------------------------------*)
#
# NameOfStates={GaugeES, EWSB};
#
# (* ----- Before EWSB ----- *)
#
# DEFINITION[GaugeES][LagrangianInput]= {
# 	{LagHC, {AddHC->True}},
# 	{LagNoHC,{AddHC->False}}
# };
#
#
# LagNoHC = -mu2 conj[H].H - 1/2 \[Lambda] conj[H].H.conj[H].H;
# LagHC =  -(Yd conj[H].d.q + Ye conj[H].e.l + Yu u.q.H);
#
#
#
#
# (* Gauge Sector *)
#
# DEFINITION[EWSB][GaugeSector] =
# {
#   {{VB,VWB[3]},{VP,VZ},ZZ},
#   {{VWB[1],VWB[2]},{VWp,conj[VWp]},ZW}
# };
#
#
#
#
# (* ----- VEVs ---- *)
#
# DEFINITION[EWSB][VEVs]=
# {    {H0, {v, 1/Sqrt[2]}, {Ah, \[ImaginaryI]/Sqrt[2]},{hh, 1/Sqrt[2]}}     };
#
#
# DEFINITION[EWSB][MatterSector]=
#     {{{{dL}, {conj[dR]}}, {{DL,Vd}, {DR,Ud}}},
#      {{{uL}, {conj[uR]}}, {{UL,Vu}, {UR,Uu}}},
#      {{{eL}, {conj[eR]}}, {{EL,Ve}, {ER,Ue}}}};
#
#
# (*------------------------------------------------------*)
# (* Dirac-Spinors *)
# (*------------------------------------------------------*)
#
# DEFINITION[EWSB][DiracSpinors]={
#  Fd ->{  DL, conj[DR]},
#  Fe ->{  EL, conj[ER]},
#  Fu ->{  UL, conj[UR]},
#  Fv ->{  vL, 0}};
#
# DEFINITION[EWSB][GaugeES]={
#  Fd1 ->{  FdL, 0},
#  Fd2 ->{  0, FdR},
#  Fu1 ->{  Fu1, 0},
#  Fu2 ->{  0, Fu2},
#  Fe1 ->{  Fe1, 0},
#  Fe2 ->{  0, Fe2}};
