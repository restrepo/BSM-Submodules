# %% [markdown]
# <a href="https://colab.research.google.com/github/restrepo/BSM-Submodules/blob/master/particles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Particles generator

# %% [markdown]
# ## Dictionary design for JSON output

# %% [markdown]
# The SM will be defined as pandas file in JSON format.
# In this file it will be shown the definition of such a file from a dictionary

# %%
#TODO: Initialize objects
particles=[]
particlessons=[]

Fields=['Gauge','FermionFields','ScalarFields']
NAME='DEFINITION'
KEY='EWSB'
# Get also particles from
#NAME[KEY] dictionary!

# %%
import pandas as pd
import numpy as np
import json
# import re, cmdlike as cmd, OrdereDict, json
from SARAH import *
pd.set_option('display.max_colwidth',200)

# %%
cat kk.json | cut -c1-80
# Out:
# {"EWSB":{"Ah":{"Mass":[0],"PDG.IX":[0],"PDG":[0],"Description":"Pseudo-Scalar Hi

# %% [markdown]
# Build SM as dictionary to feed pandas

# %%
#Matter fields
# LaTeX backslash as \\\\
str_keys=['LaTeX','OutputName','Description']
lst_keys=['PDG','PDG.IX']
ParticleDefinitions={'GaugeES':
                             {'H0':{'PDG'  :[0],
                                    'Width':0,
                                    'Mass' : 'Automatic',
                                    'FeynArtsNr' : 1,
                                    'LaTeX' : 'H^0',
                                    'OutputName' : 'H0'                                   
                                   },
                              'Hp':{'PDG'  :[0],
                                    'Width':0,
                                    'Mass' : 'Automatic',
                                    'FeynArtsNr' : 2,
                                    'LaTeX' : 'H^+',
                                    'OutputName' : 'Hp'                                   
                                   },
                              'VB' : {'Description' :'B-Boson'      },                                                   
                              'VG' : {'Description' :'Gluon'        },          
                              'VWB': {'Description' :'W-Bosons'     },          
                              'gB' : {'Description' :'B-Boson Ghost'},                                                   
                              'gG' : {'Description' :'Gluon Ghost'  },          
                              'gWB': {'Description' :'W-Boson Ghost'}
                             },
                            'EWSB':
                            {                                
                            },
                            'WeylFermionAndIndermediate':
                            {   
                            }
                           }

ParticleDefinitions['EWSB']['hh']={'Description' : 'Higgs',
                                   'PDG'         : [25],
                                   'PDG.IX'      : [101000001]}
ParticleDefinitions['EWSB']['Ah']={'Description' : "Pseudo-Scalar Higgs",
                                   'PDG'         : [0],
                                   'PDG.IX'      : [0],
                                   'Mass'        : [0],
                                   'Width'       : [0]
                                   }
ParticleDefinitions['EWSB']['Hp']={'Description'    : 'Charged Higgs', 
                                   'PDG'            : [0],
                                   'PDG.IX'         : [0],
                                   'Width'          : [0], 
                                   'Mass'           : [0],
                                   'LaTeX'          : ['H^+','H^-' ],
                                   'OutputName'     : ['Hp' ,'Hm'  ],
                                   'ElectricCharge' : 1
                                   }

ParticleDefinitions['EWSB']['VP']  =  { 'Description' : 'Photon'}
ParticleDefinitions['EWSB']['VZ']  =  { 'Description' : 'Z-Boson',
                                        'Goldstone' : 'Ah' }
ParticleDefinitions['EWSB']['VG']  =  { 'Description' : 'Gluon' }
ParticleDefinitions['EWSB']['VWp'] =  { 'Description' : 'W+ - Boson',
                                        'Goldstone': 'Hp' }
ParticleDefinitions['EWSB']['gP']  =  { 'Description' : 'Photon Ghost'}
ParticleDefinitions['EWSB']['gWp'] =  { 'Description' : 'Positive W+ - Boson Ghost'}
ParticleDefinitions['EWSB']['gWpC']=  { 'Description' : 'Negative W+ - Boson Ghost' }
ParticleDefinitions['EWSB']['gZ']  =  { 'Description' : 'Z-Boson Ghost' }
ParticleDefinitions['EWSB']['gG']  =  { 'Description' : 'Gluon Ghost' }
ParticleDefinitions['EWSB']['Fd']  =  { 'Description' : 'Down-Quarks'}
ParticleDefinitions['EWSB']['Fu']  =  { 'Description' : 'Up-Quarks'}
ParticleDefinitions['EWSB']['Fe']  =  { 'Description' : 'Leptons' }
ParticleDefinitions['EWSB']['Fv']  =  { 'Description' : 'Neutrinos' }

ParticleDefinitions['WeylFermionAndIndermediate']['H' ] = {'PDG'       : [0],
                                                           'Width'     : 0,
                                                           'Mass'      : 'Automatic',
                                                           'LaTeX'     : 'H',
                                                           'OutputName': 'H' }
ParticleDefinitions['WeylFermionAndIndermediate']['dR'] = {'LaTeX' : 'd_R'   }
ParticleDefinitions['WeylFermionAndIndermediate']['eR'] = {'LaTeX' : 'e_R'   }
ParticleDefinitions['WeylFermionAndIndermediate']['l' ] = {'LaTeX' : 'l'     }
ParticleDefinitions['WeylFermionAndIndermediate']['uR'] = {'LaTeX' : 'u_R'   }
ParticleDefinitions['WeylFermionAndIndermediate']['q' ] = {'LaTeX' : 'q'     }
ParticleDefinitions['WeylFermionAndIndermediate']['eL'] = {'LaTeX' : 'e_L'   }
ParticleDefinitions['WeylFermionAndIndermediate']['dL'] = {'LaTeX' : 'd_L'   }
ParticleDefinitions['WeylFermionAndIndermediate']['uL'] = {'LaTeX' : 'u_L'   }
ParticleDefinitions['WeylFermionAndIndermediate']['vL'] = {'LaTeX' : '\\\\nu_L'}
ParticleDefinitions['WeylFermionAndIndermediate']['DR'] = {'LaTeX' : 'D_R'   }
ParticleDefinitions['WeylFermionAndIndermediate']['ER'] = {'LaTeX' : 'E_R'   }
ParticleDefinitions['WeylFermionAndIndermediate']['UR'] = {'LaTeX' : 'U_R'   }
ParticleDefinitions['WeylFermionAndIndermediate']['EL'] = {'LaTeX' : 'E_L'   }
ParticleDefinitions['WeylFermionAndIndermediate']['DL'] = {'LaTeX' : 'D_L'   }
ParticleDefinitions['WeylFermionAndIndermediate']['UL'] = {'LaTeX' : 'U_L'   }

# %% [markdown]
# Example to modify dictionary entry

# %%
ParticleDefinitions['GaugeES']['H0']['FeynArtsNr']=1

# %% [markdown]
# ## Save as JSON

# %%
f=open('JSON/particles.json','w')
json.dump(ParticleDefinitions,f)
f.close()

# %% [markdown]
# Check if `pandas` can read it

# %%
pd.read_json('JSON/particles.json').loc['Hp']['EWSB']
# Out:
# {'Description': 'Charged Higgs',
#  'ElectricCharge': 1,
#  'LaTeX': ['H^+', 'H^-'],
#  'Mass': [0],
#  'OutputName': ['Hp', 'Hm'],
#  'PDG': [0],
#  'PDG.IX': [0],
#  'Width': [0]}

# %% [markdown]
# ## Feed a `pandas` `DataFrame`

# %%
SM=pd.DataFrame( ParticleDefinitions  )

# %%
SM
# Out:
#                                                                                                                                                                   EWSB  \
# Ah                                                                        {'Width': [0], 'PDG.IX': [0], 'PDG': [0], 'Mass': [0], 'Description': 'Pseudo-Scalar Higgs'}
# DL                                                                                                                                                                 NaN
# DR                                                                                                                                                                 NaN
# EL                                                                                                                                                                 NaN
# ER                                                                                                                                                                 NaN
# Fd                                                                                                                                      {'Description': 'Down-Quarks'}
# Fe                                                                                                                                          {'Description': 'Leptons'}
# Fu                                                                                                                                        {'Description': 'Up-Quarks'}
# Fv                                                                                                                                        {'Description': 'Neutrinos'}
# H                                                                                                                                                                  NaN
# H0                                                                                                                                                                 NaN
# Hp    {'OutputName': ['Hp', 'Hm'], 'PDG': [0], 'Mass': [0], 'Width': [0], 'ElectricCharge': 1, 'PDG.IX': [0], 'LaTeX': ['H^+', 'H^-'], 'Description': 'Charged Higgs'}
# UL                                                                                                                                                                 NaN
# UR                                                                                                                                                                 NaN
# VB                                                                                                                                                                 NaN
# VG                                                                                                                                            {'Description': 'Gluon'}
# VP                                                                                                                                           {'Description': 'Photon'}
# VWB                                                                                                                                                                NaN
# VWp                                                                                                                   {'Goldstone': 'Hp', 'Description': 'W+ - Boson'}
# VZ                                                                                                                       {'Goldstone': 'Ah', 'Description': 'Z-Boson'}
# dL                                                                                                                                                                 NaN
# dR                                                                                                                                                                 NaN
# eL                                                                                                                                                                 NaN
# eR                                                                                                                                                                 NaN
# gB                                                                                                                                                                 NaN
# gG                                                                                                                                      {'Description': 'Gluon Ghost'}
# gP                                                                                                                                     {'Description': 'Photon Ghost'}
# gWB                                                                                                                                                                NaN
# gWp                                                                                                                       {'Description': 'Positive W+ - Boson Ghost'}
# gWpC                                                                                                                      {'Description': 'Negative W+ - Boson Ghost'}
# gZ                                                                                                                                    {'Description': 'Z-Boson Ghost'}
# hh                                                                                                        {'PDG.IX': [101000001], 'PDG': [25], 'Description': 'Higgs'}
# l                                                                                                                                                                  NaN
# q                                                                                                                                                                  NaN
# uL                                                                                                                                                                 NaN
# uR                                                                                                                                                                 NaN
# vL                                                                                                                                                                 NaN
#
#                                                                                                  GaugeES  \
# Ah                                                                                                   NaN
# DL                                                                                                   NaN
# DR                                                                                                   NaN
# EL                                                                                                   NaN
# ER                                                                                                   NaN
# Fd                                                                                                   NaN
# Fe                                                                                                   NaN
# Fu                                                                                                   NaN
# Fv                                                                                                   NaN
# H                                                                                                    NaN
# H0    {'OutputName': 'H0', 'PDG': [0], 'Mass': 'Automatic', 'Width': 0, 'FeynArtsNr': 1, 'LaTeX': 'H^0'}
# Hp    {'OutputName': 'Hp', 'PDG': [0], 'Mass': 'Automatic', 'Width': 0, 'FeynArtsNr': 2, 'LaTeX': 'H^+'}
# UL                                                                                                   NaN
# UR                                                                                                   NaN
# VB                                                                            {'Description': 'B-Boson'}
# VG                                                                              {'Description': 'Gluon'}
# VP                                                                                                   NaN
# VWB                                                                          {'Description': 'W-Bosons'}
# VWp                                                                                                  NaN
# VZ                                                                                                   NaN
# dL                                                                                                   NaN
# dR                                                                                                   NaN
# eL                                                                                                   NaN
# eR                                                                                                   NaN
# gB                                                                      {'Description': 'B-Boson Ghost'}
# gG                                                                        {'Description': 'Gluon Ghost'}
# gP                                                                                                   NaN
# gWB                                                                     {'Description': 'W-Boson Ghost'}
# gWp                                                                                                  NaN
# gWpC                                                                                                 NaN
# gZ                                                                                                   NaN
# hh                                                                                                   NaN
# l                                                                                                    NaN
# q                                                                                                    NaN
# uL                                                                                                   NaN
# uR                                                                                                   NaN
# vL                                                                                                   NaN
#
#                                                           WeylFermionAndIndermediate
# Ah                                                                               NaN
# DL                                                                  {'LaTeX': 'D_L'}
# DR                                                                  {'LaTeX': 'D_R'}
# EL                                                                  {'LaTeX': 'E_L'}
# ER                                                                  {'LaTeX': 'E_R'}
# Fd                                                                               NaN
# Fe                                                                               NaN
# Fu                                                                               NaN
# Fv                                                                               NaN
# H     {'Width': 0, 'OutputName': 'H', 'PDG': [0], 'Mass': 'Automatic', 'LaTeX': 'H'}
# H0                                                                               NaN
# Hp                                                                               NaN
# UL                                                                  {'LaTeX': 'U_L'}
# UR                                                                  {'LaTeX': 'U_R'}
# VB                                                                               NaN
# VG                                                                               NaN
# VP                                                                               NaN
# VWB                                                                              NaN
# VWp                                                                              NaN
# VZ                                                                               NaN
# dL                                                                  {'LaTeX': 'd_L'}
# dR                                                                  {'LaTeX': 'd_R'}
# eL                                                                  {'LaTeX': 'e_L'}
# eR                                                                  {'LaTeX': 'e_R'}
# gB                                                                               NaN
# gG                                                                               NaN
# gP                                                                               NaN
# gWB                                                                              NaN
# gWp                                                                              NaN
# gWpC                                                                             NaN
# gZ                                                                               NaN
# hh                                                                               NaN
# l                                                                     {'LaTeX': 'l'}
# q                                                                     {'LaTeX': 'q'}
# uL                                                                  {'LaTeX': 'u_L'}
# uR                                                                  {'LaTeX': 'u_R'}
# vL                                                               {'LaTeX': '\\nu_L'}

# %% [markdown]
# Checks

# %%
SM['GaugeES']['H0']
# Out:
# {'FeynArtsNr': 1,
#  'LaTeX': 'H^0',
#  'Mass': 'Automatic',
#  'OutputName': 'H0',
#  'PDG': [0],
#  'Width': 0}

# %%
SM['EWSB']['VZ']
# Out:
# {'Description': 'Z-Boson', 'Goldstone': 'Ah'}

# %%
SM[:1]
# Out:
#                                                                                             EWSB  \
# Ah  {'Width': [0], 'PDG.IX': [0], 'PDG': [0], 'Mass': [0], 'Description': 'Pseudo-Scalar Higgs'}
#
#    GaugeES WeylFermionAndIndermediate
# Ah     NaN                        NaN

# %% [markdown]
# Show a particle

# %%
SM['GaugeES']['H0']
# Out:
# {'FeynArtsNr': 1,
#  'LaTeX': 'H^0',
#  'Mass': 'Automatic',
#  'OutputName': 'H0',
#  'PDG': [0],
#  'Width': 0}

# %% [markdown]
# Example: Modify particle property

# %%
SM['WeylFermionAndIndermediate']['dR'] = {'LaTeX' : 'd_R'   }

# %% [markdown]
# ## Load JSON
# Directly fromo the `json.dumps...`

# %%
BSM=pd.read_json('JSON/particles.json')#,lines=True,orient='records')

# %%
BSM[:1]
# Out:
#                                                                                             EWSB  \
# Ah  {'Width': [0], 'PDG': [0], 'Mass': [0], 'Description': 'Pseudo-Scalar Higgs', 'PDG.IX': [0]}
#
#    GaugeES WeylFermionAndIndermediate
# Ah     NaN                        NaN

# %%
BSM['GaugeES'].dropna()['H0']
# Out:
# {'FeynArtsNr': 1,
#  'LaTeX': 'H^0',
#  'Mass': 'Automatic',
#  'OutputName': 'H0',
#  'PDG': [0],
#  'Width': 0}

# %%
BSM['GaugeES']['H0']
# Out:
# {'FeynArtsNr': 1,
#  'LaTeX': 'H^0',
#  'Mass': 'Automatic',
#  'OutputName': 'H0',
#  'PDG': [0],
#  'Width': 0}

# %%
BSM['EWSB']['VZ']
# Out:
# {'Description': 'Z-Boson', 'Goldstone': 'Ah'}

# %%
BSM['WeylFermionAndIndermediate']['dR'] = {'LaTeX' : 'd_R'   }

# %%
BSM.loc['Ah','EWSB']
# Out:
# {'Description': 'Pseudo-Scalar Higgs',
#  'Mass': [0],
#  'PDG': [0],
#  'PDG.IX': [0],
#  'Width': [0]}

# %% [markdown]
# ## Export to files

# %%
SM=BSM.loc[['Ah', 'DL', 'DR', 'EL', 'ER', 'Fd', 'Fe', 'Fu', 'Fv', 'H', 'H0', 'Hp',
       'UL', 'UR', 'VB', 'VG', 'VP', 'VWB', 'VWp', 'VZ', 'dL', 'dR', 'eL',
       'eR', 'gB', 'gG', 'gP', 'gWB', 'gWp', 'gWpC', 'gZ', 'hh', 'l', 'q',
       'uL', 'uR', 'vL']]

# %%
CHECK_PANDAS_SAVED_JSON=False
if CHECK_PANDAS_SAVED_JSON:
    SM=pd.read_json('SM2.json')#,lines=True,orient='records')

# %%
print( to_math(SM,'p.m') )
# Out:
# ParticleDefinitions[EWSB] = {
#     {Ah, { Description -> "Pseudo-Scalar Higgs",
#            Width -> {0},
#            PDG -> {0},
#            Mass -> {0},
#            PDG.IX -> {0}}},
#     {Fd, { Description -> "Down-Quarks"}},
#     {Fe, { Description -> "Leptons"}},
#     {Fu, { Description -> "Up-Quarks"}},
#     {Fv, { Description -> "Neutrinos"}},
#     {Hp, { Description -> "Charged Higgs",
#            LaTeX -> {"H^+", "H^-"},
#            OutputName -> {"Hp", "Hm"},
#            PDG -> {0},
#            Mass -> {0},
#            Width -> {0},
#            ElectricCharge -> 1,
#            PDG.IX -> {0}}},
#     {VG, { Description -> "Gluon"}},
#     {VP, { Description -> "Photon"}},
#     {VWp, { Description -> "W+ - Boson",
#            Goldstone -> Hp}},
#     {VZ, { Description -> "Z-Boson",
#            Goldstone -> Ah}},
#     {gG, { Description -> "Gluon Ghost"}},
#     {gP, { Description -> "Photon Ghost"}},
#     {gWp, { Description -> "Positive W+ - Boson Ghost"}},
#     {gWpC, { Description -> "Negative W+ - Boson Ghost"}},
#     {gZ, { Description -> "Z-Boson Ghost"}},
#     {hh, { Description -> "Higgs",
#            PDG -> {25},
#            PDG.IX -> {101000001}}}
# };
#
# ParticleDefinitions[GaugeES] = {
#     {H0, { OutputName -> H0,
#            PDG -> {0},
#            Mass -> Automatic,
#            Width -> 0,
#            FeynArtsNr -> 1,
#            LaTeX -> "H^0"}},
#     {Hp, { OutputName -> Hp,
#            PDG -> {0},
#            Mass -> Automatic,
#            Width -> 0,
#            FeynArtsNr -> 2,
#            LaTeX -> "H^+"}},
#     {VB, { Description -> "B-Boson"}},
#     {VG, { Description -> "Gluon"}},
#     {VWB, { Description -> "W-Bosons"}},
#     {gB, { Description -> "B-Boson Ghost"}},
#     {gG, { Description -> "Gluon Ghost"}},
#     {gWB, { Description -> "W-Boson Ghost"}}
# };
#
# ParticleDefinitions[WeylFermionAndIndermediate] = {
#     {DL, { LaTeX -> "D_L"}},
#     {DR, { LaTeX -> "D_R"}},
#     {EL, { LaTeX -> "E_L"}},
#     {ER, { LaTeX -> "E_R"}},
#     {H, { Width -> 0,
#            OutputName -> H,
#            PDG -> {0},
#            Mass -> Automatic,
#            LaTeX -> "H"}},
#     {UL, { LaTeX -> "U_L"}},
#     {UR, { LaTeX -> "U_R"}},
#     {dL, { LaTeX -> "d_L"}},
#     {dR, { LaTeX -> "d_R"}},
#     {eL, { LaTeX -> "e_L"}},
#     {eR, { LaTeX -> "e_R"}},
#     {l, { LaTeX -> "l"}},
#     {q, { LaTeX -> "q"}},
#     {uL, { LaTeX -> "u_L"}},
#     {uR, { LaTeX -> "u_R"}},
#     {vL, { LaTeX -> "\\nu_L"}}
# };

# %% [markdown]
# # Get particle from model file

# %% [markdown]
# Design:
# * Intialize `particle` as an empty dictionary.
# * Intialize `particles` as an empty list.
# * Fill particle properties and build the list: `particles`
# * Internal defintions
#   * weyl: Charged Weyl fermion bidiagonal rotation object
#   * symm: Symmetric diagonalization system object
#   * vev:  Complex scalar decomposition

# %% [markdown]
# Implementation:
# 1. Get particles from particles definitions
# 2. Get particles from `DEFINITION[EWSB]`
#
# Assumptions:
#
# * SM doublet Higgs field is assigned `H`
# * Fermion doublets have decreasing Hypercharge, $Y$
# * $ Q=T_3+Y/2 $

# %% [markdown]
# ## Load Model file

# %%
import pandas as pd
from SARAH import *
pd.set_option('display.max_colwidth',200)
#TODO: Initialize objects
particles=[]
particlessons=[]

Fields=['Gauge','FermionFields','ScalarFields']
NAME='DEFINITION'
KEY='EWSB'

# %%
MODEL_PATH="./SARAH/Models/SM/SM.m"
f=open(MODEL_PATH,'r')
smf=f.read()
f.close()

# %%
smf
# Out:
# 'Off[General::spell]\n\nModel`Name = "SM";\nModel`NameLaTeX ="Standard Model";\nModel`Authors = "F.Staub";\nModel`Date = "2014-11-06";\n\n(* 2013-01-24: changed normalization of lambda term to convention of hep-ph/0207271 *)\n(* 2013-06-24: using new name conventions (without inital "S" and "F" for scalar and matter fields) *)\n(* 2013-09-01: changing to new conventions for FermionFields/MatterFields *)\n(* 2014-11-06: Changed sign in Lagrangian to fit standard conventions *)\n(* 2016-05-03: Changed sign of Yu *)\n\n\n\n(*-------------------------------------------*)\n(*   Particle Content*)\n(*-------------------------------------------*)\n\n(* Gauge Groups *)\n\nGauge[[1]]={B,   U[1], hypercharge, g1,False};\nGauge[[2]]={WB, SU[2], left,        g2,True};\nGauge[[3]]={G,  SU[3], color,       g3,False};\n\n\n(* Matter Fields *)\n\nFermionFields[[1]] = {q, 3, {uL, dL},     1/6, 2,  3};  \nFermionFields[[2]] = {l, 3, {vL, eL},    -1/2, 2,  1};\nFermionFields[[3]] = {d, 3, conj[dR],     1/3, 1, -3};\nFermionFields[[4]] = {u, 3, conj[uR],    -2/3, 1, -3};\nFermionFields[[5]] = {e, 3, conj[eR],       1, 1,  1};\n\nScalarFields[[1]] =  {H, 1, {Hp, H0},     1/2, 2,  1};\n\n\n        \n(*----------------------------------------------*)\n(*   DEFINITION                                 *)\n(*----------------------------------------------*)\n\nNameOfStates={GaugeES, EWSB};\n\n(* ----- Before EWSB ----- *)\n\nDEFINITION[GaugeES][LagrangianInput]= {\n\t{LagHC, {AddHC->True}},\n\t{LagNoHC,{AddHC->False}}\n};\n\n\nLagNoHC = -mu2 conj[H].H - 1/2 \\[Lambda] conj[H].H.conj[H].H;\nLagHC =  -(Yd conj[H].d.q + Ye conj[H].e.l + Yu u.q.H);\n\n\n\t\t\t  \t\t  \n\n(* Gauge Sector *)\n\nDEFINITION[EWSB][GaugeSector] =\n{ \n  {{VB,VWB[3]},{VP,VZ},ZZ},\n  {{VWB[1],VWB[2]},{VWp,conj[VWp]},ZW}\n};     \n        \n        \n          \t\n\n(* ----- VEVs ---- *)\n\nDEFINITION[EWSB][VEVs]= \n{    {H0, {v, 1/Sqrt[2]}, {Ah, \\[ImaginaryI]/Sqrt[2]},{hh, 1/Sqrt[2]}}     };\n \n\nDEFINITION[EWSB][MatterSector]=   \n    {{{{dL}, {conj[dR]}}, {{DL,Vd}, {DR,Ud}}},\n     {{{uL}, {conj[uR]}}, {{UL,Vu}, {UR,Uu}}},\n     {{{eL}, {conj[eR]}}, {{EL,Ve}, {ER,Ue}}}};  \n\n\n(*------------------------------------------------------*)\n(* Dirac-Spinors *)\n(*------------------------------------------------------*)\n\nDEFINITION[EWSB][DiracSpinors]={\n Fd ->{  DL, conj[DR]},\n Fe ->{  EL, conj[ER]},\n Fu ->{  UL, conj[UR]},\n Fv ->{  vL, 0}};\n\nDEFINITION[EWSB][GaugeES]={\n Fd1 ->{  FdL, 0},\n Fd2 ->{  0, FdR},\n Fu1 ->{  Fu1, 0},\n Fu2 ->{  0, Fu2},\n Fe1 ->{  Fe1, 0},\n Fe2 ->{  0, Fe2}};\n\n\n\n'

# %% [markdown]
# ## General definition

# %% [markdown]
# ## 1) Get particles from particles definitions

# %% [markdown]
# ### Obtain `particle` from
# * `Gauge` list
# * `FermionFields` list, with the components fields (intialized as `particlesson` `dict`) with parents information
# * `ScalarFields`  list, with the components fields (intialized as `particlesson` `dict`) with parents information
#
# and fill `particles`

# %%
particles=get_particles(smf,Fields,NAME,KEY,particles,particlessons)
# Out:
# ('B,   U[1], hypercharge, g1,False',) Gauge 5
# {'Properties': {'Group': '   U[1]', 'Lorentz': 'Vector', 'SSB': ' g1', 'Coupling': ' g1', 'Index': ' hypercharge'}, 'Field': 'VB', 'Definition': 'GaugeES', 'Parents': None}
# ('WB, SU[2], left,        g2,True',) Gauge 5
# {'Properties': {'Group': ' SU[2]', 'Lorentz': 'Vector', 'SSB': '        g2', 'Coupling': '        g2', 'Index': ' left'}, 'Field': 'VWB', 'Definition': 'GaugeES', 'Parents': None}
# ('G,  SU[3], color,       g3,False',) Gauge 5
# {'Properties': {'Group': '  SU[3]', 'Lorentz': 'Vector', 'SSB': '       g3', 'Coupling': '       g3', 'Index': ' color'}, 'Field': 'VG', 'Definition': 'GaugeES', 'Parents': None}
# ('q, 3, uL:: dL,     1/6, 2,  3;  ',) FermionFields 6
# **********
#  uL:: dL [' uL', ' dL']
#  uL
#  dL
# **********
# ('l, 3, vL:: eL,    -1/2, 2,  1;',) FermionFields 6
# **********
#  vL:: eL [' vL', ' eL']
#  vL
#  eL
# **********
# ('d, 3, conj[dR],     1/3, 1, -3',) FermionFields 6
# **********
#  conj[dR] [' dR']
#  dR
# **********
# ('u, 3, conj[uR],    -2/3, 1, -3',) FermionFields 6
# **********
#  conj[uR] [' uR']
#  uR
# **********
# ('e, 3, conj[eR],       1, 1,  1',) FermionFields 6
# **********
#  conj[eR] [' eR']
#  eR
# **********
# ('H, 1, Hp:: H0,     1/2, 2,  1;',) ScalarFields 6
# **********
#  Hp:: H0 [' Hp', ' H0']
#  Hp
#  H0
# **********

# %%
pd.DataFrame( particles )#.loc[8]['Properties']
# Out:
#                     Definition Field Parents  \
# 0                      GaugeES    VB    None
# 1                      GaugeES   VWB    None
# 2                      GaugeES    VG    None
# 3   WeylFermionAndIndermediate     q    None
# 4   WeylFermionAndIndermediate     l    None
# 5   WeylFermionAndIndermediate     d    None
# 6   WeylFermionAndIndermediate     u    None
# 7   WeylFermionAndIndermediate     e    None
# 8   WeylFermionAndIndermediate     H    None
# 9   WeylFermionAndIndermediate    uL       q
# 10  WeylFermionAndIndermediate    dL       q
# 11  WeylFermionAndIndermediate    vL       l
# 12  WeylFermionAndIndermediate    eL       l
# 13  WeylFermionAndIndermediate    dR       d
# 14  WeylFermionAndIndermediate    uR       u
# 15  WeylFermionAndIndermediate    eR       e
# 16                     GaugeES    Hp       H
# 17                     GaugeES    H0       H
#
#                                                                                                    Properties
# 0         {'Group': '   U[1]', 'Lorentz': 'Vector', 'SSB': ' g1', 'Coupling': ' g1', 'Index': ' hypercharge'}
# 1   {'Group': ' SU[2]', 'Lorentz': 'Vector', 'SSB': '        g2', 'Coupling': '        g2', 'Index': ' left'}
# 2   {'Group': '  SU[3]', 'Lorentz': 'Vector', 'SSB': '       g3', 'Coupling': '       g3', 'Index': ' color'}
# 3               {'NF': '3', 'Groups': ['1/6', '2', '3'], 'Lorentz': 'WeylFermion', 'multiplet': ['uL', 'dL']}
# 4              {'NF': '3', 'Groups': ['-1/2', '2', '1'], 'Lorentz': 'WeylFermion', 'multiplet': ['vL', 'eL']}
# 5                                         {'NF': '3', 'Groups': ['1/3', '1', '-3'], 'Lorentz': 'WeylFermion'}
# 6                                        {'NF': '3', 'Groups': ['-2/3', '1', '-3'], 'Lorentz': 'WeylFermion'}
# 7                                            {'NF': '3', 'Groups': ['1', '1', '1'], 'Lorentz': 'WeylFermion'}
# 8                    {'NF': '1', 'Groups': ['1/2', '2', '1'], 'Lorentz': 'Scalar', 'multiplet': ['Hp', 'H0']}
# 9                                                                       {'NF': '3', 'Lorentz': 'WeylFermion'}
# 10                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 11                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 12                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 13                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 14                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 15                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 16                                                                           {'NF': '1', 'Lorentz': 'Scalar'}
# 17                                                                           {'NF': '1', 'Lorentz': 'Scalar'}

# %% [markdown]
# ## 2) Get particles from `DEFINITION[EWSB]`

# %%
dsbd=parse_mathematica_list_of_list(smf,NAME='DEFINITION',KEY='EWSB')
dsbd
# Out:
# {'DiracSpinors': {'Fd': ['DL', 'conj[DR]'],
#   'Fe': ['EL', 'conj[ER]'],
#   'Fu': ['UL', 'conj[UR]'],
#   'Fv': ['vL', 0]},
#  'GaugeES': {'Fd1': ['FdL', 0],
#   'Fd2': [0, 'FdR'],
#   'Fe1': ['Fe1', 0],
#   'Fe2': [0, 'Fe2'],
#   'Fu1': ['Fu1', 0],
#   'Fu2': [0, 'Fu2']},
#  'GaugeSector': [[['VB', 'VWB[3]'], ['VP', 'VZ'], 'ZZ'],
#   [['VWB[1]', 'VWB[2]'], ['VWp', 'conj[VWp]'], 'ZW']],
#  'MatterSector': [[[['dL'], ['conj[dR]']], [['DL', 'Vd'], ['DR', 'Ud']]],
#   [[['uL'], ['conj[uR]']], [['UL', 'Vu'], ['UR', 'Uu']]],
#   [[['eL'], ['conj[eR]']], [['EL', 'Ve'], ['ER', 'Ue']]]],
#  'VEVs': [['H0',
#    ['v', '1/Sqrt[2]'],
#    ['Ah', '\\[ImaginaryI]/Sqrt[2]'],
#    ['hh', '1/Sqrt[2]']]]}

# %%
DEFINITION={}
DEFINITION['EWSB']={}
Bidiagonal=[]
Diagonal=[]
VEV=[]
for k in dsbd.keys():
    
    for w in dsbd[k]:
        if k=='GaugeSector' or k=='MatterSector':
            if np.array(w).shape==(2,2):
                weyl=bidiagonal(w,k)
                Bidiagonal.append(weyl)
            elif np.array(w).shape==(3,):
                symm=diagonal(w,k)
                Diagonal.append(symm)
        elif k=='VEVs':
            VEV.append(get_vev(w,k))

DEFINITION['EWSB']['Bidiagonal']=Bidiagonal
DEFINITION['EWSB']['Diagonal']=Diagonal
DEFINITION['EWSB']['VEVs']=VEV
DEFINITION['EWSB']['DiracSpinors']=dsbd['DiracSpinors']

# %%
particles=particles+rotations_to_particles(DEFINITION,key='EWSB',lr='',sep='')
particles=particles+rotations_to_particles(DEFINITION,key='EWSB',lr='left',sep='_')
particles=particles+rotations_to_particles(DEFINITION,key='EWSB',lr='right',sep='_')

# %%
newparticles=[]
for d in DEFINITION['EWSB']['VEVs']:
    particle=vev_to_particles(d,cp='Real')
    newparticles.append(particle)
    particle=vev_to_particles(d,cp='Imaginary')
    newparticles.append(particle)
particles=particles+newparticles

# %%
newparticles=[]
dict_of_spinors=DEFINITION['EWSB']['DiracSpinors']
for f in dict_of_spinors.keys():
    particle=spinor_to_particles(dict_of_spinors,DEFINITION,f)
    newparticles.append(particle)
particles=particles+newparticles

# %%
f=open('parseparticles.json','w')
json.dump(particles,f)
f.close()

# %%
pd.read_json('parseparticles.json')
# Out:
#            Block                  Definition Field   Parents  \
# 0            NaN                     GaugeES    VB      None
# 1            NaN                     GaugeES   VWB      None
# 2            NaN                     GaugeES    VG      None
# 3            NaN  WeylFermionAndIndermediate     q      None
# 4            NaN  WeylFermionAndIndermediate     l      None
# 5            NaN  WeylFermionAndIndermediate     d      None
# 6            NaN  WeylFermionAndIndermediate     u      None
# 7            NaN  WeylFermionAndIndermediate     e      None
# 8            NaN  WeylFermionAndIndermediate     H      None
# 9            NaN  WeylFermionAndIndermediate    uL         q
# 10           NaN  WeylFermionAndIndermediate    dL         q
# 11           NaN  WeylFermionAndIndermediate    vL         l
# 12           NaN  WeylFermionAndIndermediate    eL         l
# 13           NaN  WeylFermionAndIndermediate    dR         d
# 14           NaN  WeylFermionAndIndermediate    uR         u
# 15           NaN  WeylFermionAndIndermediate    eR         e
# 16           NaN                     GaugeES    Hp         H
# 17           NaN                     GaugeES    H0         H
# 18   GaugeSector                        EWSB    VP        VB
# 19   GaugeSector                        EWSB    VZ    VWB[3]
# 20   GaugeSector                        EWSB   VWp    VWB[1]
# 21   MatterField  WeylFermionAndIndermediate    DL        dL
# 22   MatterField  WeylFermionAndIndermediate    UL        uL
# 23   MatterField  WeylFermionAndIndermediate    EL        eL
# 24   MatterField  WeylFermionAndIndermediate    DR  conj[dR]
# 25   MatterField  WeylFermionAndIndermediate    UR  conj[uR]
# 26   MatterField  WeylFermionAndIndermediate    ER  conj[eR]
# 27          VEVs                        EWSB    hh        H0
# 28          VEVs                        EWSB    Ah        H0
# 29  DiracSpinors                        EWSB    Fu        UL
# 30  DiracSpinors                        EWSB    Fv        vL
# 31  DiracSpinors                        EWSB    Fe        EL
# 32  DiracSpinors                        EWSB    Fd        DL
#
#                                                                                                    Properties  \
# 0         {'Group': '   U[1]', 'SSB': ' g1', 'Lorentz': 'Vector', 'Coupling': ' g1', 'Index': ' hypercharge'}
# 1   {'Group': ' SU[2]', 'SSB': '        g2', 'Lorentz': 'Vector', 'Coupling': '        g2', 'Index': ' left'}
# 2   {'Group': '  SU[3]', 'SSB': '       g3', 'Lorentz': 'Vector', 'Coupling': '       g3', 'Index': ' color'}
# 3               {'NF': '3', 'Groups': ['1/6', '2', '3'], 'Lorentz': 'WeylFermion', 'multiplet': ['uL', 'dL']}
# 4              {'NF': '3', 'Groups': ['-1/2', '2', '1'], 'Lorentz': 'WeylFermion', 'multiplet': ['vL', 'eL']}
# 5                                         {'NF': '3', 'Groups': ['1/3', '1', '-3'], 'Lorentz': 'WeylFermion'}
# 6                                        {'NF': '3', 'Groups': ['-2/3', '1', '-3'], 'Lorentz': 'WeylFermion'}
# 7                                            {'NF': '3', 'Groups': ['1', '1', '1'], 'Lorentz': 'WeylFermion'}
# 8                    {'NF': '1', 'Groups': ['1/2', '2', '1'], 'Lorentz': 'Scalar', 'multiplet': ['Hp', 'H0']}
# 9                                                                       {'NF': '3', 'Lorentz': 'WeylFermion'}
# 10                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 11                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 12                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 13                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 14                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 15                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 16                                                                           {'NF': '1', 'Lorentz': 'Scalar'}
# 17                                                                           {'NF': '1', 'Lorentz': 'Scalar'}
# 18                   {'Mass_basis': ['VP', 'VZ'], 'Lorentz': 'Vector', 'Interaction_basis': ['VB', 'VWB[3]']}
# 19                   {'Mass_basis': ['VP', 'VZ'], 'Lorentz': 'Vector', 'Interaction_basis': ['VB', 'VWB[3]']}
# 20       {'Mass_basis': ['VWp', 'conj[VWp]'], 'Lorentz': 'Vector', 'Interaction_basis': ['VWB[1]', 'VWB[2]']}
# 21           {'Mass_basis': 'DL', 'Lorentz': 'WeylFermion', 'Interaction_basis': ['dL'], 'Chirality': 'left'}
# 22           {'Mass_basis': 'UL', 'Lorentz': 'WeylFermion', 'Interaction_basis': ['uL'], 'Chirality': 'left'}
# 23           {'Mass_basis': 'EL', 'Lorentz': 'WeylFermion', 'Interaction_basis': ['eL'], 'Chirality': 'left'}
# 24    {'Mass_basis': 'DR', 'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[dR]'], 'Chirality': 'right'}
# 25    {'Mass_basis': 'UR', 'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[uR]'], 'Chirality': 'right'}
# 26    {'Mass_basis': 'ER', 'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[eR]'], 'Chirality': 'right'}
# 27                                {'vev': 'v', 'CP': 'Real', 'Lorentz': 'Scalar', 'Coefficient': '1/Sqrt[2]'}
# 28               {'vev': 'v', 'CP': 'Imaginary', 'Lorentz': 'Scalar', 'Coefficient': '\[ImaginaryI]/Sqrt[2]'}
# 29                                              {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['UL', 'conj[UR]']}
# 30                                                 {'Lorentz': 'MajoranaSpinor', 'MajoranaSpinor': ['vL', 0]}
# 31                                              {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['EL', 'conj[ER]']}
# 32                                              {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['DL', 'conj[DR]']}
#
#    rotation
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18       ZZ
# 19       ZZ
# 20       ZW
# 21       Vd
# 22       Vu
# 23       Ve
# 24       Ud
# 25       Uu
# 26       Ue
# 27      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN

# %% [markdown]
# ## Generate `particles.json` from particles dict

# %%
prt=pd.DataFrame(particles)
prt=prt.where((pd.notnull(prt)), None)

# %%
def get_weylfermion_LaTeX(s):
    if len(s)==2 and re.search('[LR]$',s):
        sini=s[0]
        if sini=='v':
            sini=r'\nu'
        s=sini+'_'+s[1]
    return s

def get_abs_groups(grps=['1/2','2','1'],u1_abs='1/2',su2='2',su3_abs='1'):
    sgrps=str(grps).replace(' ','')
    return re.search(r"\['-*{}','{}','{}'".format(u1_abs,su2,su3_abs), sgrps )

def update_EWSB_Fermion_Description(p,prt):
    gprt=prt[prt.get('Field')==p.get('Parents')].reset_index(drop=True)
    if gprt.loc[0,'rotation']:
        gprt=prt[prt.get('Field')==gprt.loc[0,'Parents']].reset_index(drop=True)
    cmpt=gprt.loc[0,'Field']
    gprt=prt[prt.get('Field')==gprt.loc[0,'Parents']].reset_index(drop=True)
    if get_abs_groups( gprt.loc[0,'Properties'].get('Groups'), u1_abs='1/6',su2='2',su3_abs='3' ):
        if cmpt==gprt.loc[0,'Properties'].get('multiplet')[0]:
            p['Description']='Up-Quarks'
        else:
            p['Description']='Down-Quarks'
    if get_abs_groups( gprt.loc[0,'Properties'].get('Groups'), u1_abs='1/2',su2='2',su3_abs='1' ):
        if cmpt==gprt.loc[0,'Properties'].get('multiplet')[0]:
            p['Description']='Neutrinos'
        else:
            p['Description']='Leptons'
    return p

# %%
#TODO: Make false when there are more scalar doublets
Add_Charged_SM_Higgs_to_EWSB=True
newparticles=[]
for i in prt.index:
    p=prt.loc[i].to_dict()
    if p.get('Definition')=='GaugeES' and p.get('Properties').get('Lorentz').strip()=='Vector':
        if  p.get('Properties').get('Group').strip()=='U[1]':
            p['Description']='B-Boson'
            newparticles.append(p)
            newparticles.append({'Definition':'GaugeES','Field':'gB',
                               'Description':'B-Boson Ghost',
                               'Parents':p.get('Field'),'Properties':{
                               'Group':p.get('Properties').get('Group'),'Lorentz':'Scalar'}})
            #break
        elif p.get('Properties').get('Group').strip()=='SU[2]':
            p['Description']='W-Bosons'
            newparticles.append(p)
            newparticles.append({'Definition':'GaugeES','Field':'gWB',
                               'Description':'W-Boson Ghost',
                               'Parents':p.get('Field'),'Properties':{
                                'Group':p.get('Properties').get('Group'), 'Lorentz':'Scalar'}})        
            
        elif p.get('Properties').get('Group').strip()=='SU[3]':
            p['Description']='Gluon'
            newparticles.append(p)
            newparticles.append({'Definition':'GaugeES','Field':'gG',
                               'Description':'Gluon Ghost',
                               'Parents':p.get('Field'),'Properties':{
                               'Group':p.get('Properties').get('Group'),'Lorentz':'Scalar'}})
        #Search for daugthers
    if p.get('Definition')=='WeylFermionAndIndermediate' and p.get('Properties').get('Lorentz')=='Scalar':
        #Generic Doublet scalar: Include SM Higgs
        #re.search(r"\['-*1/2','2','1'",str(p.get('Properties').get('Groups')).replace(' ',''))
        if get_abs_groups(p.get('Properties').get('Groups'),u1_abs='1/2',su2='2',su3_abs='1'):
            p.get('Properties')['update_Description']={'PDG'       : [0],
                                                           'Width'     : 0,
                                                           'Mass'      : 'Automatic',
                                                           'LaTeX'     : p.get('Field'),
                                                           'OutputName': p.get('Field') }
            newparticles.append(p)
            #print(p)
            dprt=prt[prt['Parents']==p.get('Field')].reset_index(drop=True)
            if dprt.shape[0]==2:
                print('va',0)
                for j in dprt.index:
                    dp=dprt.loc[j].to_dict()
                    #Higss components
                    charge=[]
                    if dp.get('Parents')=='H':
                        if p.get('Properties').get('Groups')[0].find('-')==-1:
                            charge=['Charged','Neutral']
                        else:
                            charge=['Neutral','Charged']
                        #print('va j',j,charge)
                            
                        if charge[j]=='Charged':
                            dp.get('Properties')['update_Description']={'PDG'  :[0],
                                    'Width':0,
                                    'Mass' : 'Automatic',
                                    'FeynArtsNr' : 2,
                                    'LaTeX' : 'H^+',
                                    'OutputName' : dp.get('Field')                            
                                   }                            
                            newparticles.append(dp)
                            #TODO: Add EWSB charged scalar only if no more scalars
                            # with parent Hp
                            if Add_Charged_SM_Higgs_to_EWSB:
                                gdp={'Definition': 'EWSB',
                                     'Field': 'Hp',
                                     'Parents': 'Hp',
                                     'Description': 'Charged Higgs',
                                     'Properties': {'Lorentz': 'Scalar',
                                     'NF': '1',
                                     'update_Description': {
                                         'PDG'            : [0],
                                         'PDG.IX'         : [0],
                                         'Width'          : [0], 
                                         'Mass'           : [0],
                                         'LaTeX'          : ['H^+','H^-' ],
                                         'OutputName'     : ['Hp' ,'Hm'  ],
                                        'ElectricCharge' : 1
                                     }}}
                                newparticles.append(gdp)                                
                        else: #Neutral
                            dp.get('Properties')['update_Description']={'PDG'  :[0],
                                    'Width':0,
                                    'Mass' : 'Automatic',
                                    'FeynArtsNr' : 1,
                                    'LaTeX' : 'H^0',
                                    'OutputName' : dp.get('Field')                        
                                   }
                            newparticles.append(dp)
                            #print('va H0',j)
                            
                            #TODO: Define object to capture two daugthers
                            gdprt=prt[prt['Parents']==dp.get('Field')].reset_index(drop=True)
                            if gdprt.shape[0]==2:
                                for k in gdprt.index:
                                    gdp=gdprt.loc[k].to_dict()
                                    if gdp.get('Properties').get('CP')=='Real':
                                        gdp['Description']='Higgs'
                                        gdp.get('Properties')['update_Description']={
                                            'PDG'         : [25],
                                            'PDG.IX'      : [101000001]
                                        }
                                        newparticles.append(gdp)
                                    else: #'CP' → Imaginary 
                                        gdp['Description']='Pseudo-Scalar Higgs'
                                        gdp.get('Properties')['update_Description']={
                                            'PDG'         : [0],
                                            'PDG.IX'      : [0],
                                            'Mass'        : [0],
                                            'Width'       : [0]
                                        }
                                        newparticles.append(gdp)                                        
                                    #break
                        #break
            #break
            #Search for daughters: two complex fields
    if p.get('Definition')=='WeylFermionAndIndermediate' and p.get('Properties').get('Lorentz')=='WeylFermion':
        p.get('Properties')['update_Description']={'LaTeX' : get_weylfermion_LaTeX( p.get('Field') )}            
        newparticles.append(p)
    #For the following two an or could be used
    if p.get('Definition')=='EWSB' and p.get('Properties').get('Lorentz')=='DiracSpinor':
        p=update_EWSB_Fermion_Description(p,prt)
        newparticles.append(p)
    if p.get('Definition')=='EWSB' and p.get('Properties').get('Lorentz')=='MajoranaSpinor':
        p=update_EWSB_Fermion_Description(p,prt)
        newparticles.append(p)
        #break        
        #break
# Out:
# va 0

# %%
newparticles
# Out:
# [{'Block': None,
#   'Definition': 'GaugeES',
#   'Description': 'B-Boson',
#   'Field': 'VB',
#   'Parents': None,
#   'Properties': {'Coupling': ' g1',
#    'Group': '   U[1]',
#    'Index': ' hypercharge',
#    'Lorentz': 'Vector',
#    'SSB': ' g1'},
#   'rotation': None},
#  {'Definition': 'GaugeES',
#   'Description': 'B-Boson Ghost',
#   'Field': 'gB',
#   'Parents': 'VB',
#   'Properties': {'Group': '   U[1]', 'Lorentz': 'Scalar'}},
#  {'Block': None,
#   'Definition': 'GaugeES',
#   'Description': 'W-Bosons',
#   'Field': 'VWB',
#   'Parents': None,
#   'Properties': {'Coupling': '        g2',
#    'Group': ' SU[2]',
#    'Index': ' left',
#    'Lorentz': 'Vector',
#    'SSB': '        g2'},
#   'rotation': None},
#  {'Definition': 'GaugeES',
#   'Description': 'W-Boson Ghost',
#   'Field': 'gWB',
#   'Parents': 'VWB',
#   'Properties': {'Group': ' SU[2]', 'Lorentz': 'Scalar'}},
#  {'Block': None,
#   'Definition': 'GaugeES',
#   'Description': 'Gluon',
#   'Field': 'VG',
#   'Parents': None,
#   'Properties': {'Coupling': '       g3',
#    'Group': '  SU[3]',
#    'Index': ' color',
#    'Lorentz': 'Vector',
#    'SSB': '       g3'},
#   'rotation': None},
#  {'Definition': 'GaugeES',
#   'Description': 'Gluon Ghost',
#   'Field': 'gG',
#   'Parents': 'VG',
#   'Properties': {'Group': '  SU[3]', 'Lorentz': 'Scalar'}},
#  {'Block': None,
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'q',
#   'Parents': None,
#   'Properties': {'Groups': ['1/6', '2', '3'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'multiplet': ['uL', 'dL'],
#    'update_Description': {'LaTeX': 'q'}},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'l',
#   'Parents': None,
#   'Properties': {'Groups': ['-1/2', '2', '1'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'multiplet': ['vL', 'eL'],
#    'update_Description': {'LaTeX': 'l'}},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'd',
#   'Parents': None,
#   'Properties': {'Groups': ['1/3', '1', '-3'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'update_Description': {'LaTeX': 'd'}},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'u',
#   'Parents': None,
#   'Properties': {'Groups': ['-2/3', '1', '-3'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'update_Description': {'LaTeX': 'u'}},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'e',
#   'Parents': None,
#   'Properties': {'Groups': ['1', '1', '1'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'update_Description': {'LaTeX': 'e'}},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'H',
#   'Parents': None,
#   'Properties': {'Groups': ['1/2', '2', '1'],
#    'Lorentz': 'Scalar',
#    'NF': '1',
#    'multiplet': ['Hp', 'H0'],
#    'update_Description': {'LaTeX': 'H',
#     'Mass': 'Automatic',
#     'OutputName': 'H',
#     'PDG': [0],
#     'Width': 0}},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'GaugeES',
#   'Field': 'Hp',
#   'Parents': 'H',
#   'Properties': {'Lorentz': 'Scalar',
#    'NF': '1',
#    'update_Description': {'FeynArtsNr': 2,
#     'LaTeX': 'H^+',
#     'Mass': 'Automatic',
#     'OutputName': 'Hp',
#     'PDG': [0],
#     'Width': 0}},
#   'rotation': None},
#  {'Definition': 'EWSB',
#   'Description': 'Charged Higgs',
#   'Field': 'Hp',
#   'Parents': 'Hp',
#   'Properties': {'Lorentz': 'Scalar',
#    'NF': '1',
#    'update_Description': {'ElectricCharge': 1,
#     'LaTeX': ['H^+', 'H^-'],
#     'Mass': [0],
#     'OutputName': ['Hp', 'Hm'],
#     'PDG': [0],
#     'PDG.IX': [0],
#     'Width': [0]}}},
#  {'Block': None,
#   'Definition': 'GaugeES',
#   'Field': 'H0',
#   'Parents': 'H',
#   'Properties': {'Lorentz': 'Scalar',
#    'NF': '1',
#    'update_Description': {'FeynArtsNr': 1,
#     'LaTeX': 'H^0',
#     'Mass': 'Automatic',
#     'OutputName': 'H0',
#     'PDG': [0],
#     'Width': 0}},
#   'rotation': None},
#  {'Block': 'VEVs',
#   'Definition': 'EWSB',
#   'Description': 'Higgs',
#   'Field': 'hh',
#   'Parents': 'H0',
#   'Properties': {'CP': 'Real',
#    'Coefficient': '1/Sqrt[2]',
#    'Lorentz': 'Scalar',
#    'update_Description': {'PDG': [25], 'PDG.IX': [101000001]},
#    'vev': 'v'},
#   'rotation': None},
#  {'Block': 'VEVs',
#   'Definition': 'EWSB',
#   'Description': 'Pseudo-Scalar Higgs',
#   'Field': 'Ah',
#   'Parents': 'H0',
#   'Properties': {'CP': 'Imaginary',
#    'Coefficient': '\\[ImaginaryI]/Sqrt[2]',
#    'Lorentz': 'Scalar',
#    'update_Description': {'Mass': [0],
#     'PDG': [0],
#     'PDG.IX': [0],
#     'Width': [0]},
#    'vev': 'v'},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'uL',
#   'Parents': 'q',
#   'Properties': {'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'update_Description': {'LaTeX': 'u_L'}},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'dL',
#   'Parents': 'q',
#   'Properties': {'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'update_Description': {'LaTeX': 'd_L'}},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'vL',
#   'Parents': 'l',
#   'Properties': {'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'update_Description': {'LaTeX': '\\nu_L'}},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'eL',
#   'Parents': 'l',
#   'Properties': {'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'update_Description': {'LaTeX': 'e_L'}},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'dR',
#   'Parents': 'd',
#   'Properties': {'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'update_Description': {'LaTeX': 'd_R'}},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'uR',
#   'Parents': 'u',
#   'Properties': {'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'update_Description': {'LaTeX': 'u_R'}},
#   'rotation': None},
#  {'Block': None,
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'eR',
#   'Parents': 'e',
#   'Properties': {'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'update_Description': {'LaTeX': 'e_R'}},
#   'rotation': None},
#  {'Block': 'MatterField',
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'DL',
#   'Parents': 'dL',
#   'Properties': {'Chirality': 'left',
#    'Interaction_basis': ['dL'],
#    'Lorentz': 'WeylFermion',
#    'Mass_basis': 'DL',
#    'update_Description': {'LaTeX': 'D_L'}},
#   'rotation': 'Vd'},
#  {'Block': 'MatterField',
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'UL',
#   'Parents': 'uL',
#   'Properties': {'Chirality': 'left',
#    'Interaction_basis': ['uL'],
#    'Lorentz': 'WeylFermion',
#    'Mass_basis': 'UL',
#    'update_Description': {'LaTeX': 'U_L'}},
#   'rotation': 'Vu'},
#  {'Block': 'MatterField',
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'EL',
#   'Parents': 'eL',
#   'Properties': {'Chirality': 'left',
#    'Interaction_basis': ['eL'],
#    'Lorentz': 'WeylFermion',
#    'Mass_basis': 'EL',
#    'update_Description': {'LaTeX': 'E_L'}},
#   'rotation': 'Ve'},
#  {'Block': 'MatterField',
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'DR',
#   'Parents': 'conj[dR]',
#   'Properties': {'Chirality': 'right',
#    'Interaction_basis': ['conj[dR]'],
#    'Lorentz': 'WeylFermion',
#    'Mass_basis': 'DR',
#    'update_Description': {'LaTeX': 'D_R'}},
#   'rotation': 'Ud'},
#  {'Block': 'MatterField',
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'UR',
#   'Parents': 'conj[uR]',
#   'Properties': {'Chirality': 'right',
#    'Interaction_basis': ['conj[uR]'],
#    'Lorentz': 'WeylFermion',
#    'Mass_basis': 'UR',
#    'update_Description': {'LaTeX': 'U_R'}},
#   'rotation': 'Uu'},
#  {'Block': 'MatterField',
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'ER',
#   'Parents': 'conj[eR]',
#   'Properties': {'Chirality': 'right',
#    'Interaction_basis': ['conj[eR]'],
#    'Lorentz': 'WeylFermion',
#    'Mass_basis': 'ER',
#    'update_Description': {'LaTeX': 'E_R'}},
#   'rotation': 'Ue'},
#  {'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Description': 'Up-Quarks',
#   'Field': 'Fu',
#   'Parents': 'UL',
#   'Properties': {'DiracSpinor': ['UL', 'conj[UR]'], 'Lorentz': 'DiracSpinor'},
#   'rotation': None},
#  {'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Description': 'Neutrinos',
#   'Field': 'Fv',
#   'Parents': 'vL',
#   'Properties': {'Lorentz': 'MajoranaSpinor', 'MajoranaSpinor': ['vL', 0]},
#   'rotation': None},
#  {'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Description': 'Leptons',
#   'Field': 'Fe',
#   'Parents': 'EL',
#   'Properties': {'DiracSpinor': ['EL', 'conj[ER]'], 'Lorentz': 'DiracSpinor'},
#   'rotation': None},
#  {'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Description': 'Down-Quarks',
#   'Field': 'Fd',
#   'Parents': 'DL',
#   'Properties': {'DiracSpinor': ['DL', 'conj[DR]'], 'Lorentz': 'DiracSpinor'},
#   'rotation': None}]

# %%
f=open('JSON/fullparticles.json','w')
json.dump(newparticles,f)
f.close()

# %%
df=pd.read_json('JSON/fullparticles.json')
df=df.where((pd.notnull(df)), None)

# %%
nprt=df#pd.DataFrame(newparticles)

# %%
nprt
# Out:
#            Block                  Definition          Description Field  \
# 0           None                     GaugeES              B-Boson    VB
# 1           None                     GaugeES        B-Boson Ghost    gB
# 2           None                     GaugeES             W-Bosons   VWB
# 3           None                     GaugeES        W-Boson Ghost   gWB
# 4           None                     GaugeES                Gluon    VG
# 5           None                     GaugeES          Gluon Ghost    gG
# 6           None  WeylFermionAndIndermediate                 None     q
# 7           None  WeylFermionAndIndermediate                 None     l
# 8           None  WeylFermionAndIndermediate                 None     d
# 9           None  WeylFermionAndIndermediate                 None     u
# 10          None  WeylFermionAndIndermediate                 None     e
# 11          None  WeylFermionAndIndermediate                 None     H
# 12          None                     GaugeES                 None    Hp
# 13          None                        EWSB        Charged Higgs    Hp
# 14          None                     GaugeES                 None    H0
# 15          VEVs                        EWSB                Higgs    hh
# 16          VEVs                        EWSB  Pseudo-Scalar Higgs    Ah
# 17          None  WeylFermionAndIndermediate                 None    uL
# 18          None  WeylFermionAndIndermediate                 None    dL
# 19          None  WeylFermionAndIndermediate                 None    vL
# 20          None  WeylFermionAndIndermediate                 None    eL
# 21          None  WeylFermionAndIndermediate                 None    dR
# 22          None  WeylFermionAndIndermediate                 None    uR
# 23          None  WeylFermionAndIndermediate                 None    eR
# 24   MatterField  WeylFermionAndIndermediate                 None    DL
# 25   MatterField  WeylFermionAndIndermediate                 None    UL
# 26   MatterField  WeylFermionAndIndermediate                 None    EL
# 27   MatterField  WeylFermionAndIndermediate                 None    DR
# 28   MatterField  WeylFermionAndIndermediate                 None    UR
# 29   MatterField  WeylFermionAndIndermediate                 None    ER
# 30  DiracSpinors                        EWSB            Up-Quarks    Fu
# 31  DiracSpinors                        EWSB            Neutrinos    Fv
# 32  DiracSpinors                        EWSB              Leptons    Fe
# 33  DiracSpinors                        EWSB          Down-Quarks    Fd
#
#      Parents  \
# 0       None
# 1         VB
# 2       None
# 3        VWB
# 4       None
# 5         VG
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12         H
# 13        Hp
# 14         H
# 15        H0
# 16        H0
# 17         q
# 18         q
# 19         l
# 20         l
# 21         d
# 22         u
# 23         e
# 24        dL
# 25        uL
# 26        eL
# 27  conj[dR]
# 28  conj[uR]
# 29  conj[eR]
# 30        UL
# 31        vL
# 32        EL
# 33        DL
#
#                                                                                                                                                                                         Properties  \
# 0                                                                                              {'Group': '   U[1]', 'SSB': ' g1', 'Lorentz': 'Vector', 'Coupling': ' g1', 'Index': ' hypercharge'}
# 1                                                                                                                                                        {'Group': '   U[1]', 'Lorentz': 'Scalar'}
# 2                                                                                        {'Group': ' SU[2]', 'SSB': '        g2', 'Lorentz': 'Vector', 'Coupling': '        g2', 'Index': ' left'}
# 3                                                                                                                                                         {'Group': ' SU[2]', 'Lorentz': 'Scalar'}
# 4                                                                                        {'Group': '  SU[3]', 'SSB': '       g3', 'Lorentz': 'Vector', 'Coupling': '       g3', 'Index': ' color'}
# 5                                                                                                                                                        {'Group': '  SU[3]', 'Lorentz': 'Scalar'}
# 6                                                              {'NF': '3', 'update_Description': {'LaTeX': 'q'}, 'Groups': ['1/6', '2', '3'], 'Lorentz': 'WeylFermion', 'multiplet': ['uL', 'dL']}
# 7                                                             {'NF': '3', 'update_Description': {'LaTeX': 'l'}, 'Groups': ['-1/2', '2', '1'], 'Lorentz': 'WeylFermion', 'multiplet': ['vL', 'eL']}
# 8                                                                                        {'NF': '3', 'update_Description': {'LaTeX': 'd'}, 'Groups': ['1/3', '1', '-3'], 'Lorentz': 'WeylFermion'}
# 9                                                                                       {'NF': '3', 'update_Description': {'LaTeX': 'u'}, 'Groups': ['-2/3', '1', '-3'], 'Lorentz': 'WeylFermion'}
# 10                                                                                          {'NF': '3', 'update_Description': {'LaTeX': 'e'}, 'Groups': ['1', '1', '1'], 'Lorentz': 'WeylFermion'}
# 11  {'NF': '1', 'update_Description': {'LaTeX': 'H', 'PDG': [0], 'Mass': 'Automatic', 'Width': 0, 'OutputName': 'H'}, 'Groups': ['1/2', '2', '1'], 'Lorentz': 'Scalar', 'multiplet': ['Hp', 'H0']}
# 12                                      {'NF': '1', 'update_Description': {'Mass': 'Automatic', 'FeynArtsNr': 2, 'OutputName': 'Hp', 'LaTeX': 'H^+', 'PDG': [0], 'Width': 0}, 'Lorentz': 'Scalar'}
# 13        {'NF': '1', 'update_Description': {'Mass': [0], 'Width': [0], 'PDG.IX': [0], 'ElectricCharge': 1, 'LaTeX': ['H^+', 'H^-'], 'PDG': [0], 'OutputName': ['Hp', 'Hm']}, 'Lorentz': 'Scalar'}
# 14                                      {'NF': '1', 'update_Description': {'Mass': 'Automatic', 'FeynArtsNr': 1, 'OutputName': 'H0', 'LaTeX': 'H^0', 'PDG': [0], 'Width': 0}, 'Lorentz': 'Scalar'}
# 15                                                         {'vev': 'v', 'CP': 'Real', 'Lorentz': 'Scalar', 'Coefficient': '1/Sqrt[2]', 'update_Description': {'PDG': [25], 'PDG.IX': [101000001]}}
# 16                      {'vev': 'v', 'CP': 'Imaginary', 'Lorentz': 'Scalar', 'Coefficient': '\[ImaginaryI]/Sqrt[2]', 'update_Description': {'PDG': [0], 'Mass': [0], 'Width': [0], 'PDG.IX': [0]}}
# 17                                                                                                                   {'NF': '3', 'update_Description': {'LaTeX': 'u_L'}, 'Lorentz': 'WeylFermion'}
# 18                                                                                                                   {'NF': '3', 'update_Description': {'LaTeX': 'd_L'}, 'Lorentz': 'WeylFermion'}
# 19                                                                                                                 {'NF': '3', 'update_Description': {'LaTeX': '\nu_L'}, 'Lorentz': 'WeylFermion'}
# 20                                                                                                                   {'NF': '3', 'update_Description': {'LaTeX': 'e_L'}, 'Lorentz': 'WeylFermion'}
# 21                                                                                                                   {'NF': '3', 'update_Description': {'LaTeX': 'd_R'}, 'Lorentz': 'WeylFermion'}
# 22                                                                                                                   {'NF': '3', 'update_Description': {'LaTeX': 'u_R'}, 'Lorentz': 'WeylFermion'}
# 23                                                                                                                   {'NF': '3', 'update_Description': {'LaTeX': 'e_R'}, 'Lorentz': 'WeylFermion'}
# 24                                                        {'update_Description': {'LaTeX': 'D_L'}, 'Mass_basis': 'DL', 'Lorentz': 'WeylFermion', 'Interaction_basis': ['dL'], 'Chirality': 'left'}
# 25                                                        {'update_Description': {'LaTeX': 'U_L'}, 'Mass_basis': 'UL', 'Lorentz': 'WeylFermion', 'Interaction_basis': ['uL'], 'Chirality': 'left'}
# 26                                                        {'update_Description': {'LaTeX': 'E_L'}, 'Mass_basis': 'EL', 'Lorentz': 'WeylFermion', 'Interaction_basis': ['eL'], 'Chirality': 'left'}
# 27                                                 {'update_Description': {'LaTeX': 'D_R'}, 'Mass_basis': 'DR', 'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[dR]'], 'Chirality': 'right'}
# 28                                                 {'update_Description': {'LaTeX': 'U_R'}, 'Mass_basis': 'UR', 'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[uR]'], 'Chirality': 'right'}
# 29                                                 {'update_Description': {'LaTeX': 'E_R'}, 'Mass_basis': 'ER', 'Lorentz': 'WeylFermion', 'Interaction_basis': ['conj[eR]'], 'Chirality': 'right'}
# 30                                                                                                                                   {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['UL', 'conj[UR]']}
# 31                                                                                                                                      {'Lorentz': 'MajoranaSpinor', 'MajoranaSpinor': ['vL', 0]}
# 32                                                                                                                                   {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['EL', 'conj[ER]']}
# 33                                                                                                                                   {'Lorentz': 'DiracSpinor', 'DiracSpinor': ['DL', 'conj[DR]']}
#
#    rotation
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24       Vd
# 25       Vu
# 26       Ve
# 27       Ud
# 28       Uu
# 29       Ue
# 30     None
# 31     None
# 32     None
# 33     None

# %%
ParticleDefinitions={}
for k  in list(set( [d.get('Definition') for d in newparticles] )):
    ParticleDefinitions.update({k:{}})

for d in newparticles:
    #print(d.get('Field'))
    ParticleDefinitions[d.get('Definition')].update(
                                      {d.get('Field'): {}}
                                                   )
    if d.get('Description'):
        ParticleDefinitions[d.get('Definition')][d.get('Field')].update(
               {'Description':d.get('Description')})
    ud=d.get('Properties').get('update_Description')
    if ud:
        ParticleDefinitions[d.get('Definition')][d.get('Field')].update(
              ud )

# %%
ParticleDefinitions
# Out:
# {'EWSB': {'Ah': {'Description': 'Pseudo-Scalar Higgs',
#    'Mass': [0],
#    'PDG': [0],
#    'PDG.IX': [0],
#    'Width': [0]},
#   'Fd': {'Description': 'Down-Quarks'},
#   'Fe': {'Description': 'Leptons'},
#   'Fu': {'Description': 'Up-Quarks'},
#   'Fv': {'Description': 'Neutrinos'},
#   'Hp': {'Description': 'Charged Higgs',
#    'ElectricCharge': 1,
#    'LaTeX': ['H^+', 'H^-'],
#    'Mass': [0],
#    'OutputName': ['Hp', 'Hm'],
#    'PDG': [0],
#    'PDG.IX': [0],
#    'Width': [0]},
#   'hh': {'Description': 'Higgs', 'PDG': [25], 'PDG.IX': [101000001]}},
#  'GaugeES': {'H0': {'FeynArtsNr': 1,
#    'LaTeX': 'H^0',
#    'Mass': 'Automatic',
#    'OutputName': 'H0',
#    'PDG': [0],
#    'Width': 0},
#   'Hp': {'FeynArtsNr': 2,
#    'LaTeX': 'H^+',
#    'Mass': 'Automatic',
#    'OutputName': 'Hp',
#    'PDG': [0],
#    'Width': 0},
#   'VB': {'Description': 'B-Boson'},
#   'VG': {'Description': 'Gluon'},
#   'VWB': {'Description': 'W-Bosons'},
#   'gB': {'Description': 'B-Boson Ghost'},
#   'gG': {'Description': 'Gluon Ghost'},
#   'gWB': {'Description': 'W-Boson Ghost'}},
#  'WeylFermionAndIndermediate': {'DL': {'LaTeX': 'D_L'},
#   'DR': {'LaTeX': 'D_R'},
#   'EL': {'LaTeX': 'E_L'},
#   'ER': {'LaTeX': 'E_R'},
#   'H': {'LaTeX': 'H',
#    'Mass': 'Automatic',
#    'OutputName': 'H',
#    'PDG': [0],
#    'Width': 0},
#   'UL': {'LaTeX': 'U_L'},
#   'UR': {'LaTeX': 'U_R'},
#   'd': {'LaTeX': 'd'},
#   'dL': {'LaTeX': 'd_L'},
#   'dR': {'LaTeX': 'd_R'},
#   'e': {'LaTeX': 'e'},
#   'eL': {'LaTeX': 'e_L'},
#   'eR': {'LaTeX': 'e_R'},
#   'l': {'LaTeX': 'l'},
#   'q': {'LaTeX': 'q'},
#   'u': {'LaTeX': 'u'},
#   'uL': {'LaTeX': 'u_L'},
#   'uR': {'LaTeX': 'u_R'},
#   'vL': {'LaTeX': '\\nu_L'}}}

# %%
f=open('JSON/newparticles.json','w')
json.dump(ParticleDefinitions,f)
f.close()

# %%
dfnp=pd.read_json('JSON/newparticles.json')

# %%
kk=to_math(dfnp,'particles.m')

# %%
cat particles.m
# Out:
# ParticleDefinitions[EWSB] = {
#     {Ah, { Description -> "Pseudo-Scalar Higgs",
#            PDG -> {0},
#            Mass -> {0},
#            Width -> {0},
#            PDG.IX -> {0}}},
#     {Fd, { Description -> "Down-Quarks"}},
#     {Fe, { Description -> "Leptons"}},
#     {Fu, { Description -> "Up-Quarks"}},
#     {Fv, { Description -> "Neutrinos"}},
#     {Hp, { Description -> "Charged Higgs",
#            LaTeX -> {"H^+", "H^-"},
#            Width -> {0},
#            PDG.IX -> {0},
#            ElectricCharge -> 1,
#            OutputName -> {"Hp", "Hm"},
#            PDG -> {0},
#            Mass -> {0}}},
#     {hh, { Description -> "Higgs",
#            PDG -> {25},
#            PDG.IX -> {101000001}}}
# };
#
# ParticleDefinitions[GaugeES] = {
#     {H0, { Mass -> Automatic,
#            FeynArtsNr -> 1,
#            OutputName -> H0,
#            LaTeX -> "H^0",
#            PDG -> {0},
#            Width -> 0}},
#     {Hp, { Mass -> Automatic,
#            FeynArtsNr -> 2,
#            OutputName -> Hp,
#            LaTeX -> "H^+",
#            PDG -> {0},
#            Width -> 0}},
#     {VB, { Description -> "B-Boson"}},
#     {VG, { Description -> "Gluon"}},
#     {VWB, { Description -> "W-Bosons"}},
#     {gB, { Description -> "B-Boson Ghost"}},
#     {gG, { Description -> "Gluon Ghost"}},
#     {gWB, { Description -> "W-Boson Ghost"}}
# };
#
# ParticleDefinitions[WeylFermionAndIndermediate] = {
#     {DL, { LaTeX -> "D_L"}},
#     {DR, { LaTeX -> "D_R"}},
#     {EL, { LaTeX -> "E_L"}},
#     {ER, { LaTeX -> "E_R"}},
#     {H, { LaTeX -> "H",
#            PDG -> {0},
#            Mass -> Automatic,
#            Width -> 0,
#            OutputName -> H}},
#     {UL, { LaTeX -> "U_L"}},
#     {UR, { LaTeX -> "U_R"}},
#     {d, { LaTeX -> "d"}},
#     {dL, { LaTeX -> "d_L"}},
#     {dR, { LaTeX -> "d_R"}},
#     {e, { LaTeX -> "e"}},
#     {eL, { LaTeX -> "e_L"}},
#     {eR, { LaTeX -> "e_R"}},
#     {l, { LaTeX -> "l"}},
#     {q, { LaTeX -> "q"}},
#     {u, { LaTeX -> "u"}},
#     {uL, { LaTeX -> "u_L"}},
#     {uR, { LaTeX -> "u_R"}},
#     {vL, { LaTeX -> "\nu_L"}}
# };

# %%
print(smf)
# Out:
# Off[General::spell]
#
# Model`Name = "SM";
# Model`NameLaTeX ="Standard Model";
# Model`Authors = "F.Staub";
# Model`Date = "2014-11-06";
#
# (* 2013-01-24: changed normalization of lambda term to convention of hep-ph/0207271 *)
# (* 2013-06-24: using new name conventions (without inital "S" and "F" for scalar and matter fields) *)
# (* 2013-09-01: changing to new conventions for FermionFields/MatterFields *)
# (* 2014-11-06: Changed sign in Lagrangian to fit standard conventions *)
# (* 2016-05-03: Changed sign of Yu *)
#
#
#
# (*-------------------------------------------*)
# (*   Particle Content*)
# (*-------------------------------------------*)
#
# (* Gauge Groups *)
#
# Gauge[[1]]={B,   U[1], hypercharge, g1,False};
# Gauge[[2]]={WB, SU[2], left,        g2,True};
# Gauge[[3]]={G,  SU[3], color,       g3,False};
#
#
# (* Matter Fields *)
#
# FermionFields[[1]] = {q, 3, {uL, dL},     1/6, 2,  3};
# FermionFields[[2]] = {l, 3, {vL, eL},    -1/2, 2,  1};
# FermionFields[[3]] = {d, 3, conj[dR],     1/3, 1, -3};
# FermionFields[[4]] = {u, 3, conj[uR],    -2/3, 1, -3};
# FermionFields[[5]] = {e, 3, conj[eR],       1, 1,  1};
#
# ScalarFields[[1]] =  {H, 1, {Hp, H0},     1/2, 2,  1};
#
#
#
# (*----------------------------------------------*)
# (*   DEFINITION                                 *)
# (*----------------------------------------------*)
#
# NameOfStates={GaugeES, EWSB};
#
# (* ----- Before EWSB ----- *)
#
# DEFINITION[GaugeES][LagrangianInput]= {
# 	{LagHC, {AddHC->True}},
# 	{LagNoHC,{AddHC->False}}
# };
#
#
# LagNoHC = -mu2 conj[H].H - 1/2 \[Lambda] conj[H].H.conj[H].H;
# LagHC =  -(Yd conj[H].d.q + Ye conj[H].e.l + Yu u.q.H);
#
#
#
#
# (* Gauge Sector *)
#
# DEFINITION[EWSB][GaugeSector] =
# {
#   {{VB,VWB[3]},{VP,VZ},ZZ},
#   {{VWB[1],VWB[2]},{VWp,conj[VWp]},ZW}
# };
#
#
#
#
# (* ----- VEVs ---- *)
#
# DEFINITION[EWSB][VEVs]=
# {    {H0, {v, 1/Sqrt[2]}, {Ah, \[ImaginaryI]/Sqrt[2]},{hh, 1/Sqrt[2]}}     };
#
#
# DEFINITION[EWSB][MatterSector]=
#     {{{{dL}, {conj[dR]}}, {{DL,Vd}, {DR,Ud}}},
#      {{{uL}, {conj[uR]}}, {{UL,Vu}, {UR,Uu}}},
#      {{{eL}, {conj[eR]}}, {{EL,Ve}, {ER,Ue}}}};
#
#
# (*------------------------------------------------------*)
# (* Dirac-Spinors *)
# (*------------------------------------------------------*)
#
# DEFINITION[EWSB][DiracSpinors]={
#  Fd ->{  DL, conj[DR]},
#  Fe ->{  EL, conj[ER]},
#  Fu ->{  UL, conj[UR]},
#  Fv ->{  vL, 0}};
#
# DEFINITION[EWSB][GaugeES]={
#  Fd1 ->{  FdL, 0},
#  Fd2 ->{  0, FdR},
#  Fu1 ->{  Fu1, 0},
#  Fu2 ->{  0, Fu2},
#  Fe1 ->{  Fe1, 0},
#  Fe2 ->{  0, Fe2}};

# %%
1+1
# Out:
# 2
