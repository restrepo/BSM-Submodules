# %% [markdown]
# <a href="https://colab.research.google.com/github/restrepo/BSM-Submodules/blob/master/particles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Particles generator

# %% [markdown]
# ## Dictionary design for JSON output

# %% [markdown]
# The SM will be defined as pandas file in JSON format.
# In this file it will be shown the definition of such a file from a dictionary

# %%
#TODO: Initialize objects
particles=[]
particlessons=[]

Fields=['Gauge','FermionFields','ScalarFields']
NAME='DEFINITION'
KEY='EWSB'
# Get also particles from
#NAME[KEY] dictionary!

# %%
import pandas as pd
import numpy as np
import json
# import re, cmdlike as cmd, OrdereDict, json
from SARAH import *
pd.set_option('display.max_colwidth',200)

# %%
cat kk.json | cut -c1-80
# Out:
# {"EWSB":{"Ah":{"Mass":[0],"PDG.IX":[0],"PDG":[0],"Description":"Pseudo-Scalar Hi

# %% [markdown]
# Build SM as dictionary to feed pandas

# %%
#Matter fields
# LaTeX backslash as \\\\
str_keys=['LaTeX','OutputName','Description']
lst_keys=['PDG','PDG.IX']
ParticleDefinitions={'GaugeES':
                             {'H0':{'PDG'  :[0],
                                    'Width':0,
                                    'Mass' : 'Automatic',
                                    'FeynArtsNr' : 1,
                                    'LaTeX' : 'H^0',
                                    'OutputName' : 'H0'                                   
                                   },
                              'Hp':{'PDG'  :[0],
                                    'Width':0,
                                    'Mass' : 'Automatic',
                                    'FeynArtsNr' : 2,
                                    'LaTeX' : 'H^+',
                                    'OutputName' : 'Hp'                                   
                                   },
                              'VB' : {'Description' :'B-Boson'      },                                                   
                              'VG' : {'Description' :'Gluon'        },          
                              'VWB': {'Description' :'W-Bosons'     },          
                              'gB' : {'Description' :'B-Boson Ghost'},                                                   
                              'gG' : {'Description' :'Gluon Ghost'  },          
                              'gWB': {'Description' :'W-Boson Ghost'}
                             },
                            'EWSB':
                            {                                
                            },
                            'WeylFermionAndIndermediate':
                            {   
                            }
                           }

ParticleDefinitions['EWSB']['hh']={'Description' : 'Higgs',
                                   'PDG'         : [25],
                                   'PDG.IX'      : [101000001]}
ParticleDefinitions['EWSB']['Ah']={'Description' : "Pseudo-Scalar Higgs",
                                   'PDG'         : [0],
                                   'PDG.IX'      : [0],
                                   'Mass'        : [0],
                                   'Width'       : [0]
                                   }
ParticleDefinitions['EWSB']['Hp']={'Description'    : 'Charged Higgs', 
                                   'PDG'            : [0],
                                   'PDG.IX'         : [0],
                                   'Width'          : [0], 
                                   'Mass'           : [0],
                                   'LaTeX'          : ['H^+','H^-' ],
                                   'OutputName'     : ['Hp' ,'Hm'  ],
                                   'ElectricCharge' : 1
                                   }

ParticleDefinitions['EWSB']['VP']  =  { 'Description' : 'Photon'}
ParticleDefinitions['EWSB']['VZ']  =  { 'Description' : 'Z-Boson',
                                        'Goldstone' : 'Ah' }
ParticleDefinitions['EWSB']['VG']  =  { 'Description' : 'Gluon' }
ParticleDefinitions['EWSB']['VWp'] =  { 'Description' : 'W+ - Boson',
                                        'Goldstone': 'Hp' }
ParticleDefinitions['EWSB']['gP']  =  { 'Description' : 'Photon Ghost'}
ParticleDefinitions['EWSB']['gWp'] =  { 'Description' : 'Positive W+ - Boson Ghost'}
ParticleDefinitions['EWSB']['gWpC']=  { 'Description' : 'Negative W+ - Boson Ghost' }
ParticleDefinitions['EWSB']['gZ']  =  { 'Description' : 'Z-Boson Ghost' }
ParticleDefinitions['EWSB']['gG']  =  { 'Description' : 'Gluon Ghost' }
ParticleDefinitions['EWSB']['Fd']  =  { 'Description' : 'Down-Quarks'}
ParticleDefinitions['EWSB']['Fu']  =  { 'Description' : 'Up-Quarks'}
ParticleDefinitions['EWSB']['Fe']  =  { 'Description' : 'Leptons' }
ParticleDefinitions['EWSB']['Fv']  =  { 'Description' : 'Neutrinos' }

ParticleDefinitions['WeylFermionAndIndermediate']['H' ] = {'PDG'       : [0],
                                                           'Width'     : 0,
                                                           'Mass'      : 'Automatic',
                                                           'LaTeX'     : 'H',
                                                           'OutputName': 'H' }
ParticleDefinitions['WeylFermionAndIndermediate']['dR'] = {'LaTeX' : 'd_R'   }
ParticleDefinitions['WeylFermionAndIndermediate']['eR'] = {'LaTeX' : 'e_R'   }
ParticleDefinitions['WeylFermionAndIndermediate']['l' ] = {'LaTeX' : 'l'     }
ParticleDefinitions['WeylFermionAndIndermediate']['uR'] = {'LaTeX' : 'u_R'   }
ParticleDefinitions['WeylFermionAndIndermediate']['q' ] = {'LaTeX' : 'q'     }
ParticleDefinitions['WeylFermionAndIndermediate']['eL'] = {'LaTeX' : 'e_L'   }
ParticleDefinitions['WeylFermionAndIndermediate']['dL'] = {'LaTeX' : 'd_L'   }
ParticleDefinitions['WeylFermionAndIndermediate']['uL'] = {'LaTeX' : 'u_L'   }
ParticleDefinitions['WeylFermionAndIndermediate']['vL'] = {'LaTeX' : '\\\\nu_L'}
ParticleDefinitions['WeylFermionAndIndermediate']['DR'] = {'LaTeX' : 'D_R'   }
ParticleDefinitions['WeylFermionAndIndermediate']['ER'] = {'LaTeX' : 'E_R'   }
ParticleDefinitions['WeylFermionAndIndermediate']['UR'] = {'LaTeX' : 'U_R'   }
ParticleDefinitions['WeylFermionAndIndermediate']['EL'] = {'LaTeX' : 'E_L'   }
ParticleDefinitions['WeylFermionAndIndermediate']['DL'] = {'LaTeX' : 'D_L'   }
ParticleDefinitions['WeylFermionAndIndermediate']['UL'] = {'LaTeX' : 'U_L'   }

# %% [markdown]
# Example to modify dictionary entry

# %%
ParticleDefinitions['GaugeES']['H0']['FeynArtsNr']=1

# %% [markdown]
# ## Save as JSON

# %%
f=open('JSON/particles.json','w')
json.dump(ParticleDefinitions,f)
f.close()

# %% [markdown]
# Check if `pandas` can read it

# %%
pd.read_json('JSON/particles.json').loc['Hp']['EWSB']
# Out:
# {'Description': 'Charged Higgs',
#  'ElectricCharge': 1,
#  'LaTeX': ['H^+', 'H^-'],
#  'Mass': [0],
#  'OutputName': ['Hp', 'Hm'],
#  'PDG': [0],
#  'PDG.IX': [0],
#  'Width': [0]}

# %% [markdown]
# ## Feed a `pandas` `DataFrame`

# %%
SM=pd.DataFrame( ParticleDefinitions  )

# %%
SM
# Out:
#                                                                                                                                                                   EWSB  \
# Ah                                                                        {'Width': [0], 'PDG.IX': [0], 'PDG': [0], 'Mass': [0], 'Description': 'Pseudo-Scalar Higgs'}
# DL                                                                                                                                                                 NaN
# DR                                                                                                                                                                 NaN
# EL                                                                                                                                                                 NaN
# ER                                                                                                                                                                 NaN
# Fd                                                                                                                                      {'Description': 'Down-Quarks'}
# Fe                                                                                                                                          {'Description': 'Leptons'}
# Fu                                                                                                                                        {'Description': 'Up-Quarks'}
# Fv                                                                                                                                        {'Description': 'Neutrinos'}
# H                                                                                                                                                                  NaN
# H0                                                                                                                                                                 NaN
# Hp    {'OutputName': ['Hp', 'Hm'], 'PDG': [0], 'Mass': [0], 'Width': [0], 'ElectricCharge': 1, 'PDG.IX': [0], 'LaTeX': ['H^+', 'H^-'], 'Description': 'Charged Higgs'}
# UL                                                                                                                                                                 NaN
# UR                                                                                                                                                                 NaN
# VB                                                                                                                                                                 NaN
# VG                                                                                                                                            {'Description': 'Gluon'}
# VP                                                                                                                                           {'Description': 'Photon'}
# VWB                                                                                                                                                                NaN
# VWp                                                                                                                   {'Goldstone': 'Hp', 'Description': 'W+ - Boson'}
# VZ                                                                                                                       {'Goldstone': 'Ah', 'Description': 'Z-Boson'}
# dL                                                                                                                                                                 NaN
# dR                                                                                                                                                                 NaN
# eL                                                                                                                                                                 NaN
# eR                                                                                                                                                                 NaN
# gB                                                                                                                                                                 NaN
# gG                                                                                                                                      {'Description': 'Gluon Ghost'}
# gP                                                                                                                                     {'Description': 'Photon Ghost'}
# gWB                                                                                                                                                                NaN
# gWp                                                                                                                       {'Description': 'Positive W+ - Boson Ghost'}
# gWpC                                                                                                                      {'Description': 'Negative W+ - Boson Ghost'}
# gZ                                                                                                                                    {'Description': 'Z-Boson Ghost'}
# hh                                                                                                        {'PDG.IX': [101000001], 'PDG': [25], 'Description': 'Higgs'}
# l                                                                                                                                                                  NaN
# q                                                                                                                                                                  NaN
# uL                                                                                                                                                                 NaN
# uR                                                                                                                                                                 NaN
# vL                                                                                                                                                                 NaN
#
#                                                                                                  GaugeES  \
# Ah                                                                                                   NaN
# DL                                                                                                   NaN
# DR                                                                                                   NaN
# EL                                                                                                   NaN
# ER                                                                                                   NaN
# Fd                                                                                                   NaN
# Fe                                                                                                   NaN
# Fu                                                                                                   NaN
# Fv                                                                                                   NaN
# H                                                                                                    NaN
# H0    {'OutputName': 'H0', 'PDG': [0], 'Mass': 'Automatic', 'Width': 0, 'FeynArtsNr': 1, 'LaTeX': 'H^0'}
# Hp    {'OutputName': 'Hp', 'PDG': [0], 'Mass': 'Automatic', 'Width': 0, 'FeynArtsNr': 2, 'LaTeX': 'H^+'}
# UL                                                                                                   NaN
# UR                                                                                                   NaN
# VB                                                                            {'Description': 'B-Boson'}
# VG                                                                              {'Description': 'Gluon'}
# VP                                                                                                   NaN
# VWB                                                                          {'Description': 'W-Bosons'}
# VWp                                                                                                  NaN
# VZ                                                                                                   NaN
# dL                                                                                                   NaN
# dR                                                                                                   NaN
# eL                                                                                                   NaN
# eR                                                                                                   NaN
# gB                                                                      {'Description': 'B-Boson Ghost'}
# gG                                                                        {'Description': 'Gluon Ghost'}
# gP                                                                                                   NaN
# gWB                                                                     {'Description': 'W-Boson Ghost'}
# gWp                                                                                                  NaN
# gWpC                                                                                                 NaN
# gZ                                                                                                   NaN
# hh                                                                                                   NaN
# l                                                                                                    NaN
# q                                                                                                    NaN
# uL                                                                                                   NaN
# uR                                                                                                   NaN
# vL                                                                                                   NaN
#
#                                                           WeylFermionAndIndermediate
# Ah                                                                               NaN
# DL                                                                  {'LaTeX': 'D_L'}
# DR                                                                  {'LaTeX': 'D_R'}
# EL                                                                  {'LaTeX': 'E_L'}
# ER                                                                  {'LaTeX': 'E_R'}
# Fd                                                                               NaN
# Fe                                                                               NaN
# Fu                                                                               NaN
# Fv                                                                               NaN
# H     {'Width': 0, 'OutputName': 'H', 'PDG': [0], 'Mass': 'Automatic', 'LaTeX': 'H'}
# H0                                                                               NaN
# Hp                                                                               NaN
# UL                                                                  {'LaTeX': 'U_L'}
# UR                                                                  {'LaTeX': 'U_R'}
# VB                                                                               NaN
# VG                                                                               NaN
# VP                                                                               NaN
# VWB                                                                              NaN
# VWp                                                                              NaN
# VZ                                                                               NaN
# dL                                                                  {'LaTeX': 'd_L'}
# dR                                                                  {'LaTeX': 'd_R'}
# eL                                                                  {'LaTeX': 'e_L'}
# eR                                                                  {'LaTeX': 'e_R'}
# gB                                                                               NaN
# gG                                                                               NaN
# gP                                                                               NaN
# gWB                                                                              NaN
# gWp                                                                              NaN
# gWpC                                                                             NaN
# gZ                                                                               NaN
# hh                                                                               NaN
# l                                                                     {'LaTeX': 'l'}
# q                                                                     {'LaTeX': 'q'}
# uL                                                                  {'LaTeX': 'u_L'}
# uR                                                                  {'LaTeX': 'u_R'}
# vL                                                               {'LaTeX': '\\nu_L'}

# %% [markdown]
# Checks

# %%
SM['GaugeES']['H0']
# Out:
# {'FeynArtsNr': 1,
#  'LaTeX': 'H^0',
#  'Mass': 'Automatic',
#  'OutputName': 'H0',
#  'PDG': [0],
#  'Width': 0}

# %%
SM['EWSB']['VZ']
# Out:
# {'Description': 'Z-Boson', 'Goldstone': 'Ah'}

# %%
SM[:1]
# Out:
#                                                                                             EWSB  \
# Ah  {'Width': [0], 'PDG.IX': [0], 'PDG': [0], 'Mass': [0], 'Description': 'Pseudo-Scalar Higgs'}
#
#    GaugeES WeylFermionAndIndermediate
# Ah     NaN                        NaN

# %% [markdown]
# Show a particle

# %%
SM['GaugeES']['H0']
# Out:
# {'FeynArtsNr': 1,
#  'LaTeX': 'H^0',
#  'Mass': 'Automatic',
#  'OutputName': 'H0',
#  'PDG': [0],
#  'Width': 0}

# %% [markdown]
# Example: Modify particle property

# %%
SM['WeylFermionAndIndermediate']['dR'] = {'LaTeX' : 'd_R'   }

# %% [markdown]
# ## Load JSON
# Directly fromo the `json.dumps...`

# %%
BSM=pd.read_json('JSON/particles.json')#,lines=True,orient='records')

# %%
BSM[:1]
# Out:
#                                                                                             EWSB  \
# Ah  {'Width': [0], 'PDG': [0], 'Mass': [0], 'Description': 'Pseudo-Scalar Higgs', 'PDG.IX': [0]}
#
#    GaugeES WeylFermionAndIndermediate
# Ah     NaN                        NaN

# %%
BSM['GaugeES'].dropna()['H0']
# Out:
# {'FeynArtsNr': 1,
#  'LaTeX': 'H^0',
#  'Mass': 'Automatic',
#  'OutputName': 'H0',
#  'PDG': [0],
#  'Width': 0}

# %%
BSM['GaugeES']['H0']
# Out:
# {'FeynArtsNr': 1,
#  'LaTeX': 'H^0',
#  'Mass': 'Automatic',
#  'OutputName': 'H0',
#  'PDG': [0],
#  'Width': 0}

# %%
BSM['EWSB']['VZ']
# Out:
# {'Description': 'Z-Boson', 'Goldstone': 'Ah'}

# %%
BSM['WeylFermionAndIndermediate']['dR'] = {'LaTeX' : 'd_R'   }

# %%
BSM.loc['Ah','EWSB']
# Out:
# {'Description': 'Pseudo-Scalar Higgs',
#  'Mass': [0],
#  'PDG': [0],
#  'PDG.IX': [0],
#  'Width': [0]}

# %% [markdown]
# ## Export to files

# %%
SM=BSM.loc[['Ah', 'DL', 'DR', 'EL', 'ER', 'Fd', 'Fe', 'Fu', 'Fv', 'H', 'H0', 'Hp',
       'UL', 'UR', 'VB', 'VG', 'VP', 'VWB', 'VWp', 'VZ', 'dL', 'dR', 'eL',
       'eR', 'gB', 'gG', 'gP', 'gWB', 'gWp', 'gWpC', 'gZ', 'hh', 'l', 'q',
       'uL', 'uR', 'vL']]

# %%
CHECK_PANDAS_SAVED_JSON=False
if CHECK_PANDAS_SAVED_JSON:
    SM=pd.read_json('SM2.json')#,lines=True,orient='records')

# %%
print( to_math(SM,'p.m') )
# Out:
# ParticleDefinitions[EWSB] = {
#     {Ah, { Description -> "Pseudo-Scalar Higgs",
#            Width -> {0},
#            PDG -> {0},
#            Mass -> {0},
#            PDG.IX -> {0}}},
#     {Fd, { Description -> "Down-Quarks"}},
#     {Fe, { Description -> "Leptons"}},
#     {Fu, { Description -> "Up-Quarks"}},
#     {Fv, { Description -> "Neutrinos"}},
#     {Hp, { Description -> "Charged Higgs",
#            LaTeX -> {"H^+", "H^-"},
#            OutputName -> {"Hp", "Hm"},
#            PDG -> {0},
#            Mass -> {0},
#            Width -> {0},
#            ElectricCharge -> 1,
#            PDG.IX -> {0}}},
#     {VG, { Description -> "Gluon"}},
#     {VP, { Description -> "Photon"}},
#     {VWp, { Description -> "W+ - Boson",
#            Goldstone -> Hp}},
#     {VZ, { Description -> "Z-Boson",
#            Goldstone -> Ah}},
#     {gG, { Description -> "Gluon Ghost"}},
#     {gP, { Description -> "Photon Ghost"}},
#     {gWp, { Description -> "Positive W+ - Boson Ghost"}},
#     {gWpC, { Description -> "Negative W+ - Boson Ghost"}},
#     {gZ, { Description -> "Z-Boson Ghost"}},
#     {hh, { Description -> "Higgs",
#            PDG -> {25},
#            PDG.IX -> {101000001}}}
# };
#
# ParticleDefinitions[GaugeES] = {
#     {H0, { OutputName -> H0,
#            PDG -> {0},
#            Mass -> Automatic,
#            Width -> 0,
#            FeynArtsNr -> 1,
#            LaTeX -> "H^0"}},
#     {Hp, { OutputName -> Hp,
#            PDG -> {0},
#            Mass -> Automatic,
#            Width -> 0,
#            FeynArtsNr -> 2,
#            LaTeX -> "H^+"}},
#     {VB, { Description -> "B-Boson"}},
#     {VG, { Description -> "Gluon"}},
#     {VWB, { Description -> "W-Bosons"}},
#     {gB, { Description -> "B-Boson Ghost"}},
#     {gG, { Description -> "Gluon Ghost"}},
#     {gWB, { Description -> "W-Boson Ghost"}}
# };
#
# ParticleDefinitions[WeylFermionAndIndermediate] = {
#     {DL, { LaTeX -> "D_L"}},
#     {DR, { LaTeX -> "D_R"}},
#     {EL, { LaTeX -> "E_L"}},
#     {ER, { LaTeX -> "E_R"}},
#     {H, { Width -> 0,
#            OutputName -> H,
#            PDG -> {0},
#            Mass -> Automatic,
#            LaTeX -> "H"}},
#     {UL, { LaTeX -> "U_L"}},
#     {UR, { LaTeX -> "U_R"}},
#     {dL, { LaTeX -> "d_L"}},
#     {dR, { LaTeX -> "d_R"}},
#     {eL, { LaTeX -> "e_L"}},
#     {eR, { LaTeX -> "e_R"}},
#     {l, { LaTeX -> "l"}},
#     {q, { LaTeX -> "q"}},
#     {uL, { LaTeX -> "u_L"}},
#     {uR, { LaTeX -> "u_R"}},
#     {vL, { LaTeX -> "\\nu_L"}}
# };

# %% [markdown]
# # Get particle from model file

# %% [markdown]
# Design:
# * Intialize `particle` as an empty dictionary.
# * Intialize `particles` as an empty list.
# * Fill particle properties and build the list: `particles`
# * Internal defintions
#   * weyl: Charged Weyl fermion bidiagonal rotation object
#   * symm: Symmetric diagonalization system object
#   * vev:  Complex scalar decomposition

# %% [markdown]
# Implementation:
# 1. Get particles from particles definitions
# 2. Get particles from `DEFINITION[EWSB]`
#
# Assumptions:
#
# * SM doublet Higgs field is assigned `H`
# * Fermion doublets have decreasing Hypercharge, $Y$
# * $ Q=T_3+Y/2 $

# %% [markdown]
# ## Load Model file

# %%
import pandas as pd
from SARAH import *
pd.set_option('display.max_colwidth',200)
#TODO: Initialize objects
particles=[]
particlessons=[]

Fields=['Gauge','FermionFields','ScalarFields']
NAME='DEFINITION'
KEY='EWSB'

# %%
pwd
# Out:
# '/home/restrepo/tmp'

# %%
MODEL_PATH="./SARAH/Models/SM/SM.m"

# %%
f=open(MODEL_PATH,'r')

# %%
smf=f.read()
f.close()

# %%
smf
# Out:
# 'Off[General::spell]\n\nModel`Name = "SM";\nModel`NameLaTeX ="Standard Model";\nModel`Authors = "F.Staub";\nModel`Date = "2014-11-06";\n\n(* 2013-01-24: changed normalization of lambda term to convention of hep-ph/0207271 *)\n(* 2013-06-24: using new name conventions (without inital "S" and "F" for scalar and matter fields) *)\n(* 2013-09-01: changing to new conventions for FermionFields/MatterFields *)\n(* 2014-11-06: Changed sign in Lagrangian to fit standard conventions *)\n(* 2016-05-03: Changed sign of Yu *)\n\n\n\n(*-------------------------------------------*)\n(*   Particle Content*)\n(*-------------------------------------------*)\n\n(* Gauge Groups *)\n\nGauge[[1]]={B,   U[1], hypercharge, g1,False};\nGauge[[2]]={WB, SU[2], left,        g2,True};\nGauge[[3]]={G,  SU[3], color,       g3,False};\n\n\n(* Matter Fields *)\n\nFermionFields[[1]] = {q, 3, {uL, dL},     1/6, 2,  3};  \nFermionFields[[2]] = {l, 3, {vL, eL},    -1/2, 2,  1};\nFermionFields[[3]] = {d, 3, conj[dR],     1/3, 1, -3};\nFermionFields[[4]] = {u, 3, conj[uR],    -2/3, 1, -3};\nFermionFields[[5]] = {e, 3, conj[eR],       1, 1,  1};\n\nScalarFields[[1]] =  {H, 1, {Hp, H0},     1/2, 2,  1};\n\n\n        \n(*----------------------------------------------*)\n(*   DEFINITION                                 *)\n(*----------------------------------------------*)\n\nNameOfStates={GaugeES, EWSB};\n\n(* ----- Before EWSB ----- *)\n\nDEFINITION[GaugeES][LagrangianInput]= {\n\t{LagHC, {AddHC->True}},\n\t{LagNoHC,{AddHC->False}}\n};\n\n\nLagNoHC = -mu2 conj[H].H - 1/2 \\[Lambda] conj[H].H.conj[H].H;\nLagHC =  -(Yd conj[H].d.q + Ye conj[H].e.l + Yu u.q.H);\n\n\n\t\t\t  \t\t  \n\n(* Gauge Sector *)\n\nDEFINITION[EWSB][GaugeSector] =\n{ \n  {{VB,VWB[3]},{VP,VZ},ZZ},\n  {{VWB[1],VWB[2]},{VWp,conj[VWp]},ZW}\n};     \n        \n        \n          \t\n\n(* ----- VEVs ---- *)\n\nDEFINITION[EWSB][VEVs]= \n{    {H0, {v, 1/Sqrt[2]}, {Ah, \\[ImaginaryI]/Sqrt[2]},{hh, 1/Sqrt[2]}}     };\n \n\nDEFINITION[EWSB][MatterSector]=   \n    {{{{dL}, {conj[dR]}}, {{DL,Vd}, {DR,Ud}}},\n     {{{uL}, {conj[uR]}}, {{UL,Vu}, {UR,Uu}}},\n     {{{eL}, {conj[eR]}}, {{EL,Ve}, {ER,Ue}}}};  \n\n\n(*------------------------------------------------------*)\n(* Dirac-Spinors *)\n(*------------------------------------------------------*)\n\nDEFINITION[EWSB][DiracSpinors]={\n Fd ->{  DL, conj[DR]},\n Fe ->{  EL, conj[ER]},\n Fu ->{  UL, conj[UR]},\n Fv ->{  vL, 0}};\n\nDEFINITION[EWSB][GaugeES]={\n Fd1 ->{  FdL, 0},\n Fd2 ->{  0, FdR},\n Fu1 ->{  Fu1, 0},\n Fu2 ->{  0, Fu2},\n Fe1 ->{  Fe1, 0},\n Fe2 ->{  0, Fe2}};\n\n\n\n'

# %% [markdown]
# ## General definition

# %% [markdown]
# ## 1) Get particles from particles definitions

# %% [markdown]
# ### Obtain `particle` from
# * `Gauge` list
# * `FermionFields` list, with the components fields (intialized as `particlesson` `dict`) with parents information
# * `ScalarFields`  list, with the components fields (intialized as `particlesson` `dict`) with parents information
#
# and fill `particles`

# %%
particles=get_particles(smf,Fields,NAME,KEY,particles,particlessons)
# Out:
# ('B,   U[1], hypercharge, g1,False',) Gauge 5
# {'Field': 'VB', 'Parents': None, 'Properties': {'Group': '   U[1]', 'Coupling': ' g1', 'SSB': ' g1', 'Lorentz': 'Vector', 'Index': ' hypercharge'}, 'Definition': 'GaugeES'}
# ('WB, SU[2], left,        g2,True',) Gauge 5
# {'Field': 'VWB', 'Parents': None, 'Properties': {'Group': ' SU[2]', 'Coupling': '        g2', 'SSB': '        g2', 'Lorentz': 'Vector', 'Index': ' left'}, 'Definition': 'GaugeES'}
# ('G,  SU[3], color,       g3,False',) Gauge 5
# {'Field': 'VG', 'Parents': None, 'Properties': {'Group': '  SU[3]', 'Coupling': '       g3', 'SSB': '       g3', 'Lorentz': 'Vector', 'Index': ' color'}, 'Definition': 'GaugeES'}
# ('q, 3, uL:: dL,     1/6, 2,  3;  ',) FermionFields 6
# **********
#  uL:: dL [' uL', ' dL']
#  uL
#  dL
# **********
# ('l, 3, vL:: eL,    -1/2, 2,  1;',) FermionFields 6
# **********
#  vL:: eL [' vL', ' eL']
#  vL
#  eL
# **********
# ('d, 3, conj[dR],     1/3, 1, -3',) FermionFields 6
# **********
#  conj[dR] [' dR']
#  dR
# **********
# ('u, 3, conj[uR],    -2/3, 1, -3',) FermionFields 6
# **********
#  conj[uR] [' uR']
#  uR
# **********
# ('e, 3, conj[eR],       1, 1,  1',) FermionFields 6
# **********
#  conj[eR] [' eR']
#  eR
# **********
# ('H, 1, Hp:: H0,     1/2, 2,  1;',) ScalarFields 6
# **********
#  Hp:: H0 [' Hp', ' H0']
#  Hp
#  H0
# **********

# %%
particles
# Out:
# [{'Definition': 'GaugeES',
#   'Field': 'VB',
#   'Parents': None,
#   'Properties': {'Coupling': ' g1',
#    'Group': '   U[1]',
#    'Index': ' hypercharge',
#    'Lorentz': 'Vector',
#    'SSB': ' g1'}},
#  {'Definition': 'GaugeES',
#   'Field': 'VWB',
#   'Parents': None,
#   'Properties': {'Coupling': '        g2',
#    'Group': ' SU[2]',
#    'Index': ' left',
#    'Lorentz': 'Vector',
#    'SSB': '        g2'}},
#  {'Definition': 'GaugeES',
#   'Field': 'VG',
#   'Parents': None,
#   'Properties': {'Coupling': '       g3',
#    'Group': '  SU[3]',
#    'Index': ' color',
#    'Lorentz': 'Vector',
#    'SSB': '       g3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'q',
#   'Parents': None,
#   'Properties': {'Groups': ['1/6', '2', '3'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'multiplet': ['uL', 'dL']}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'l',
#   'Parents': None,
#   'Properties': {'Groups': ['-1/2', '2', '1'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'multiplet': ['vL', 'eL']}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'd',
#   'Parents': None,
#   'Properties': {'Groups': ['1/3', '1', '-3'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'u',
#   'Parents': None,
#   'Properties': {'Groups': ['-2/3', '1', '-3'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'e',
#   'Parents': None,
#   'Properties': {'Groups': ['1', '1', '1'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'H',
#   'Parents': None,
#   'Properties': {'Groups': ['1/2', '2', '1'],
#    'Lorentz': 'Scalar',
#    'NF': '1',
#    'multiplet': ['Hp', 'H0']}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'uL',
#   'Parents': 'q',
#   'Properties': {'Lorentz': 'WeylFermion', 'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'dL',
#   'Parents': 'q',
#   'Properties': {'Lorentz': 'WeylFermion', 'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'vL',
#   'Parents': 'l',
#   'Properties': {'Lorentz': 'WeylFermion', 'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'eL',
#   'Parents': 'l',
#   'Properties': {'Lorentz': 'WeylFermion', 'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'dR',
#   'Parents': 'd',
#   'Properties': {'Lorentz': 'WeylFermion', 'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'uR',
#   'Parents': 'u',
#   'Properties': {'Lorentz': 'WeylFermion', 'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'eR',
#   'Parents': 'e',
#   'Properties': {'Lorentz': 'WeylFermion', 'NF': '3'}},
#  {'Definition': 'GaugeES',
#   'Field': 'Hp',
#   'Parents': 'H',
#   'Properties': {'Lorentz': 'Scalar', 'NF': '1'}},
#  {'Definition': 'GaugeES',
#   'Field': 'H0',
#   'Parents': 'H',
#   'Properties': {'Lorentz': 'Scalar', 'NF': '1'}}]

# %%
pd.DataFrame( particles )#.loc[8]['Properties']
# Out:
#                     Definition Field Parents  \
# 0                      GaugeES    VB    None
# 1                      GaugeES   VWB    None
# 2                      GaugeES    VG    None
# 3   WeylFermionAndIndermediate     q    None
# 4   WeylFermionAndIndermediate     l    None
# 5   WeylFermionAndIndermediate     d    None
# 6   WeylFermionAndIndermediate     u    None
# 7   WeylFermionAndIndermediate     e    None
# 8   WeylFermionAndIndermediate     H    None
# 9   WeylFermionAndIndermediate    uL       q
# 10  WeylFermionAndIndermediate    dL       q
# 11  WeylFermionAndIndermediate    vL       l
# 12  WeylFermionAndIndermediate    eL       l
# 13  WeylFermionAndIndermediate    dR       d
# 14  WeylFermionAndIndermediate    uR       u
# 15  WeylFermionAndIndermediate    eR       e
# 16                     GaugeES    Hp       H
# 17                     GaugeES    H0       H
#
#                                                                                                    Properties
# 0         {'Group': '   U[1]', 'Coupling': ' g1', 'SSB': ' g1', 'Lorentz': 'Vector', 'Index': ' hypercharge'}
# 1   {'Group': ' SU[2]', 'Coupling': '        g2', 'SSB': '        g2', 'Lorentz': 'Vector', 'Index': ' left'}
# 2   {'Group': '  SU[3]', 'Coupling': '       g3', 'SSB': '       g3', 'Lorentz': 'Vector', 'Index': ' color'}
# 3               {'multiplet': ['uL', 'dL'], 'NF': '3', 'Groups': ['1/6', '2', '3'], 'Lorentz': 'WeylFermion'}
# 4              {'multiplet': ['vL', 'eL'], 'NF': '3', 'Groups': ['-1/2', '2', '1'], 'Lorentz': 'WeylFermion'}
# 5                                         {'NF': '3', 'Groups': ['1/3', '1', '-3'], 'Lorentz': 'WeylFermion'}
# 6                                        {'NF': '3', 'Groups': ['-2/3', '1', '-3'], 'Lorentz': 'WeylFermion'}
# 7                                            {'NF': '3', 'Groups': ['1', '1', '1'], 'Lorentz': 'WeylFermion'}
# 8                    {'multiplet': ['Hp', 'H0'], 'NF': '1', 'Groups': ['1/2', '2', '1'], 'Lorentz': 'Scalar'}
# 9                                                                       {'NF': '3', 'Lorentz': 'WeylFermion'}
# 10                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 11                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 12                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 13                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 14                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 15                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 16                                                                           {'NF': '1', 'Lorentz': 'Scalar'}
# 17                                                                           {'NF': '1', 'Lorentz': 'Scalar'}

# %% [markdown]
# ## 2) Get particles from `DEFINITION[EWSB]`

# %%
dsbd=parse_mathematica_list_of_list(smf,NAME='DEFINITION',KEY='EWSB')
dsbd
# Out:
# {'DiracSpinors': {'Fd': ['DL', 'conj[DR]'],
#   'Fe': ['EL', 'conj[ER]'],
#   'Fu': ['UL', 'conj[UR]'],
#   'Fv': ['vL', 0]},
#  'GaugeES': {'Fd1': ['FdL', 0],
#   'Fd2': [0, 'FdR'],
#   'Fe1': ['Fe1', 0],
#   'Fe2': [0, 'Fe2'],
#   'Fu1': ['Fu1', 0],
#   'Fu2': [0, 'Fu2']},
#  'GaugeSector': [[['VB', 'VWB[3]'], ['VP', 'VZ'], 'ZZ'],
#   [['VWB[1]', 'VWB[2]'], ['VWp', 'conj[VWp]'], 'ZW']],
#  'MatterSector': [[[['dL'], ['conj[dR]']], [['DL', 'Vd'], ['DR', 'Ud']]],
#   [[['uL'], ['conj[uR]']], [['UL', 'Vu'], ['UR', 'Uu']]],
#   [[['eL'], ['conj[eR]']], [['EL', 'Ve'], ['ER', 'Ue']]]],
#  'VEVs': [['H0',
#    ['v', '1/Sqrt[2]'],
#    ['Ah', '\\[ImaginaryI]/Sqrt[2]'],
#    ['hh', '1/Sqrt[2]']]]}

# %%
DEFINITION={}
DEFINITION['EWSB']={}
Bidiagonal=[]
Diagonal=[]
VEV=[]
for k in dsbd.keys():
    
    for w in dsbd[k]:
        if k=='GaugeSector' or k=='MatterSector':
            if np.array(w).shape==(2,2):
                weyl=bidiagonal(w,k)
                Bidiagonal.append(weyl)
            elif np.array(w).shape==(3,):
                symm=diagonal(w,k)
                Diagonal.append(symm)
        elif k=='VEVs':
            VEV.append(get_vev(w,k))

DEFINITION['EWSB']['Bidiagonal']=Bidiagonal
DEFINITION['EWSB']['Diagonal']=Diagonal
DEFINITION['EWSB']['VEVs']=VEV
DEFINITION['EWSB']['DiracSpinors']=dsbd['DiracSpinors']

# %%
particles=particles+rotations_to_particles(DEFINITION,key='EWSB',lr='',sep='')
particles=particles+rotations_to_particles(DEFINITION,key='EWSB',lr='left',sep='_')
particles=particles+rotations_to_particles(DEFINITION,key='EWSB',lr='right',sep='_')

# %%
newparticles=[]
for d in DEFINITION['EWSB']['VEVs']:
    particle=vev_to_particles(d,cp='Real')
    newparticles.append(particle)
    particle=vev_to_particles(d,cp='Imaginary')
    newparticles.append(particle)
particles=particles+newparticles

# %%
newparticles=[]
dict_of_spinors=DEFINITION['EWSB']['DiracSpinors']
for f in dict_of_spinors.keys():
    particle=spinor_to_particles(dict_of_spinors,DEFINITION,f)
    newparticles.append(particle)
particles=particles+newparticles

# %%
f=open('parseparticles.json','w')
json.dump(particles,f)
f.close()

# %%
particles
# Out:
# [{'Definition': 'GaugeES',
#   'Field': 'VB',
#   'Parents': None,
#   'Properties': {'Coupling': ' g1',
#    'Group': '   U[1]',
#    'Index': ' hypercharge',
#    'Lorentz': 'Vector',
#    'SSB': ' g1'}},
#  {'Definition': 'GaugeES',
#   'Field': 'VWB',
#   'Parents': None,
#   'Properties': {'Coupling': '        g2',
#    'Group': ' SU[2]',
#    'Index': ' left',
#    'Lorentz': 'Vector',
#    'SSB': '        g2'}},
#  {'Definition': 'GaugeES',
#   'Field': 'VG',
#   'Parents': None,
#   'Properties': {'Coupling': '       g3',
#    'Group': '  SU[3]',
#    'Index': ' color',
#    'Lorentz': 'Vector',
#    'SSB': '       g3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'q',
#   'Parents': None,
#   'Properties': {'Groups': ['1/6', '2', '3'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'multiplet': ['uL', 'dL']}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'l',
#   'Parents': None,
#   'Properties': {'Groups': ['-1/2', '2', '1'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3',
#    'multiplet': ['vL', 'eL']}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'd',
#   'Parents': None,
#   'Properties': {'Groups': ['1/3', '1', '-3'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'u',
#   'Parents': None,
#   'Properties': {'Groups': ['-2/3', '1', '-3'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'e',
#   'Parents': None,
#   'Properties': {'Groups': ['1', '1', '1'],
#    'Lorentz': 'WeylFermion',
#    'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'H',
#   'Parents': None,
#   'Properties': {'Groups': ['1/2', '2', '1'],
#    'Lorentz': 'Scalar',
#    'NF': '1',
#    'multiplet': ['Hp', 'H0']}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'uL',
#   'Parents': 'q',
#   'Properties': {'Lorentz': 'WeylFermion', 'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'dL',
#   'Parents': 'q',
#   'Properties': {'Lorentz': 'WeylFermion', 'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'vL',
#   'Parents': 'l',
#   'Properties': {'Lorentz': 'WeylFermion', 'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'eL',
#   'Parents': 'l',
#   'Properties': {'Lorentz': 'WeylFermion', 'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'dR',
#   'Parents': 'd',
#   'Properties': {'Lorentz': 'WeylFermion', 'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'uR',
#   'Parents': 'u',
#   'Properties': {'Lorentz': 'WeylFermion', 'NF': '3'}},
#  {'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'eR',
#   'Parents': 'e',
#   'Properties': {'Lorentz': 'WeylFermion', 'NF': '3'}},
#  {'Definition': 'GaugeES',
#   'Field': 'Hp',
#   'Parents': 'H',
#   'Properties': {'Lorentz': 'Scalar', 'NF': '1'}},
#  {'Definition': 'GaugeES',
#   'Field': 'H0',
#   'Parents': 'H',
#   'Properties': {'Lorentz': 'Scalar', 'NF': '1'}},
#  {'Block': 'GaugeSector',
#   'Definition': 'EWSB',
#   'Field': 'VP',
#   'Parents': 'VB',
#   'Properties': {'Interaction_basis': ['VB', 'VWB[3]'],
#    'Lorentz': 'Vector',
#    'Mass_basis': ['VP', 'VZ']},
#   'rotation': 'ZZ'},
#  {'Block': 'GaugeSector',
#   'Definition': 'EWSB',
#   'Field': 'VZ',
#   'Parents': 'VWB[3]',
#   'Properties': {'Interaction_basis': ['VB', 'VWB[3]'],
#    'Lorentz': 'Vector',
#    'Mass_basis': ['VP', 'VZ']},
#   'rotation': 'ZZ'},
#  {'Block': 'GaugeSector',
#   'Definition': 'EWSB',
#   'Field': 'VWp',
#   'Parents': 'VWB[1]',
#   'Properties': {'Interaction_basis': ['VWB[1]', 'VWB[2]'],
#    'Lorentz': 'Vector',
#    'Mass_basis': ['VWp', 'conj[VWp]']},
#   'rotation': 'ZW'},
#  {'Block': 'MatterField',
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'DL',
#   'Parents': 'dL',
#   'Properties': {'Chirality': 'left',
#    'Interaction_basis': ['dL'],
#    'Lorentz': 'WeylFermion',
#    'Mass_basis': 'DL'},
#   'rotation': 'Vd'},
#  {'Block': 'MatterField',
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'UL',
#   'Parents': 'uL',
#   'Properties': {'Chirality': 'left',
#    'Interaction_basis': ['uL'],
#    'Lorentz': 'WeylFermion',
#    'Mass_basis': 'UL'},
#   'rotation': 'Vu'},
#  {'Block': 'MatterField',
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'EL',
#   'Parents': 'eL',
#   'Properties': {'Chirality': 'left',
#    'Interaction_basis': ['eL'],
#    'Lorentz': 'WeylFermion',
#    'Mass_basis': 'EL'},
#   'rotation': 'Ve'},
#  {'Block': 'MatterField',
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'DR',
#   'Parents': 'conj[dR]',
#   'Properties': {'Chirality': 'right',
#    'Interaction_basis': ['conj[dR]'],
#    'Lorentz': 'WeylFermion',
#    'Mass_basis': 'DR'},
#   'rotation': 'Ud'},
#  {'Block': 'MatterField',
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'UR',
#   'Parents': 'conj[uR]',
#   'Properties': {'Chirality': 'right',
#    'Interaction_basis': ['conj[uR]'],
#    'Lorentz': 'WeylFermion',
#    'Mass_basis': 'UR'},
#   'rotation': 'Uu'},
#  {'Block': 'MatterField',
#   'Definition': 'WeylFermionAndIndermediate',
#   'Field': 'ER',
#   'Parents': 'conj[eR]',
#   'Properties': {'Chirality': 'right',
#    'Interaction_basis': ['conj[eR]'],
#    'Lorentz': 'WeylFermion',
#    'Mass_basis': 'ER'},
#   'rotation': 'Ue'},
#  {'Block': 'VEVs',
#   'Definition': 'EWSB',
#   'Field': 'hh',
#   'Parents': 'H0',
#   'Properties': {'CP': 'Real',
#    'Coefficient': '1/Sqrt[2]',
#    'Lorentz': 'Scalar',
#    'vev': 'v'}},
#  {'Block': 'VEVs',
#   'Definition': 'EWSB',
#   'Field': 'Ah',
#   'Parents': 'H0',
#   'Properties': {'CP': 'Imaginary',
#    'Coefficient': '\\[ImaginaryI]/Sqrt[2]',
#    'Lorentz': 'Scalar',
#    'vev': 'v'}},
#  {'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Field': 'Fd',
#   'Parents': 'DL',
#   'Properties': {'DiracSpinor': ['DL', 'conj[DR]'], 'Lorentz': 'DiracSpinor'}},
#  {'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Field': 'Fe',
#   'Parents': 'EL',
#   'Properties': {'DiracSpinor': ['EL', 'conj[ER]'], 'Lorentz': 'DiracSpinor'}},
#  {'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Field': 'Fu',
#   'Parents': 'UL',
#   'Properties': {'DiracSpinor': ['UL', 'conj[UR]'], 'Lorentz': 'DiracSpinor'}},
#  {'Block': 'DiracSpinors',
#   'Definition': 'EWSB',
#   'Field': 'Fv',
#   'Parents': 'vL',
#   'Properties': {'Lorentz': 'MajoranaSpinor', 'MajoranaSpinor': ['vL', 0]}}]

# %%
pd.read_json('parseparticles.json')
# Out:
#            Block                  Definition Field   Parents  \
# 0            NaN                     GaugeES    VB      None
# 1            NaN                     GaugeES   VWB      None
# 2            NaN                     GaugeES    VG      None
# 3            NaN  WeylFermionAndIndermediate     q      None
# 4            NaN  WeylFermionAndIndermediate     l      None
# 5            NaN  WeylFermionAndIndermediate     d      None
# 6            NaN  WeylFermionAndIndermediate     u      None
# 7            NaN  WeylFermionAndIndermediate     e      None
# 8            NaN  WeylFermionAndIndermediate     H      None
# 9            NaN  WeylFermionAndIndermediate    uL         q
# 10           NaN  WeylFermionAndIndermediate    dL         q
# 11           NaN  WeylFermionAndIndermediate    vL         l
# 12           NaN  WeylFermionAndIndermediate    eL         l
# 13           NaN  WeylFermionAndIndermediate    dR         d
# 14           NaN  WeylFermionAndIndermediate    uR         u
# 15           NaN  WeylFermionAndIndermediate    eR         e
# 16           NaN                     GaugeES    Hp         H
# 17           NaN                     GaugeES    H0         H
# 18   GaugeSector                        EWSB    VP        VB
# 19   GaugeSector                        EWSB    VZ    VWB[3]
# 20   GaugeSector                        EWSB   VWp    VWB[1]
# 21   MatterField  WeylFermionAndIndermediate    DL        dL
# 22   MatterField  WeylFermionAndIndermediate    UL        uL
# 23   MatterField  WeylFermionAndIndermediate    EL        eL
# 24   MatterField  WeylFermionAndIndermediate    DR  conj[dR]
# 25   MatterField  WeylFermionAndIndermediate    UR  conj[uR]
# 26   MatterField  WeylFermionAndIndermediate    ER  conj[eR]
# 27          VEVs                        EWSB    hh        H0
# 28          VEVs                        EWSB    Ah        H0
# 29  DiracSpinors                        EWSB    Fd        DL
# 30  DiracSpinors                        EWSB    Fe        EL
# 31  DiracSpinors                        EWSB    Fu        UL
# 32  DiracSpinors                        EWSB    Fv        vL
#
#                                                                                                    Properties  \
# 0         {'Group': '   U[1]', 'Coupling': ' g1', 'SSB': ' g1', 'Index': ' hypercharge', 'Lorentz': 'Vector'}
# 1   {'Group': ' SU[2]', 'Coupling': '        g2', 'SSB': '        g2', 'Index': ' left', 'Lorentz': 'Vector'}
# 2   {'Group': '  SU[3]', 'Coupling': '       g3', 'SSB': '       g3', 'Index': ' color', 'Lorentz': 'Vector'}
# 3               {'multiplet': ['uL', 'dL'], 'NF': '3', 'Groups': ['1/6', '2', '3'], 'Lorentz': 'WeylFermion'}
# 4              {'multiplet': ['vL', 'eL'], 'NF': '3', 'Groups': ['-1/2', '2', '1'], 'Lorentz': 'WeylFermion'}
# 5                                         {'NF': '3', 'Groups': ['1/3', '1', '-3'], 'Lorentz': 'WeylFermion'}
# 6                                        {'NF': '3', 'Groups': ['-2/3', '1', '-3'], 'Lorentz': 'WeylFermion'}
# 7                                            {'NF': '3', 'Groups': ['1', '1', '1'], 'Lorentz': 'WeylFermion'}
# 8                    {'multiplet': ['Hp', 'H0'], 'NF': '1', 'Groups': ['1/2', '2', '1'], 'Lorentz': 'Scalar'}
# 9                                                                       {'NF': '3', 'Lorentz': 'WeylFermion'}
# 10                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 11                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 12                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 13                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 14                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 15                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 16                                                                           {'NF': '1', 'Lorentz': 'Scalar'}
# 17                                                                           {'NF': '1', 'Lorentz': 'Scalar'}
# 18                   {'Mass_basis': ['VP', 'VZ'], 'Interaction_basis': ['VB', 'VWB[3]'], 'Lorentz': 'Vector'}
# 19                   {'Mass_basis': ['VP', 'VZ'], 'Interaction_basis': ['VB', 'VWB[3]'], 'Lorentz': 'Vector'}
# 20       {'Mass_basis': ['VWp', 'conj[VWp]'], 'Interaction_basis': ['VWB[1]', 'VWB[2]'], 'Lorentz': 'Vector'}
# 21           {'Mass_basis': 'DL', 'Chirality': 'left', 'Interaction_basis': ['dL'], 'Lorentz': 'WeylFermion'}
# 22           {'Mass_basis': 'UL', 'Chirality': 'left', 'Interaction_basis': ['uL'], 'Lorentz': 'WeylFermion'}
# 23           {'Mass_basis': 'EL', 'Chirality': 'left', 'Interaction_basis': ['eL'], 'Lorentz': 'WeylFermion'}
# 24    {'Mass_basis': 'DR', 'Chirality': 'right', 'Interaction_basis': ['conj[dR]'], 'Lorentz': 'WeylFermion'}
# 25    {'Mass_basis': 'UR', 'Chirality': 'right', 'Interaction_basis': ['conj[uR]'], 'Lorentz': 'WeylFermion'}
# 26    {'Mass_basis': 'ER', 'Chirality': 'right', 'Interaction_basis': ['conj[eR]'], 'Lorentz': 'WeylFermion'}
# 27                                {'CP': 'Real', 'Coefficient': '1/Sqrt[2]', 'vev': 'v', 'Lorentz': 'Scalar'}
# 28               {'CP': 'Imaginary', 'Coefficient': '\[ImaginaryI]/Sqrt[2]', 'vev': 'v', 'Lorentz': 'Scalar'}
# 29                                              {'DiracSpinor': ['DL', 'conj[DR]'], 'Lorentz': 'DiracSpinor'}
# 30                                              {'DiracSpinor': ['EL', 'conj[ER]'], 'Lorentz': 'DiracSpinor'}
# 31                                              {'DiracSpinor': ['UL', 'conj[UR]'], 'Lorentz': 'DiracSpinor'}
# 32                                                 {'Lorentz': 'MajoranaSpinor', 'MajoranaSpinor': ['vL', 0]}
#
#    rotation
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18       ZZ
# 19       ZZ
# 20       ZW
# 21       Vd
# 22       Vu
# 23       Ve
# 24       Ud
# 25       Uu
# 26       Ue
# 27      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN

# %%
prt=pd.DataFrame(particles)

# %% [markdown]
# ## Generate `particles.json` from particles dict

# %% [markdown]
# The Higgs doublet is assumed to be assigned to 'H'

# %%
prt.index
# Out:
# RangeIndex(start=0, stop=33, step=1)

# %%
for p in prt['Field']:
    print(p)
    break
# Out:
# VB

# %%
def get_weylfermion_LaTeX(s):
    if len(s)==2 and re.search('[LR]$',s):
        sini=s[0]
        if sini=='v':
            sini=r'\nu'
        s=sini+'_'+s[1]
    return s

def get_abs_groups(grps=['1/2','2','1'],u1_abs='1/2',su2='2',su3_abs='1'):
    sgrps=str(grps).replace(' ','')
    return re.search(r"\['-*{}','{}','{}'".format(u1_abs,su2,su3_abs), sgrps )

# %%
def update_EWSB_Fermion_Description(p,prt,Lorentz='DiracSpinor'):
    gprt=prt[prt.get('Field')==p.get('Parents')].reset_index(drop=True)
    if Lorentz=='DiracSpinor':
        gprt=prt[prt.get('Field')==gprt.loc[0,'Parents']].reset_index(drop=True)
    cmpt=gprt.loc[0,'Field']
    gprt=prt[prt.get('Field')==gprt.loc[0,'Parents']].reset_index(drop=True)
    if get_abs_groups( gprt.loc[0,'Properties'].get('Groups'), u1_abs='1/6',su2='2',su3_abs='3' ):
        if cmpt==gprt.loc[0,'Properties'].get('multiplet')[0]:
            p['Description']='Up-Quarks'
        else:
            p['Description']='Down-Quarks'
    if get_abs_groups( gprt.loc[0,'Properties'].get('Groups'), u1_abs='1/2',su2='2',su3_abs='1' ):
        if cmpt==gprt.loc[0,'Properties'].get('multiplet')[0]:
            p['Description']='Neutrinos'
        else:
            p['Description']='Leptons'
    return p

# %%
#TODO: Make false when there are more scalar doublets
Add_Charged_SM_Higgs_to_EWSB=True
newparticles=[]
for i in prt.index:
    p=prt.loc[i].to_dict()
    if p.get('Definition')=='GaugeES' and p.get('Properties').get('Lorentz').strip()=='Vector':
        if  p.get('Properties').get('Group').strip()=='U[1]':
            p['Description']='B-Boson'
            newparticles.append(p)
            newparticles.append({'Definition':'GaugeEs','Field':'gB',
                               'Description':'B-Boson Ghost',
                               'Parents':p.get('Field'),'Properties':{
                               'Group':p.get('Properties').get('Group'),'Lorentz':'Scalar'}})
            #break
        elif p.get('Properties').get('Group').strip()=='SU[2]':
            p['Description']='W-Bosons'
            newparticles.append(p)
            newparticles.append({'Definition':'GaugeEs','Field':'gWB',
                               'Description':'W-Boson Ghost',
                               'Parents':p.get('Field'),'Properties':{
                                'Group':p.get('Properties').get('Group'), 'Lorentz':'Scalar'}})        
            
        elif p.get('Properties').get('Group').strip()=='SU[3]':
            p['Description']='Gluon'
            newparticles.append(p)
            newparticles.append({'Definition':'GaugeEs','Field':'gG',
                               'Description':'Gluon Ghost',
                               'Parents':p.get('Field'),'Properties':{
                               'Group':p.get('Properties').get('Group'),'Lorentz':'Scalar'}})
        #Search for daugthers
    if p.get('Definition')=='WeylFermionAndIndermediate' and p.get('Properties').get('Lorentz')=='Scalar':
        #Generic Doublet scalar: Include SM Higgs
        #re.search(r"\['-*1/2','2','1'",str(p.get('Properties').get('Groups')).replace(' ',''))
        if get_abs_groups(p.get('Properties').get('Groups'),u1_abs='1/2',su2='2',su3_abs='1'):
            p.get('Properties')['update_Description']={'PDG'       : [0],
                                                           'Width'     : 0,
                                                           'Mass'      : 'Automatic',
                                                           'LaTeX'     : p.get('Field'),
                                                           'OutputName': p.get('Field') }
            newparticles.append(p)
            #print(p)
            dprt=prt[prt['Parents']==p.get('Field')].reset_index(drop=True)
            if dprt.shape[0]==2:
                print('va',0)
                for j in dprt.index:
                    dp=dprt.loc[j].to_dict()
                    #Higss components
                    charge=[]
                    if dp.get('Parents')=='H':
                        if p.get('Properties').get('Groups')[0].find('-')==-1:
                            charge=['Charged','Neutral']
                        else:
                            charge=['Neutral','Charged']
                        #print('va j',j,charge)
                            
                        if charge[j]=='Charged':
                            dp.get('Properties')['update_Description']={'PDG'  :[0],
                                    'Width':0,
                                    'Mass' : 'Automatic',
                                    'FeynArtsNr' : 2,
                                    'LaTeX' : 'H^+',
                                    'OutputName' : dp.get('Field')                            
                                   }                            
                            newparticles.append(dp)
                            #TODO: Add EWSB charged scalar only if no more scalars
                            # with parent Hp
                            if Add_Charged_SM_Higgs_to_EWSB:
                                gdp={'Definition': 'EWSB',
                                     'Field': 'Hp',
                                     'Parents': 'Hp',
                                     'Properties': {'Lorentz': 'Scalar',
                                     'NF': '1',
                                     'Description': 'Charged Higgs',
                                     'update_Description': {
                                         'PDG'            : [0],
                                         'PDG.IX'         : [0],
                                         'Width'          : [0], 
                                         'Mass'           : [0],
                                         'LaTeX'          : ['H^+','H^-' ],
                                         'OutputName'     : ['Hp' ,'Hm'  ],
                                        'ElectricCharge' : 1
                                     }}}
                                newparticles.append(gdp)                                
                        else: #Neutral
                            dp.get('Properties')['update_Description']={'PDG'  :[0],
                                    'Width':0,
                                    'Mass' : 'Automatic',
                                    'FeynArtsNr' : 1,
                                    'LaTeX' : 'H^0',
                                    'OutputName' : dp.get('Field')                        
                                   }
                            newparticles.append(dp)
                            #print('va H0',j)
                            
                            #TODO: Define object to capture two daugthers
                            gdprt=prt[prt['Parents']==dp.get('Field')].reset_index(drop=True)
                            if gdprt.shape[0]==2:
                                for k in gdprt.index:
                                    gdp=gdprt.loc[k].to_dict()
                                    if gdp.get('Properties').get('CP')=='Real':
                                        gdp['Description']='Higgs'
                                        gdp.get('Properties')['update_Description']={
                                            'PDG'         : [25],
                                            'PDG.IX'      : [101000001]
                                        }
                                        newparticles.append(gdp)
                                    else: #'CP' → Imaginary 
                                        gdp['Description']='Pseudo-Scalar Higgs'
                                        gdp.get('Properties')['update_Description']={
                                            'PDG'         : [0],
                                            'PDG.IX'      : [0],
                                            'Mass'        : [0],
                                            'Width'       : [0]
                                        }
                                        newparticles.append(gdp)                                        
                                    #break
                        #break
            #break
            #Search for daughters: two complex fields
    if p.get('Definition')=='WeylFermionAndIndermediate' and p.get('Properties').get('Lorentz')=='WeylFermion':
        p.get('Properties')['update_Description']={'LaTeX' : get_weylfermion_LaTeX( p.get('Field') )}            
        newparticles.append(p)
    if p.get('Definition')=='EWSB' and p.get('Properties').get('Lorentz')=='DiracSpinor':
        p=update_EWSB_Fermion_Description(p,prt)
        newparticles.append(p)
    if p.get('Definition')=='EWSB' and p.get('Properties').get('Lorentz')=='MajoranaSpinor':
        p=update_EWSB_Fermion_Description(p,prt,Lorentz=p.get('Properties').get('Lorentz'))
        newparticles.append(p)
        #break        
        #break
# Out:
# va 0

# %%
nprt=pd.DataFrame(newparticles)

# %%
nprt.index=nprt['Description']

# %%
nprt.to_dict()
# Out:
# {'Block': {'B-Boson': nan,
#   'B-Boson Ghost': nan,
#   'Down-Quarks': 'DiracSpinors',
#   'Gluon': nan,
#   'Gluon Ghost': nan,
#   'Higgs': 'VEVs',
#   'Leptons': 'DiracSpinors',
#   'Neutrinos': 'DiracSpinors',
#   'Pseudo-Scalar Higgs': 'VEVs',
#   'Up-Quarks': 'DiracSpinors',
#   'W-Boson Ghost': nan,
#   'W-Bosons': nan,
#   nan: 'MatterField'},
#  'Definition': {'B-Boson': 'GaugeES',
#   'B-Boson Ghost': 'GaugeEs',
#   'Down-Quarks': 'EWSB',
#   'Gluon': 'GaugeES',
#   'Gluon Ghost': 'GaugeEs',
#   'Higgs': 'EWSB',
#   'Leptons': 'EWSB',
#   'Neutrinos': 'EWSB',
#   'Pseudo-Scalar Higgs': 'EWSB',
#   'Up-Quarks': 'EWSB',
#   'W-Boson Ghost': 'GaugeEs',
#   'W-Bosons': 'GaugeES',
#   nan: 'WeylFermionAndIndermediate'},
#  'Description': {'B-Boson': 'B-Boson',
#   'B-Boson Ghost': 'B-Boson Ghost',
#   'Down-Quarks': 'Down-Quarks',
#   'Gluon': 'Gluon',
#   'Gluon Ghost': 'Gluon Ghost',
#   'Higgs': 'Higgs',
#   'Leptons': 'Leptons',
#   'Neutrinos': 'Neutrinos',
#   'Pseudo-Scalar Higgs': 'Pseudo-Scalar Higgs',
#   'Up-Quarks': 'Up-Quarks',
#   'W-Boson Ghost': 'W-Boson Ghost',
#   'W-Bosons': 'W-Bosons',
#   nan: nan},
#  'Field': {'B-Boson': 'VB',
#   'B-Boson Ghost': 'gB',
#   'Down-Quarks': 'Fd',
#   'Gluon': 'VG',
#   'Gluon Ghost': 'gG',
#   'Higgs': 'hh',
#   'Leptons': 'Fe',
#   'Neutrinos': 'Fv',
#   'Pseudo-Scalar Higgs': 'Ah',
#   'Up-Quarks': 'Fu',
#   'W-Boson Ghost': 'gWB',
#   'W-Bosons': 'VWB',
#   nan: 'ER'},
#  'Parents': {'B-Boson': None,
#   'B-Boson Ghost': 'VB',
#   'Down-Quarks': 'DL',
#   'Gluon': None,
#   'Gluon Ghost': 'VG',
#   'Higgs': 'H0',
#   'Leptons': 'EL',
#   'Neutrinos': 'vL',
#   'Pseudo-Scalar Higgs': 'H0',
#   'Up-Quarks': 'UL',
#   'W-Boson Ghost': 'VWB',
#   'W-Bosons': None,
#   nan: 'conj[eR]'},
#  'Properties': {'B-Boson': {'Coupling': ' g1',
#    'Group': '   U[1]',
#    'Index': ' hypercharge',
#    'Lorentz': 'Vector',
#    'SSB': ' g1'},
#   'B-Boson Ghost': {'Group': '   U[1]', 'Lorentz': 'Scalar'},
#   'Down-Quarks': {'DiracSpinor': ['DL', 'conj[DR]'], 'Lorentz': 'DiracSpinor'},
#   'Gluon': {'Coupling': '       g3',
#    'Group': '  SU[3]',
#    'Index': ' color',
#    'Lorentz': 'Vector',
#    'SSB': '       g3'},
#   'Gluon Ghost': {'Group': '  SU[3]', 'Lorentz': 'Scalar'},
#   'Higgs': {'CP': 'Real',
#    'Coefficient': '1/Sqrt[2]',
#    'Lorentz': 'Scalar',
#    'update_Description': {'PDG': [25], 'PDG.IX': [101000001]},
#    'vev': 'v'},
#   'Leptons': {'DiracSpinor': ['EL', 'conj[ER]'], 'Lorentz': 'DiracSpinor'},
#   'Neutrinos': {'Lorentz': 'MajoranaSpinor', 'MajoranaSpinor': ['vL', 0]},
#   'Pseudo-Scalar Higgs': {'CP': 'Imaginary',
#    'Coefficient': '\\[ImaginaryI]/Sqrt[2]',
#    'Lorentz': 'Scalar',
#    'update_Description': {'Mass': [0],
#     'PDG': [0],
#     'PDG.IX': [0],
#     'Width': [0]},
#    'vev': 'v'},
#   'Up-Quarks': {'DiracSpinor': ['UL', 'conj[UR]'], 'Lorentz': 'DiracSpinor'},
#   'W-Boson Ghost': {'Group': ' SU[2]', 'Lorentz': 'Scalar'},
#   'W-Bosons': {'Coupling': '        g2',
#    'Group': ' SU[2]',
#    'Index': ' left',
#    'Lorentz': 'Vector',
#    'SSB': '        g2'},
#   nan: {'Chirality': 'right',
#    'Interaction_basis': ['conj[eR]'],
#    'Lorentz': 'WeylFermion',
#    'Mass_basis': 'ER',
#    'update_Description': {'LaTeX': 'E_R'}}},
#  'rotation': {'B-Boson': nan,
#   'B-Boson Ghost': nan,
#   'Down-Quarks': nan,
#   'Gluon': nan,
#   'Gluon Ghost': nan,
#   'Higgs': nan,
#   'Leptons': nan,
#   'Neutrinos': nan,
#   'Pseudo-Scalar Higgs': nan,
#   'Up-Quarks': nan,
#   'W-Boson Ghost': nan,
#   'W-Bosons': nan,
#   nan: 'Ue'}}

# %%
prt[prt['Field']=='Hp'].reset_index(drop=True).loc[0].to_dict()
# Out:
# {'Block': nan,
#  'Definition': 'GaugeES',
#  'Field': 'Hp',
#  'Parents': 'H',
#  'Properties': {'Lorentz': 'Scalar',
#   'NF': '1',
#   'update_Description': {'FeynArtsNr': 1,
#    'LaTeX': 'H^0',
#    'Mass': 'Automatic',
#    'OutputName': 'Hp',
#    'PDG': [0],
#    'Width': 0}},
#  'rotation': nan}

# %%
newparticles.append({'Definition':'GaugeEs','Field':'gB',
                               'Description':'B-Boson Ghost',
                               'Parents':p['Field'],'Properties':{'Lorentz':'Scalar'}})

# %%
pd.DataFrame(particles)
# Out:
#            Block                  Definition    Description Field   Parents  \
# 0            NaN                     GaugeES  B-Boson Ghost    gB      None
# 1            NaN                     GaugeES       W-Bosons   VWB      None
# 2            NaN                     GaugeES          Gluon    VG      None
# 3            NaN  WeylFermionAndIndermediate            NaN     q      None
# 4            NaN  WeylFermionAndIndermediate            NaN     l      None
# 5            NaN  WeylFermionAndIndermediate            NaN     d      None
# 6            NaN  WeylFermionAndIndermediate            NaN     u      None
# 7            NaN  WeylFermionAndIndermediate            NaN     e      None
# 8            NaN  WeylFermionAndIndermediate            NaN     H      None
# 9            NaN  WeylFermionAndIndermediate            NaN    uL         q
# 10           NaN  WeylFermionAndIndermediate            NaN    dL         q
# 11           NaN  WeylFermionAndIndermediate            NaN    vL         l
# 12           NaN  WeylFermionAndIndermediate            NaN    eL         l
# 13           NaN  WeylFermionAndIndermediate            NaN    dR         d
# 14           NaN  WeylFermionAndIndermediate            NaN    uR         u
# 15           NaN  WeylFermionAndIndermediate            NaN    eR         e
# 16           NaN                     GaugeES            NaN    Hp         H
# 17           NaN                     GaugeES            NaN    H0         H
# 18   GaugeSector                        EWSB            NaN    VP        VB
# 19   GaugeSector                        EWSB            NaN    VZ    VWB[3]
# 20   GaugeSector                        EWSB            NaN   VWp    VWB[1]
# 21   MatterField  WeylFermionAndIndermediate            NaN    DL        dL
# 22   MatterField  WeylFermionAndIndermediate            NaN    UL        uL
# 23   MatterField  WeylFermionAndIndermediate            NaN    EL        eL
# 24   MatterField  WeylFermionAndIndermediate            NaN    DR  conj[dR]
# 25   MatterField  WeylFermionAndIndermediate            NaN    UR  conj[uR]
# 26   MatterField  WeylFermionAndIndermediate            NaN    ER  conj[eR]
# 27          VEVs                        EWSB            NaN    hh        H0
# 28          VEVs                        EWSB            NaN    Ah        H0
# 29  DiracSpinors                        EWSB            NaN    Fv        vL
# 30  DiracSpinors                        EWSB            NaN    Fu        UL
# 31  DiracSpinors                        EWSB            NaN    Fd        DL
# 32  DiracSpinors                        EWSB            NaN    Fe        EL
#
#                                                                                                    Properties  \
# 0         {'SSB': ' g1', 'Coupling': ' g1', 'Group': '   U[1]', 'Lorentz': 'Vector', 'Index': ' hypercharge'}
# 1   {'SSB': '        g2', 'Coupling': '        g2', 'Group': ' SU[2]', 'Lorentz': 'Vector', 'Index': ' left'}
# 2   {'SSB': '       g3', 'Coupling': '       g3', 'Group': '  SU[3]', 'Lorentz': 'Vector', 'Index': ' color'}
# 3                               {'Groups': ['     1/6', ' 2', '  3;  '], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 4                                 {'Groups': ['    -1/2', ' 2', '  1;'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 5                                  {'Groups': ['     1/3', ' 1', ' -3'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 6                                  {'Groups': ['    -2/3', ' 1', ' -3'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 7                                  {'Groups': ['       1', ' 1', '  1'], 'NF': '3', 'Lorentz': 'WeylFermion'}
# 8                                      {'Groups': ['     1/2', ' 2', '  1;'], 'NF': '1', 'Lorentz': 'Scalar'}
# 9                                                                       {'NF': '3', 'Lorentz': 'WeylFermion'}
# 10                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 11                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 12                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 13                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 14                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 15                                                                      {'NF': '3', 'Lorentz': 'WeylFermion'}
# 16                                                                           {'NF': '1', 'Lorentz': 'Scalar'}
# 17                                                                           {'NF': '1', 'Lorentz': 'Scalar'}
# 18                   {'Mass_basis': ['VP', 'VZ'], 'Interaction_basis': ['VB', 'VWB[3]'], 'Lorentz': 'Vector'}
# 19                   {'Mass_basis': ['VP', 'VZ'], 'Interaction_basis': ['VB', 'VWB[3]'], 'Lorentz': 'Vector'}
# 20       {'Mass_basis': ['VWp', 'conj[VWp]'], 'Interaction_basis': ['VWB[1]', 'VWB[2]'], 'Lorentz': 'Vector'}
# 21                                     {'Mass_basis': 'DL', 'Interaction_basis': ['dL'], 'Chirality': 'left'}
# 22                                     {'Mass_basis': 'UL', 'Interaction_basis': ['uL'], 'Chirality': 'left'}
# 23                                     {'Mass_basis': 'EL', 'Interaction_basis': ['eL'], 'Chirality': 'left'}
# 24                              {'Mass_basis': 'DR', 'Interaction_basis': ['conj[dR]'], 'Chirality': 'right'}
# 25                              {'Mass_basis': 'UR', 'Interaction_basis': ['conj[uR]'], 'Chirality': 'right'}
# 26                              {'Mass_basis': 'ER', 'Interaction_basis': ['conj[eR]'], 'Chirality': 'right'}
# 27                                {'Coefficient': '1/Sqrt[2]', 'CP': 'Real', 'vev': 'v', 'Lorentz': 'Scalar'}
# 28               {'Coefficient': '\[ImaginaryI]/Sqrt[2]', 'CP': 'Imaginary', 'vev': 'v', 'Lorentz': 'Scalar'}
# 29                                                 {'MajoranaSpinor': ['vL', 0], 'Lorentz': 'MajoranaSpinor'}
# 30                                              {'DiracSpinor': ['UL', 'conj[UR]'], 'Lorentz': 'DiracSpinor'}
# 31                                              {'DiracSpinor': ['DL', 'conj[DR]'], 'Lorentz': 'DiracSpinor'}
# 32                                              {'DiracSpinor': ['EL', 'conj[ER]'], 'Lorentz': 'DiracSpinor'}
#
#    rotation
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18       ZZ
# 19       ZZ
# 20       ZW
# 21       Vd
# 22       Vu
# 23       Ve
# 24       Ud
# 25       Uu
# 26       Ue
# 27      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN

# %%
print(smf)
# Out:
# Off[General::spell]
#
# Model`Name = "SM";
# Model`NameLaTeX ="Standard Model";
# Model`Authors = "F.Staub";
# Model`Date = "2014-11-06";
#
# (* 2013-01-24: changed normalization of lambda term to convention of hep-ph/0207271 *)
# (* 2013-06-24: using new name conventions (without inital "S" and "F" for scalar and matter fields) *)
# (* 2013-09-01: changing to new conventions for FermionFields/MatterFields *)
# (* 2014-11-06: Changed sign in Lagrangian to fit standard conventions *)
# (* 2016-05-03: Changed sign of Yu *)
#
#
#
# (*-------------------------------------------*)
# (*   Particle Content*)
# (*-------------------------------------------*)
#
# (* Gauge Groups *)
#
# Gauge[[1]]={B,   U[1], hypercharge, g1,False};
# Gauge[[2]]={WB, SU[2], left,        g2,True};
# Gauge[[3]]={G,  SU[3], color,       g3,False};
#
#
# (* Matter Fields *)
#
# FermionFields[[1]] = {q, 3, {uL, dL},     1/6, 2,  3};
# FermionFields[[2]] = {l, 3, {vL, eL},    -1/2, 2,  1};
# FermionFields[[3]] = {d, 3, conj[dR],     1/3, 1, -3};
# FermionFields[[4]] = {u, 3, conj[uR],    -2/3, 1, -3};
# FermionFields[[5]] = {e, 3, conj[eR],       1, 1,  1};
#
# ScalarFields[[1]] =  {H, 1, {Hp, H0},     1/2, 2,  1};
#
#
#
# (*----------------------------------------------*)
# (*   DEFINITION                                 *)
# (*----------------------------------------------*)
#
# NameOfStates={GaugeES, EWSB};
#
# (* ----- Before EWSB ----- *)
#
# DEFINITION[GaugeES][LagrangianInput]= {
# 	{LagHC, {AddHC->True}},
# 	{LagNoHC,{AddHC->False}}
# };
#
#
# LagNoHC = -mu2 conj[H].H - 1/2 \[Lambda] conj[H].H.conj[H].H;
# LagHC =  -(Yd conj[H].d.q + Ye conj[H].e.l + Yu u.q.H);
#
#
#
#
# (* Gauge Sector *)
#
# DEFINITION[EWSB][GaugeSector] =
# {
#   {{VB,VWB[3]},{VP,VZ},ZZ},
#   {{VWB[1],VWB[2]},{VWp,conj[VWp]},ZW}
# };
#
#
#
#
# (* ----- VEVs ---- *)
#
# DEFINITION[EWSB][VEVs]=
# {    {H0, {v, 1/Sqrt[2]}, {Ah, \[ImaginaryI]/Sqrt[2]},{hh, 1/Sqrt[2]}}     };
#
#
# DEFINITION[EWSB][MatterSector]=
#     {{{{dL}, {conj[dR]}}, {{DL,Vd}, {DR,Ud}}},
#      {{{uL}, {conj[uR]}}, {{UL,Vu}, {UR,Uu}}},
#      {{{eL}, {conj[eR]}}, {{EL,Ve}, {ER,Ue}}}};
#
#
# (*------------------------------------------------------*)
# (* Dirac-Spinors *)
# (*------------------------------------------------------*)
#
# DEFINITION[EWSB][DiracSpinors]={
#  Fd ->{  DL, conj[DR]},
#  Fe ->{  EL, conj[ER]},
#  Fu ->{  UL, conj[UR]},
#  Fv ->{  vL, 0}};
#
# DEFINITION[EWSB][GaugeES]={
#  Fd1 ->{  FdL, 0},
#  Fd2 ->{  0, FdR},
#  Fu1 ->{  Fu1, 0},
#  Fu2 ->{  0, Fu2},
#  Fe1 ->{  Fe1, 0},
#  Fe2 ->{  0, Fe2}};

# %%
1+1
# Out:
# 2
